# %%
# API key: 3CPSX6vE31S6wiyUFpc45wqd6
# API Secret Key: mbuRYtNTaFLYC5IRrW2Dz6mj5fXlkv0SgIk5OCSLqLYHQMXR0O
# Access Token: 391364404-IiRlLVX4KO1OiTFbtpMEWjzNoV07AJI7YPd8z1kD
# Access Token Secret: qvmLo4zi3tcQWJIYZQkrB2P0iwcuzHLaLmTBpo98HYmNg
# Bearer Token: AAAAAAAAAAAAAAAAAAAAANb5KgEAAAAA4ekthlHPKw6igRtOWh7JwrT7v4Q%3Dsl2xPlwhys2Lkd26GlhymYSzRVYeLL7a0DowLnLxXRuus15lYw

# %%
consumer_key = "3CPSX6vE31S6wiyUFpc45wqd6"
consumer_key_secret = "mbuRYtNTaFLYC5IRrW2Dz6mj5fXlkv0SgIk5OCSLqLYHQMXR0O"
access_token = "391364404-IiRlLVX4KO1OiTFbtpMEWjzNoV07AJI7YPd8z1kD"
access_token_secret = "qvmLo4zi3tcQWJIYZQkrB2P0iwcuzHLaLmTBpo98HYmNg"
bearer_token = "AAAAAAAAAAAAAAAAAAAAANb5KgEAAAAA4ekthlHPKw6igRtOWh7JwrT7v4Q%3Dsl2xPlwhys2Lkd26GlhymYSzRVYeLL7a0DowLnLxXRuus15lYw"

# %%
# authentication for URL based api

import requests
from requests_oauthlib import OAuth1

auth = OAuth1(consumer_key, consumer_key_secret, access_token, access_token_secret)

# %%
import tweepy
import matplotlib.pyplot as plt

auth = tweepy.OAuthHandler("3CPSX6vE31S6wiyUFpc45wqd6", "mbuRYtNTaFLYC5IRrW2Dz6mj5fXlkv0SgIk5OCSLqLYHQMXR0O")
auth.set_access_token("391364404-IiRlLVX4KO1OiTFbtpMEWjzNoV07AJI7YPd8z1kD", "qvmLo4zi3tcQWJIYZQkrB2P0iwcuzHLaLmTBpo98HYmNg")

api = tweepy.API(auth)

# %%
trends_raw = api.trends_place(id=20070458)
trends_raw
# Out:
# [{'trends': [{'name': '#SidNaazKiPyaariDuniya',
#     'url': 'http://twitter.com/search?q=%23SidNaazKiPyaariDuniya',
#     'promoted_content': None,
#     'query': '%23SidNaazKiPyaariDuniya',
#     'tweet_volume': 104890},
#    {'name': '#Marriage_In_17Minutes',
#     'url': 'http://twitter.com/search?q=%23Marriage_In_17Minutes',
#     'promoted_content': None,
#     'query': '%23Marriage_In_17Minutes',
#     'tweet_volume': 333084},
#    {'name': '#Dahej_Mukt_Bharat',
#     'url': 'http://twitter.com/search?q=%23Dahej_Mukt_Bharat',
#     'promoted_content': None,
#     'query': '%23Dahej_Mukt_Bharat',
#     'tweet_volume': 288124},
#    {'name': '#WeRejectADMK',
#     'url': 'http://twitter.com/search?q=%23WeRejectADMK',
#     'promoted_content': None,
#     'query': '%23WeRejectADMK',
#     'tweet_volume': 104479},
#    {'name': '#IndiaRoars4SSR',
#     'url': 'http://twitter.com/search?q=%23IndiaRoars4SSR',
#     'promoted_content': None,
#     'query': '%23IndiaRoars4SSR',
#     'tweet_volume': 129911},
#    {'name': 'Gurudwara',
#     'url': 'http://twitter.com/search?q=Gurudwara',
#     'promoted_content': None,
#     'query': 'Gurudwara',
#     'tweet_volume': 20948},
#    {'name': 'Sant Rampal Ji Maharaj',
#     'url': 'http://twitter.com/search?q=%22Sant+Rampal+Ji+Maharaj%22',
#     'promoted_content': None,
#     'query': '%22Sant+Rampal+Ji+Maharaj%22',
#     'tweet_volume': 82194},
#    {'name': 'Guru Teg Bahadur',
#     'url': 'http://twitter.com/search?q=%22Guru+Teg+Bahadur%22',
#     'promoted_content': None,
#     'query': '%22Guru+Teg+Bahadur%22',
#     'tweet_volume': 12452},
#    {'name': 'दहेज मुक्त',
#     'url': 'http://twitter.com/search?q=%22%E0%A4%A6%E0%A4%B9%E0%A5%87%E0%A4%9C+%E0%A4%AE%E0%A5%81%E0%A4%95%E0%A5%8D%E0%A4%A4%22',
#     'promoted_content': None,
#     'query': '%22%E0%A4%A6%E0%A4%B9%E0%A5%87%E0%A4%9C+%E0%A4%AE%E0%A5%81%E0%A4%95%E0%A5%8D%E0%A4%A4%22',
#     'tweet_volume': 79336},
#    {'name': 'Canelo',
#     'url': 'http://twitter.com/search?q=Canelo',
#     'promoted_content': None,
#     'query': 'Canelo',
#     'tweet_volume': 191831},
#    {'name': 'Ankita',
#     'url': 'http://twitter.com/search?q=Ankita',
#     'promoted_content': None,
#     'query': 'Ankita',
#     'tweet_volume': 13398},
#    {'name': 'Dowry',
#     'url': 'http://twitter.com/search?q=Dowry',
#     'promoted_content': None,
#     'query': 'Dowry',
#     'tweet_volume': 148236},
#    {'name': 'सिंह रावत',
#     'url': 'http://twitter.com/search?q=%22%E0%A4%B8%E0%A4%BF%E0%A4%82%E0%A4%B9+%E0%A4%B0%E0%A4%BE%E0%A4%B5%E0%A4%A4%22',
#     'promoted_content': None,
#     'query': '%22%E0%A4%B8%E0%A4%BF%E0%A4%82%E0%A4%B9+%E0%A4%B0%E0%A4%BE%E0%A4%B5%E0%A4%A4%22',
#     'tweet_volume': None},
#    {'name': 'Expression Queen',
#     'url': 'http://twitter.com/search?q=%22Expression+Queen%22',
#     'promoted_content': None,
#     'query': '%22Expression+Queen%22',
#     'tweet_volume': None},
#    {'name': 'उत्तम स्वास्थ्य',
#     'url': 'http://twitter.com/search?q=%22%E0%A4%89%E0%A4%A4%E0%A5%8D%E0%A4%A4%E0%A4%AE+%E0%A4%B8%E0%A5%8D%E0%A4%B5%E0%A4%BE%E0%A4%B8%E0%A5%8D%E0%A4%A5%E0%A5%8D%E0%A4%AF%22',
#     'promoted_content': None,
#     'query': '%22%E0%A4%89%E0%A4%A4%E0%A5%8D%E0%A4%A4%E0%A4%AE+%E0%A4%B8%E0%A5%8D%E0%A4%B5%E0%A4%BE%E0%A4%B8%E0%A5%8D%E0%A4%A5%E0%A5%8D%E0%A4%AF%22',
#     'tweet_volume': None},
#    {'name': 'Tulsi',
#     'url': 'http://twitter.com/search?q=Tulsi',
#     'promoted_content': None,
#     'query': 'Tulsi',
#     'tweet_volume': 28521},
#    {'name': 'मुख्यमंत्री श्री',
#     'url': 'http://twitter.com/search?q=%22%E0%A4%AE%E0%A5%81%E0%A4%96%E0%A5%8D%E0%A4%AF%E0%A4%AE%E0%A4%82%E0%A4%A4%E0%A5%8D%E0%A4%B0%E0%A5%80+%E0%A4%B6%E0%A5%8D%E0%A4%B0%E0%A5%80%22',
#     'promoted_content': None,
#     'query': '%22%E0%A4%AE%E0%A5%81%E0%A4%96%E0%A5%8D%E0%A4%AF%E0%A4%AE%E0%A4%82%E0%A4%A4%E0%A5%8D%E0%A4%B0%E0%A5%80+%E0%A4%B6%E0%A5%8D%E0%A4%B0%E0%A5%80%22',
#     'tweet_volume': 15015},
#    {'name': 'Sant Shri Asharamji Bapu',
#     'url': 'http://twitter.com/search?q=%22Sant+Shri+Asharamji+Bapu%22',
#     'promoted_content': None,
#     'query': '%22Sant+Shri+Asharamji+Bapu%22',
#     'tweet_volume': 74608},
#    {'name': 'गुरु तेग बहादुर',
#     'url': 'http://twitter.com/search?q=%22%E0%A4%97%E0%A5%81%E0%A4%B0%E0%A5%81+%E0%A4%A4%E0%A5%87%E0%A4%97+%E0%A4%AC%E0%A4%B9%E0%A4%BE%E0%A4%A6%E0%A5%81%E0%A4%B0%22',
#     'promoted_content': None,
#     'query': '%22%E0%A4%97%E0%A5%81%E0%A4%B0%E0%A5%81+%E0%A4%A4%E0%A5%87%E0%A4%97+%E0%A4%AC%E0%A4%B9%E0%A4%BE%E0%A4%A6%E0%A5%81%E0%A4%B0%22',
#     'tweet_volume': 14963},
#    {'name': 'AIADMK',
#     'url': 'http://twitter.com/search?q=AIADMK',
#     'promoted_content': None,
#     'query': 'AIADMK',
#     'tweet_volume': 18510},
#    {'name': 'PM Modi',
#     'url': 'http://twitter.com/search?q=%22PM+Modi%22',
#     'promoted_content': None,
#     'query': '%22PM+Modi%22',
#     'tweet_volume': 28334},
#    {'name': '#FarmActsAreUnconstitutional',
#     'url': 'http://twitter.com/search?q=%23FarmActsAreUnconstitutional',
#     'promoted_content': None,
#     'query': '%23FarmActsAreUnconstitutional',
#     'tweet_volume': 68402},
#    {'name': '#StandWithPopularFront',
#     'url': 'http://twitter.com/search?q=%23StandWithPopularFront',
#     'promoted_content': None,
#     'query': '%23StandWithPopularFront',
#     'tweet_volume': 20839},
#    {'name': '#IndiaUnsafeUnderBJP',
#     'url': 'http://twitter.com/search?q=%23IndiaUnsafeUnderBJP',
#     'promoted_content': None,
#     'query': '%23IndiaUnsafeUnderBJP',
#     'tweet_volume': 10479},
#    {'name': '#sundayvibes',
#     'url': 'http://twitter.com/search?q=%23sundayvibes',
#     'promoted_content': None,
#     'query': '%23sundayvibes',
#     'tweet_volume': None},
#    {'name': '#SundayMorning',
#     'url': 'http://twitter.com/search?q=%23SundayMorning',
#     'promoted_content': None,
#     'query': '%23SundayMorning',
#     'tweet_volume': None},
#    {'name': '#SundayMotivation',
#     'url': 'http://twitter.com/search?q=%23SundayMotivation',
#     'promoted_content': None,
#     'query': '%23SundayMotivation',
#     'tweet_volume': None},
#    {'name': '#BengalwithBJP',
#     'url': 'http://twitter.com/search?q=%23BengalwithBJP',
#     'promoted_content': None,
#     'query': '%23BengalwithBJP',
#     'tweet_volume': 113640},
#    {'name': '#SundayThoughts',
#     'url': 'http://twitter.com/search?q=%23SundayThoughts',
#     'promoted_content': None,
#     'query': '%23SundayThoughts',
#     'tweet_volume': None},
#    {'name': '#TaimurAliKhan',
#     'url': 'http://twitter.com/search?q=%23TaimurAliKhan',
#     'promoted_content': None,
#     'query': '%23TaimurAliKhan',
#     'tweet_volume': None},
#    {'name': '#IntolerantIslam',
#     'url': 'http://twitter.com/search?q=%23IntolerantIslam',
#     'promoted_content': None,
#     'query': '%23IntolerantIslam',
#     'tweet_volume': 53697},
#    {'name': '#ThankYouAJITH',
#     'url': 'http://twitter.com/search?q=%23ThankYouAJITH',
#     'promoted_content': None,
#     'query': '%23ThankYouAJITH',
#     'tweet_volume': None},
#    {'name': '#KICCHATheBrandOfSandalwood',
#     'url': 'http://twitter.com/search?q=%23KICCHATheBrandOfSandalwood',
#     'promoted_content': None,
#     'query': '%23KICCHATheBrandOfSandalwood',
#     'tweet_volume': 66789},
#    {'name': '#HBDNazriyaNazim',
#     'url': 'http://twitter.com/search?q=%23HBDNazriyaNazim',
#     'promoted_content': None,
#     'query': '%23HBDNazriyaNazim',
#     'tweet_volume': None},
#    {'name': '#1YrOfRevolutionaryHero',
#     'url': 'http://twitter.com/search?q=%231YrOfRevolutionaryHero',
#     'promoted_content': None,
#     'query': '%231YrOfRevolutionaryHero',
#     'tweet_volume': 22424},
#    {'name': '#KicchaSudeep',
#     'url': 'http://twitter.com/search?q=%23KicchaSudeep',
#     'promoted_content': None,
#     'query': '%23KicchaSudeep',
#     'tweet_volume': 69351},
#    {'name': '#Save21LakhParivar',
#     'url': 'http://twitter.com/search?q=%23Save21LakhParivar',
#     'promoted_content': None,
#     'query': '%23Save21LakhParivar',
#     'tweet_volume': 10008},
#    {'name': '#TheFamilyMan',
#     'url': 'http://twitter.com/search?q=%23TheFamilyMan',
#     'promoted_content': None,
#     'query': '%23TheFamilyMan',
#     'tweet_volume': None},
#    {'name': '#TheGreat_Initiator',
#     'url': 'http://twitter.com/search?q=%23TheGreat_Initiator',
#     'promoted_content': None,
#     'query': '%23TheGreat_Initiator',
#     'tweet_volume': 63997},
#    {'name': '#giftoftruelife',
#     'url': 'http://twitter.com/search?q=%23giftoftruelife',
#     'promoted_content': None,
#     'query': '%23giftoftruelife',
#     'tweet_volume': 15447},
#    {'name': '#hindumunnani',
#     'url': 'http://twitter.com/search?q=%23hindumunnani',
#     'promoted_content': None,
#     'query': '%23hindumunnani',
#     'tweet_volume': None},
#    {'name': '#Nepal',
#     'url': 'http://twitter.com/search?q=%23Nepal',
#     'promoted_content': None,
#     'query': '%23Nepal',
#     'tweet_volume': None},
#    {'name': '#NZvPAK',
#     'url': 'http://twitter.com/search?q=%23NZvPAK',
#     'promoted_content': None,
#     'query': '%23NZvPAK',
#     'tweet_volume': None},
#    {'name': '#36allout',
#     'url': 'http://twitter.com/search?q=%2336allout',
#     'promoted_content': None,
#     'query': '%2336allout',
#     'tweet_volume': 12047},
#    {'name': '#Fight_For_Farmer_Right',
#     'url': 'http://twitter.com/search?q=%23Fight_For_Farmer_Right',
#     'promoted_content': None,
#     'query': '%23Fight_For_Farmer_Right',
#     'tweet_volume': 12204},
#    {'name': '#dainikjagranghatiyapanbandkar',
#     'url': 'http://twitter.com/search?q=%23dainikjagranghatiyapanbandkar',
#     'promoted_content': None,
#     'query': '%23dainikjagranghatiyapanbandkar',
#     'tweet_volume': None},
#    {'name': '#VDO_नियुक्ति_दो_योगीजी',
#     'url': 'http://twitter.com/search?q=%23VDO_%E0%A4%A8%E0%A4%BF%E0%A4%AF%E0%A5%81%E0%A4%95%E0%A5%8D%E0%A4%A4%E0%A4%BF_%E0%A4%A6%E0%A5%8B_%E0%A4%AF%E0%A5%8B%E0%A4%97%E0%A5%80%E0%A4%9C%E0%A5%80',
#     'promoted_content': None,
#     'query': '%23VDO_%E0%A4%A8%E0%A4%BF%E0%A4%AF%E0%A5%81%E0%A4%95%E0%A5%8D%E0%A4%A4%E0%A4%BF_%E0%A4%A6%E0%A5%8B_%E0%A4%AF%E0%A5%8B%E0%A4%97%E0%A5%80%E0%A4%9C%E0%A5%80',
#     'tweet_volume': 29091},
#    {'name': '#Phantom',
#     'url': 'http://twitter.com/search?q=%23Phantom',
#     'promoted_content': None,
#     'query': '%23Phantom',
#     'tweet_volume': 44582},
#    {'name': '#SundayFunday',
#     'url': 'http://twitter.com/search?q=%23SundayFunday',
#     'promoted_content': None,
#     'query': '%23SundayFunday',
#     'tweet_volume': None},
#    {'name': '#மக்களுக்கான_தலைவர்_திருமா',
#     'url': 'http://twitter.com/search?q=%23%E0%AE%AE%E0%AE%95%E0%AF%8D%E0%AE%95%E0%AE%B3%E0%AF%81%E0%AE%95%E0%AF%8D%E0%AE%95%E0%AE%BE%E0%AE%A9_%E0%AE%A4%E0%AE%B2%E0%AF%88%E0%AE%B5%E0%AE%B0%E0%AF%8D_%E0%AE%A4%E0%AE%BF%E0%AE%B0%E0%AF%81%E0%AE%AE%E0%AE%BE',
#     'promoted_content': None,
#     'query': '%23%E0%AE%AE%E0%AE%95%E0%AF%8D%E0%AE%95%E0%AE%B3%E0%AF%81%E0%AE%95%E0%AF%8D%E0%AE%95%E0%AE%BE%E0%AE%A9_%E0%AE%A4%E0%AE%B2%E0%AF%88%E0%AE%B5%E0%AE%B0%E0%AF%8D_%E0%AE%A4%E0%AE%BF%E0%AE%B0%E0%AF%81%E0%AE%AE%E0%AE%BE',
#     'tweet_volume': None}],
#   'as_of': '2020-12-20T07:00:07Z',
#   'created_at': '2020-12-19T06:18:19Z',
#   'locations': [{'name': 'Delhi', 'woeid': 20070458}]}]

# %%
top_trending_hashtag = trends_raw[0]['trends'][0]['name']
top_trending_hashtag
# Out:
# '#SidNaazKiPyaariDuniya'

# %%
tweets = tweepy.Cursor(api.search,
              q=top_trending_hashtag).items(50)

# %%
tweets

# %%
# [tweet.text for tweet in tweets]

# %%
tweets = api.search(q=top_trending_hashtag, count=100)

# %%
# tweets

# %%
for tweet in tweets:
    print(tweet._json['text'])
    print('----------')
# Out:
# @Kuch_na_kahoo Kullu.. Puttu.. Baby... Gulu gulu... Kasam... Etc..
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @KrithikaTweets: From : Teri duniya alag hai, Meri alag hai
# To: #SidNaazKiPyaariDuniya
# ----------
# RT @Soul_SidNaaz13: Guy's the tag line is out and it is -
# #SidNaazKiPyaariDuniya
# ----------
# RT @iamautumnspark: it’s a love story , baby just say YES !
# #SidNaazKiPyaariDuniya https://t.co/GYlMOYUI2g
# ----------
# RT @Saloni05007919: #SidNaaz KA CRAZEEE SIRF BHADA HAI.......OR SIRF BHADEGA.......(FIRE ND HEART EMOJI)
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @TamandeepKaur5: #SidNaazKiPyaariDuniya
#
# 101k completed guys.....
#
# Keep tweeting https://t.co/JqNpXu4WiT
# ----------
# RT @iBeingAman: 100K + Tweets Done in 28 Mins !!!
#
# Aaj Ek Baar Firse Duniya Pagal Ho Rahi Hain....
#
# Keep Maintain Dis Speed Guys...Rukna Na…
# ----------
# Mai to agar sidnaaz ke bareme mere friends ko bolna suru karti hu to rukti hi nehi hu
# #SidNaazKiPyaariDuniya
# ----------
# RT @iBeingAman: Describe #SidNaaz Chemistry in One Word !!!
#
# Comment Everyone wid Tag Fast !!!
#
# &gt;&gt; #SidNaazKiPyaariDuniya ✓✓
# ----------
# RT @JThakers: Hamesha Khush Rahe ...!#SidNaazKiPyaariDuniya
# ----------
# RT @sidnaazbaebies: Indeed sabse pyaari duniya. Indeed the best thing to happen to us in 2020.
#
# We are all blessed to witness the greatest…
# ----------
# RT @Rose_isFae: Heyyyyy beautiful peeps... m back... sorry was out of house with mom... let’s enjoy trend now ... The tagline is: #SidNaazK…
# ----------
# RT @HSpheonix: #SidNaaz tum jo aaye zindagi mein baat bann gyi.....
# #SidNaazKiPyaariDuniya
# ----------
# RT @SheilaSandhu: Hey @sidharth_shukla n @ishehnaaz_gill how about a live session together as a Xmas gift for us...
# #SidNaazKiPyaariDuniya
# ----------
# RT @Ohudeadppl: Him taking care of her on MSK sets and she being her happy self seeing him with her.
#
# #SidNaazKiPyaariDuniya
# ----------
# @Hriri84722788 Lol
# #SidNaazKiPyaariDuniya
# ----------
# RT @_naive_girl: We are luckiest ! Why ? Bcoz we saw two strangers meeting, being each others best friends, forming a magical bond, falling…
# ----------
# love you both #SidNaazKiPyaariDuniya
# ----------
# RT @BTG_ChotaFc: @4EverTillEnd Abey moti
# #SidNaazKiPyaariDuniya
# ----------
# RT @vinita_pansari: I am sorry
#
# I embarrassed u ( mera baby )
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @Pankha_Army: 101 k done in 27 minutes
#
# 200 we are just near you
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @_shadowstar: From Sidharth hiding the SidNaaz related content in his stories to openly posting it
#
# We have come a long way
#
# #SidNaazKi…
# ----------
# RT @celebtani: 100k done!!
# In just 27mins!
#
# #SidNaazKiPyaariDuniya
# ----------
# @devdNk Good morning
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @sidheartfan21: Trending
#
# #SidNaazKiPyaariDuniya https://t.co/vCeaCMsebD
# ----------
# RT @4EverTillEnd: Sidharth Once Said ?
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @ColdCoffee2710: Q) Duniya kiske peeche pagal hai..?
# Le Duniya: #SidNaazKiPyaariDuniya
# ----------
# RT @sidnaaz__fan: 93K tweets done #SidNaazKiPyaariDuniya
# ----------
# RT @Muz14658071: You have bewitched me body and soul, and I love, I love, I love you.
# #SidNaazKiPyaariDuniya https://t.co/oQt8nan11x
# ----------
# RT @Inaayat_ily: @FemaleSidheart ofcourse babes!
# #SidNaazKiPyaariDuniya
# ----------
# RT @Ohudeadppl: Living in this 'duniya' is not easy, ups and downs are there but at the end its worth it.. its beautiful ♡
# #SidNaazKiPyaari…
# ----------
# RT @KapoorSamrita: From "Teri Duniya Alag MERI Duniya Alag" to #SidNaazKiPyaariDuniya
#
# What a beautiful journey
# ----------
# RT @Min_Miera01: Can I get 100 RT....
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @JyadaHoRhaTera: "Your hand fits in mine like its made just for me
# But bear this mind it was meant to be
# And I'm joining up the dots wit…
# ----------
# RT @TeraSyapa: what was it like to lose her?
# it was like hearing every goodbye ever said to him - said all at once.
# #SidNaaz
# #SidNaazKiP…
# ----------
# RT @parikilife: What is love? #SidNaazKiPyaariDuniya
# ----------
# RT @Ohudeadppl: What happened when #SidNaazKiPyaariDuniya entered the REAL DUNIYA?
#
# They stayed in contact with eachother and no one else.…
# ----------
# RT @nk_sidnaaz: Congratulations SidNaazians from USA .... #SidNaazKiPyaariDuniya
# ----------
# RT @sunaina_113: I've been waiting for this tagline since sooo long!!!
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @mini_fizz: She was deeply in Love with Him
# He was Madly in Love with Her
#
# But the best thing we witnessed they did not run for anything…
# ----------
# RT @_miss__kaur_: Who is your role model?
#
# Reply using #SidNaazKiPyaariDuniya
# ----------
# RT @Saloni05007919: ONCE SANA SAID-------------
#
# USE TAGLINE
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @ayaat_sidnaaz: A for attitude and aggressive also
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @ZarmeenAhmad: #SidNaazKiPyaariDuniya is trending at no 3 in pakistan
# Sidnaaz be like hmary Han tu ese he hota h https://t.co/9M1uWBewUZ
# ----------
# RT @SidNaazIsPyaar: I would worry about whether the bond will remain the same outside the house or not. And they just celebrated all the fe…
# ----------
# RT @Hayat_SidNaaz: CAN I GET 50 RTS ......ITNA TO KR HI SKTE HO
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @sidnaaz__fan: 101K tweets within 28 minutes
# #SidNaazKiPyaariDuniya https://t.co/llnkBIZyq5
# ----------
# RT @_naive_girl: The day when he made her sleep in his arms it was a new year .. a new year for us indeed
# We didn't knew what the year hel…
# ----------
# RT @sidsanax: You taught us love. You taught us how to overcome pain. You taught us strength. You taught us dignity. You taught us honestly…
# ----------
# sid - mai tujhe kabhi dukhi karunga..nahi naa....
# yes yes it's not fictional its a  fairytale real love story....… https://t.co/H1JZRHgZ4G
# ----------
# RT @_naive_girl: The day when he made her sleep in his arms it was a new year .. a new year for us indeed
# We didn't knew what the year hel…
# ----------
# RT @KrithikaTweets: From : Teri duniya alag hai, Meri alag hai
# To: #SidNaazKiPyaariDuniya
# ----------
# RT @milenialparadox: The whole tagline sums up for me in such moments &lt;3
#
# #SidNaazKiPyaariDuniya https://t.co/SaDLIn2B8t
# ----------
# RT @slay_like_diya: Finally this is happening !
# Its my fav tagline ever &lt;3
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @AGreenEyedMnstr: SidNaaz Valo kha ho attendence lgao idher.
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @Farha2000: We are living in #SidNaazKiPyaariDuniya
# ----------
# RT @iBeingAman: 100K + Tweets Done in 28 Mins !!!
#
# Aaj Ek Baar Firse Duniya Pagal Ho Rahi Hain....
#
# Keep Maintain Dis Speed Guys...Rukna Na…
# ----------
# RT @Prathyu85160274: A true relationship is two unperfect people refusing to give up on each other!
# #SidNaazKiPyaariDuniya
# ----------
# RT @chittarkhaanetu: THIS IS CRAZY
# #SidNaazKiPyaariDuniya https://t.co/MUZiZ8Z8xI
# ----------
# RT @sidnaazbaebies: Number 1 within 10 minutes!
#
# The power they hold is unmatched. The love we have for them is unmeasurable. The purest t…
# ----------
# RT @SonniaSlays: A year ago I never imagined that it would be unimaginable to think of my life without the existence of these 2 beautiful p…
# ----------
# RT @sidharthkifanhu: #SidNaazKiPyaariDuniya Congratulations @sidharth_shukla Bhai
#
# #SidharthShukla crossed 1.9M+ Posts on instagram♡♡ https…
# ----------
# @Rose_isFae Here it is  #SidNaazKiPyaariDuniya
# ----------
# RT @Innocent1Ashish: Trend pe aao Moti
#
# ( laughing emoji) ...
#
# #SidNaazKiPyaariDuniya https://t.co/aXNnFJygZD
# ----------
# RT @Santosh15285739: @OfficialSidNaaz @sidharth_shukla @ishehnaaz_gill @pinkvilla @TellyTalkIndia @PinkvillaTelly @tellychakkar @tellymasal…
# ----------
# RT @AnkitaS00194600: @SheebaM31315185 @Ohhfudge_ Red
# #sidNaazkipyaariDuniya
# ----------
# RT @SidNaazian4ever: 100k tweets in 25mins power of SidNaaz
# #SidNaazKiPyaariDuniya https://t.co/d0Exxbqa8e
# ----------
# RT @KrithikaTweets: This 6 minutes video is just heaven for all of us &lt;3 #SidNaazKiPyaariDuniya https://t.co/tJTP0OhY80
# ----------
# RT @leo_bookworm: She'd come to find him again. No one ever looked for him. They all knew he wanted to be alone. Except it wasn't always th…
# ----------
# Come enter into  #SidNaazKiPyaariDuniya
#
# Sana :Tu mujhe ignore kar raha h
# Sid :Kya karu baby photo laga k samne rak… https://t.co/Z4iBx1F1ua
# ----------
# RT @Farii_SidNaaz: I loved the tag..
# @OfficialSidNaaz thank you for this beautiful tag ♥️ #SidNaazKiPyaariDuniya
# ----------
# BABY KYA KARU MAIN KHUDH apne tears wipe karke tweet kar rahi hoon #SidNaazKiPyaariDuniya https://t.co/zhaNigVCWD
# ----------
# RT @bornsavageme: Trending no 1 with 85k plus tweets
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @SidNaazSoul: IF YOU LOVE THIS TAG LINE THEN RT THIS
#
# I WANT MAX RTS
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @AGreenEyedMnstr: Which is your favourite Sidnaaz moment???
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @Tooooobs: ~Wabi-Sabi~ The discovery of beauty in imperfection!
#
# #SidNaazKiPyaariDuniya https://t.co/Z8vQZsXDia
# ----------
# RT @Malinipanigrah6: Break fast huaa ki nhi sab ka #SidNaazKiPyaariDuniya
# ----------
# RT @KrithikaTweets: From : Teri duniya alag hai, Meri alag hai
# To: #SidNaazKiPyaariDuniya
# ----------
# RT @Saloni05007919: CAN I GET 50 RTS ......ITNA TO KR HI SKTE HO
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @4EverTillEnd: Love yourself first and everything falls into line.
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @Tooooobs: It is said that only together with a real man a woman can bloom and enjoy life, I feel like the most beautiful flower on the…
# ----------
# RT @Ohudeadppl: Inside BB house he gave  hee his shorts
# Outside BB house he gave her his 2 T shirts
# one she wore and other she made teddy…
# ----------
# RT @HusainHacker: I have Always Said this...
#
# They were Real,
# What They felt was Real,
# What we felt for them was Real !
#
# It might happen or…
# ----------
# RT @ArifaSu92622394: @Pankha_Army @ColorsTV Thanks to @ColorsTV for giving us this  tagline. The VM Rangu posted on voot with #SidNaazKiPya…
# ----------
# RT @poojavora2492: Pehna toone kurta jo peela
# Uspe gir gayi thodi si tequila
# Kurta tera ho gaya geela
# Geela geela geela geela
#
# Mera bhi mij…
# ----------
# RT @SidNaazSoul: So Sidnaazians Not it's our time
#
# The tagline is: #SidNaazKiPyaariDuniya
#
# S, N, K , P , D in capital letters
#
# Copy paste…
# ----------
# RT @_tune_hurt_kiya: 2020 gives us a lot SidNaaz content so this trend should be mega lets start everyone
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @Pankha_Army: BTW what's the target for today ?
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @SidNaazSoul: Kurkure or Lays
#
# RT for Kurkure
# Like for Lays
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @Apun_Chand_pe_h: Enjoy guys mujhe bht important kaam h oh krke ati hu u guys plz carry on #SidNaazKiPyaariDuniya
# ----------
# RT @ishapriya22: Love for u two is unconditional. I don’t know why but i feel so connected to u guys.Never ever in my life i was and i gues…
# ----------
# RT @Krishyaa2: This tagline made me emotional
# #SidNaazKiPyaariDuniya
# ----------
# RT @Inaayat_ily: the tagline has my whole dil,gurda,fefde, kidney!!!!
# meriii favvvvvvv!!
#
# #SidNaazKiPyaariDuniya is all about love and emo…
# ----------
# RT @ZarmeenAhmad: #SidNaazKiPyaariDuniya is trending at no 3 in pakistan
# Sidnaaz be like hmary Han tu ese he hota h https://t.co/9M1uWBewUZ
# ----------
# RT @daffahojaosare: They made us believe in love again.
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @AGreenEyedMnstr: Wohoooooooo Trending at no. 1 within 10 minutes.
# Burrrraaaahhhhhhhhhhh
#
# #SidNaazKiPyaariDuniya https://t.co/EF7TI3XrBK
# ----------
# RT @SonniaSlays: “Big boss chahte the Mujhe sidharth hi lekar jaaye” - @ishehnaaz_gill
#
# #SidNaazKiPyaariDuniya https://t.co/jvk6AH0hVV
# ----------
# RT @AkelaKhushHoon: Can I get 100 Rts and 10 comments with tag?
#
# #SidNaazKiPyaariDuniya
# ----------
# RT @4EverTillEnd: If you find someone you love in your life, then hang on to that love.
#
# #SidNaazKiPyaariDuniya
# ----------
# Zoro jldi aya
# @ishehnaaz_gill
# #SidNaazKiPyaariDuniya
# ----------

# %%
for tweet in tweets:
    print(tweet._json['lang'])
    print('----------')
# Out:
# en
# ----------
# en
# ----------
# et
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# hi
# ----------
# en
# ----------
# en
# ----------
# hi
# ----------
# en
# ----------
# en
# ----------
# und
# ----------
# en
# ----------
# hi
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# hi
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# in
# ----------
# en
# ----------
# en
# ----------
# hi
# ----------
# in
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# hi
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# hi
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# hi
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# in
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# hi
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# in
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# hi
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# hi
# ----------
# en
# ----------
# en
# ----------

# %%
for tweet in tweets:
    print(tweet._json['retweeted'])
    print('----------')
# Out:
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------

# %%
tweets[0]
# Out:
# Status(_api=<tweepy.api.API object at 0x7f71c482ccd0>, _json={'created_at': 'Sun Dec 20 07:00:14 +0000 2020', 'id': 1340552574986903552, 'id_str': '1340552574986903552', 'text': 'RT @iBeingAman: Trend Tagline Out Now !!!\n\nCopy &amp; Paste Everyone Fast !!!\n\n&gt;&gt; #SidNaazKiPyaariDuniya ✓✓', 'truncated': False, 'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya', 'indices': [88, 110]}], 'symbols': [], 'user_mentions': [{'screen_name': 'iBeingAman', 'name': 'BEING AMAN RAJ', 'id': 2849859583, 'id_str': '2849859583', 'indices': [3, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1334921180361289728, 'id_str': '1334921180361289728', 'name': 'Ashwini', 'screen_name': 'Ashwini76953449', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 6, 'listed_count': 0, 'created_at': 'Fri Dec 04 18:03:23 +0000 2020', 'favourites_count': 83, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 48, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Dec 20 06:32:05 +0000 2020', 'id': 1340545489519820801, 'id_str': '1340545489519820801', 'text': 'Trend Tagline Out Now !!!\n\nCopy &amp; Paste Everyone Fast !!!\n\n&gt;&gt; #SidNaazKiPyaariDuniya ✓✓', 'truncated': False, 'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya', 'indices': [72, 94]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2849859583, 'id_str': '2849859583', 'name': 'BEING AMAN RAJ', 'screen_name': 'iBeingAman', 'location': '', 'description': 'I Met Salman Khan on 28/12/19 Dream Comes True❤️\nI Met Sid Two Times After BB13 on 4 & 5 March💎\nLATEST UPDATES , PICS & VIDEO🌟 |\nFAN ACCOUNT ✌️', 'url': 'https://t.co/WqeS9UKlQZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/WqeS9UKlQZ', 'expanded_url': 'https://instagram.com/beingaman.ig?igshid=1vrztlmjbzsqi', 'display_url': 'instagram.com/beingaman.ig?i…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 16641, 'friends_count': 140, 'listed_count': 11, 'created_at': 'Fri Oct 10 06:53:48 +0000 2014', 'favourites_count': 8462, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 29725, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http:// ...

# %%
import json
tweetJson = []
for tweet in tweets:
    tweetJson.append(tweet._json)

# %%
tweetJson
# Out:
# [{'created_at': 'Sun Dec 20 07:00:14 +0000 2020',
#   'id': 1340552574986903552,
#   'id_str': '1340552574986903552',
#   'text': 'RT @iBeingAman: Trend Tagline Out Now !!!\n\nCopy &amp; Paste Everyone Fast !!!\n\n&gt;&gt; #SidNaazKiPyaariDuniya ✓✓',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#      'indices': [88, 110]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'iBeingAman',
#      'name': 'BEING AMAN RAJ',
#      'id': 2849859583,
#      'id_str': '2849859583',
#      'indices': [3, 14]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1334921180361289728,
#    'id_str': '1334921180361289728',
#    'name': 'Ashwini',
#    'screen_name': 'Ashwini76953449',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 0,
#    'friends_count': 6,
#    'listed_count': 0,
#    'created_at': 'Fri Dec 04 18:03:23 +0000 2020',
#    'favourites_count': 83,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 48,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': True,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 06:32:05 +0000 2020',
#    'id': 1340545489519820801,
#    'id_str': '1340545489519820801',
#    'text': 'Trend Tagline Out Now !!!\n\nCopy &amp; Paste Everyone Fast !!!\n\n&gt;&gt; #SidNaazKiPyaariDuniya ✓✓',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#       'indices': [72, 94]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2849859583,
#     'id_str': '2849859583',
#     'name': 'BEING AMAN RAJ',
#     'screen_name': 'iBeingAman',
#     'location': '',
#     'description': 'I Met Salman Khan on 28/12/19 Dream Comes True❤️\nI Met Sid Two Times After BB13 on 4 & 5 March💎\nLATEST UPDATES , PICS & VIDEO🌟 |\nFAN ACCOUNT ✌️',
#     'url': 'https://t.co/WqeS9UKlQZ',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/WqeS9UKlQZ',
#         'expanded_url': 'https://instagram.com/beingaman.ig?igshid=1vrztlmjbzsqi',
#         'display_url': 'instagram.com/beingaman.ig?i…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 16641,
#     'friends_count': 140,
#     'listed_count': 11,
#     'created_at': 'Fri Oct 10 06:53:48 +0000 2014',
#     'favourites_count': 8462,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 29725,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1254996853071835136/6KPfiiEr_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1254996853071835136/6KPfiiEr_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2849859583/1587956684',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 543,
#    'favorite_count': 162,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 543,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 20 07:00:14 +0000 2020',
#   'id': 1340552574567501828,
#   'id_str': '1340552574567501828',
#   'text': 'We love SIDNAAZ   #SidNaazKiPyaariDuniya',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#      'indices': [18, 40]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1232551650386046981,
#    'id_str': '1232551650386046981',
#    'name': 'Afrina',
#    'screen_name': 'Afrina23433247',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4,
#    'friends_count': 26,
#    'listed_count': 0,
#    'created_at': 'Wed Feb 26 06:23:27 +0000 2020',
#    'favourites_count': 789,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 163,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1272220641282756608/48Hr4voe_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1272220641282756608/48Hr4voe_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1232551650386046981/1592155980',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 20 07:00:14 +0000 2020',
#   'id': 1340552574412312582,
#   'id_str': '1340552574412312582',
#   'text': 'RT @PNM1210: Meaning of Love= SidNaaz\n emotional attachment\nKya tu mere pyaar me hai\nPyaar to tu mujse krta hai\nWe r just friend\n#SidNaazKi…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'PNM1210',
#      'name': 'PNM😘❤️sidnaaz❤️😘',
#      'id': 1285799994331500547,
#      'id_str': '1285799994331500547',
#      'indices': [3, 11]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'et', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1284075691357569025,
#    'id_str': '1284075691357569025',
#    'name': 'Prathyusha',
#    'screen_name': 'Prathyu85160274',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 241,
#    'friends_count': 258,
#    'listed_count': 0,
#    'created_at': 'Fri Jul 17 10:41:45 +0000 2020',
#    'favourites_count': 10165,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 10731,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1302553302958182400/pB2f0OX0_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1302553302958182400/pB2f0OX0_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1284075691357569025/1599288132',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 06:58:39 +0000 2020',
#    'id': 1340552175194279936,
#    'id_str': '1340552175194279936',
#    'text': 'Meaning of Love= SidNaaz\n emotional attachment\nKya tu mere pyaar me hai\nPyaar to tu mujse krta hai\nWe r just friend\n#SidNaazKiPyaariDuniya',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#       'indices': [116, 138]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'et', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1285799994331500547,
#     'id_str': '1285799994331500547',
#     'name': 'PNM😘❤️sidnaaz❤️😘',
#     'screen_name': 'PNM1210',
#     'location': '',
#     'description': 'Too much Emotional attachment with lovely 😘SIDNAAZ😘',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 124,
#     'friends_count': 103,
#     'listed_count': 0,
#     'created_at': 'Wed Jul 22 04:53:15 +0000 2020',
#     'favourites_count': 159,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 655,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1337827493416415233/XNXLSJ2G_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1337827493416415233/XNXLSJ2G_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1285799994331500547/1607073708',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'et'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'et'},
#  {'created_at': 'Sun Dec 20 07:00:14 +0000 2020',
#   'id': 1340552574210994178,
#   'id_str': '1340552574210994178',
#   'text': "RT @DarkesttttStorm: As Long as SID is there, it's all cool \n\nSo yaaaaaaaaaaaaaa!!!!!\n\n#SidNaazKiPyaariDuniya \n\nIt's the last trend of2020…",
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#      'indices': [87, 109]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'DarkesttttStorm',
#      'name': 'SHIVANI~~(SIDHARTH)❤🌈🔥',
#      'id': 1242696106250649602,
#      'id_str': '1242696106250649602',
#      'indices': [3, 19]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1312279121922195458,
#    'id_str': '1312279121922195458',
#    'name': 'Angel❣️',
#    'screen_name': 'CShehnaaz',
#    'location': '',
#    'description': 'Crazy for shehnaaz...😘😗',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 49,
#    'friends_count': 148,
#    'listed_count': 0,
#    'created_at': 'Sat Oct 03 06:31:56 +0000 2020',
#    'favourites_count': 2643,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 3084,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1334138420168253440/6weoBlSD_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1334138420168253440/6weoBlSD_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1312279121922195458/1604594321',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 06:34:20 +0000 2020',
#    'id': 1340546056975618052,
#    'id_str': '1340546056975618052',
#    'text': "As Long as SID is there, it's all cool \n\nSo yaaaaaaaaaaaaaa!!!!!\n\n#SidNaazKiPyaariDuniya \n\nIt's the last trend of2020 let's do it....",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#       'indices': [66, 88]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1242696106250649602,
#     'id_str': '1242696106250649602',
#     'name': 'SHIVANI~~(SIDHARTH)❤🌈🔥',
#     'screen_name': 'DarkesttttStorm',
#     'location': 'Mumbai, India',
#     'description': '|| CivilEngineer || bb13 || SidharthShukla ||ShuklaIslove || ♠️♠️',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1300,
#     'friends_count': 292,
#     'listed_count': 0,
#     'created_at': 'Wed Mar 25 06:13:44 +0000 2020',
#     'favourites_count': 54967,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 24877,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1340294034649059331/405M9M4C_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1340294034649059331/405M9M4C_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1242696106250649602/1608190822',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 267,
#    'favorite_count': 61,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 267,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 20 07:00:14 +0000 2020',
#   'id': 1340552574194208768,
#   'id_str': '1340552574194208768',
#   'text': "RT @SidNaazSoul: Isse Humara ek Alag hi attachment hai\n\nI am in with this tagline and yeah it's a bad one\n\n#SidNaazKiPyaariDuniya",
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#      'indices': [107, 129]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'SidNaazSoul',
#      'name': '💫 Gunnu 💫 ẞìdNàáz ẞôûl 💕',
#      'id': 1238364711537618944,
#      'id_str': '1238364711537618944',
#      'indices': [3, 15]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1302535217173864448,
#    'id_str': '1302535217173864448',
#    'name': 'Sonalipatil',
#    'screen_name': 'Sonalip84446141',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 145,
#    'friends_count': 400,
#    'listed_count': 0,
#    'created_at': 'Sun Sep 06 09:13:06 +0000 2020',
#    'favourites_count': 626,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1990,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1340316642195066883/-9UWgq6t_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1340316642195066883/-9UWgq6t_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 06:58:54 +0000 2020',
#    'id': 1340552237584580608,
#    'id_str': '1340552237584580608',
#    'text': "Isse Humara ek Alag hi attachment hai\n\nI am in with this tagline and yeah it's a bad one\n\n#SidNaazKiPyaariDuniya",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#       'indices': [90, 112]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1238364711537618944,
#     'id_str': '1238364711537618944',
#     'name': '💫 Gunnu 💫 ẞìdNàáz ẞôûl 💕',
#     'screen_name': 'SidNaazSoul',
#     'location': 'India',
#     'description': 'Haq Se Sidnaazian ❤️\n\nBackup - @DestinySidNaaz',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1821,
#     'friends_count': 994,
#     'listed_count': 2,
#     'created_at': 'Fri Mar 13 07:22:38 +0000 2020',
#     'favourites_count': 13371,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 29253,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1339539031311306752/z6iOzwdm_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1339539031311306752/z6iOzwdm_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1238364711537618944/1607919896',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 5,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 20 07:00:14 +0000 2020',
#   'id': 1340552574110375936,
#   'id_str': '1340552574110375936',
#   'text': 'RT @GadhaMazdoori: I am so blessed to be a part of this pyari dunya\nSo blessed to witness their pyari dunya\nSo blessed to have these two py…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'GadhaMazdoori',
#      'name': '💙Prem ki Deewani💙',
#      'id': 1226113864036765696,
#      'id_str': '1226113864036765696',
#      'indices': [3, 17]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1298276818915430401,
#    'id_str': '1298276818915430401',
#    'name': 'Zurishreya',
#    'screen_name': 'zurishreya',
#    'location': 'Jharkhand, India',
#    'description': "you can't go back and change the beginning, but you can start where you are and change the ending ♥️♥️♥️\n(kattar_sidnaaz _fan_ girl)😍😍😍",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 97,
#    'friends_count': 93,
#    'listed_count': 0,
#    'created_at': 'Tue Aug 25 15:12:04 +0000 2020',
#    'favourites_count': 124,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 3287,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1298277298076958721/wumuHmcS_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1298277298076958721/wumuHmcS_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 06:46:13 +0000 2020',
#    'id': 1340549045182447617,
#    'id_str': '1340549045182447617',
#    'text': 'I am so blessed to be a part of this pyari dunya\nSo blessed to witness their pyari dunya\nSo blessed to have these t… https://t.co/LhMl6MJQ2U',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/LhMl6MJQ2U',
#       'expanded_url': 'https://twitter.com/i/web/status/1340549045182447617',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1226113864036765696,
#     'id_str': '1226113864036765696',
#     'name': '💙Prem ki Deewani💙',
#     'screen_name': 'GadhaMazdoori',
#     'location': '',
#     'description': 'mera sense of humour kamaal hai aapko dheere dheere pata chalega😌💅😎',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 335,
#     'friends_count': 97,
#     'listed_count': 0,
#     'created_at': 'Sat Feb 08 12:01:58 +0000 2020',
#     'favourites_count': 17556,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 10158,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1339454752787214343/fuS71Mhn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1339454752787214343/fuS71Mhn_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1226113864036765696/1606096658',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 218,
#    'favorite_count': 36,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 218,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 20 07:00:14 +0000 2020',
#   'id': 1340552573980307456,
#   'id_str': '1340552573980307456',
#   'text': 'RT @sanakadevar: Shower Love For Sid and sana today using this tag in tweets !\n\n#SidNaazKiPyaariDuniya',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#      'indices': [80, 102]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'sanakadevar',
#      'name': 'Aj🌟',
#      'id': 1222159648477728771,
#      'id_str': '1222159648477728771',
#      'indices': [3, 15]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1251125361418485762,
#    'id_str': '1251125361418485762',
#    'name': 'rosysekhon',
#    'screen_name': 'rosysekhon',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 42,
#    'friends_count': 47,
#    'listed_count': 0,
#    'created_at': 'Fri Apr 17 12:28:53 +0000 2020',
#    'favourites_count': 47452,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 32140,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1282866582369099776/zLLsvkz9_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1282866582369099776/zLLsvkz9_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 06:33:13 +0000 2020',
#    'id': 1340545775172874240,
#    'id_str': '1340545775172874240',
#    'text': 'Shower Love For Sid and sana today using this tag in tweets !\n\n#SidNaazKiPyaariDuniya',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#       'indices': [63, 85]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1222159648477728771,
#     'id_str': '1222159648477728771',
#     'name': 'Aj🌟',
#     'screen_name': 'sanakadevar',
#     'location': '',
#     'description': 'Love❤️and peace✌️\n@nk_sidnaaz ka chhota bhai ❤️\n\nhttps://t.co/FgfJ7muHTn',
#     'url': None,
#     'entities': {'description': {'urls': [{'url': 'https://t.co/FgfJ7muHTn',
#         'expanded_url': 'https://www.instagram.com/sana_ka_devar/',
#         'display_url': 'instagram.com/sana_ka_devar/',
#         'indices': [49, 72]}]}},
#     'protected': False,
#     'followers_count': 1221,
#     'friends_count': 403,
#     'listed_count': 0,
#     'created_at': 'Tue Jan 28 14:09:15 +0000 2020',
#     'favourites_count': 21163,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 49380,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1340516317065928705/krrIyV7b_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1340516317065928705/krrIyV7b_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1222159648477728771/1608125670',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 117,
#    'favorite_count': 12,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 117,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 20 07:00:14 +0000 2020',
#   'id': 1340552573879664640,
#   'id_str': '1340552573879664640',
#   'text': 'RT @PG_Edits_: BB ne bhi hamare liye voot pe #SidNaazKiPyaariDuniya banayi....',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#      'indices': [45, 67]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'PG_Edits_',
#      'name': 'PG',
#      'id': 1199917635451768832,
#      'id_str': '1199917635451768832',
#      'indices': [3, 13]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1252453455450517505,
#    'id_str': '1252453455450517505',
#    'name': 'beenu',
#    'screen_name': 'beenu15122446',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 39,
#    'friends_count': 157,
#    'listed_count': 0,
#    'created_at': 'Tue Apr 21 04:25:59 +0000 2020',
#    'favourites_count': 52095,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 13787,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': True,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 06:37:55 +0000 2020',
#    'id': 1340546955533897730,
#    'id_str': '1340546955533897730',
#    'text': 'BB ne bhi hamare liye voot pe #SidNaazKiPyaariDuniya banayi....',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#       'indices': [30, 52]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1199917635451768832,
#     'id_str': '1199917635451768832',
#     'name': 'PG',
#     'screen_name': 'PG_Edits_',
#     'location': '',
#     'description': '❤SidNaaz Forever❤ haters jalte raho🔥😂',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 5391,
#     'friends_count': 168,
#     'listed_count': 3,
#     'created_at': 'Thu Nov 28 05:07:27 +0000 2019',
#     'favourites_count': 49,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 28961,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1339543490124947458/VhlMsOSW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1339543490124947458/VhlMsOSW_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1199917635451768832/1593002608',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 59,
#    'favorite_count': 10,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'hi'},
#   'is_quote_status': False,
#   'retweet_count': 59,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'hi'},
#  {'created_at': 'Sun Dec 20 07:00:14 +0000 2020',
#   'id': 1340552573871255553,
#   'id_str': '1340552573871255553',
#   'text': 'RT @iBeingAman: Trend Tagline Out Now !!!\n\nCopy &amp; Paste Everyone Fast !!!\n\n&gt;&gt; #SidNaazKiPyaariDuniya ✓✓',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#      'indices': [88, 110]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'iBeingAman',
#      'name': 'BEING AMAN RAJ',
#      'id': 2849859583,
#      'id_str': '2849859583',
#      'indices': [3, 14]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1232629727145283585,
#    'id_str': '1232629727145283585',
#    'name': '💞Sid💖Naaz💞',
#    'screen_name': 'KhushiJhurani5',
#    'location': 'Ahmadabad City, India',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 44,
#    'friends_count': 87,
#    'listed_count': 0,
#    'created_at': 'Wed Feb 26 11:33:36 +0000 2020',
#    'favourites_count': 8299,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 6304,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1339302859607719936/LbnGIrFx_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1339302859607719936/LbnGIrFx_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1232629727145283585/1608149787',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 06:32:05 +0000 2020',
#    'id': 1340545489519820801,
#    'id_str': '1340545489519820801',
#    'text': 'Trend Tagline Out Now !!!\n\nCopy &amp; Paste Everyone Fast !!!\n\n&gt;&gt; #SidNaazKiPyaariDuniya ✓✓',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#       'indices': [72, 94]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2849859583,
#     'id_str': '2849859583',
#     'name': 'BEING AMAN RAJ',
#     'screen_name': 'iBeingAman',
#     'location': '',
#     'description': 'I Met Salman Khan on 28/12/19 Dream Comes True❤️\nI Met Sid Two Times After BB13 on 4 & 5 March💎\nLATEST UPDATES , PICS & VIDEO🌟 |\nFAN ACCOUNT ✌️',
#     'url': 'https://t.co/WqeS9UKlQZ',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/WqeS9UKlQZ',
#         'expanded_url': 'https://instagram.com/beingaman.ig?igshid=1vrztlmjbzsqi',
#         'display_url': 'instagram.com/beingaman.ig?i…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 16641,
#     'friends_count': 140,
#     'listed_count': 11,
#     'created_at': 'Fri Oct 10 06:53:48 +0000 2014',
#     'favourites_count': 8462,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 29725,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1254996853071835136/6KPfiiEr_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1254996853071835136/6KPfiiEr_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2849859583/1587956684',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 543,
#    'favorite_count': 162,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 543,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 20 07:00:14 +0000 2020',
#   'id': 1340552573770555392,
#   'id_str': '1340552573770555392',
#   'text': 'RT @kaurnavi11: 100k in less thn half an hour \n#SidNaazKiPyaariDuniya',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#      'indices': [47, 69]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'kaurnavi11',
#      'name': '💫👀😘Navi😘ShonaShona👀💫',
#      'id': 1226993662359261184,
#      'id_str': '1226993662359261184',
#      'indices': [3, 14]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1218875675714576386,
#    'id_str': '1218875675714576386',
#    'name': 'Anjali //Shona Shona😘😘',
#    'screen_name': 'sidnaazanjali',
#    'location': '',
#    'description': 'Falling in Love with the bond share by @sidharth_shukla nd @ishehnaaz_gill  called (SIDNAAZ) #sidnaaz 💞💞💞 backup id @sidnaazanjali2',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 190,
#    'friends_count': 204,
#    'listed_count': 0,
#    'created_at': 'Sun Jan 19 12:40:03 +0000 2020',
#    'favourites_count': 10185,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 10759,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1330413357183234048/2A86ecP2_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1330413357183234048/2A86ecP2_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1218875675714576386/1591596707',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
# ...
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 20 07:00:13 +0000 2020',
#   'id': 1340552568225730561,
#   'id_str': '1340552568225730561',
#   'text': 'RT @SidNaaz92012982: Do jism ek jaan . So truly said \n#SidNaazKiPyaariDuniya',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#      'indices': [54, 76]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'SidNaaz92012982',
#      'name': 'SidNaaz Love',
#      'id': 1340283982345211904,
#      'id_str': '1340283982345211904',
#      'indices': [3, 19]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1274728090749394945,
#    'id_str': '1274728090749394945',
#    'name': 'Somya',
#    'screen_name': 'Somya42411855',
#    'location': 'New Delhi, India',
#    'description': '#SidNaazForever\n# Kullu&Gadhi\n💞💞💞💞💞',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 123,
#    'friends_count': 150,
#    'listed_count': 0,
#    'created_at': 'Sun Jun 21 15:37:34 +0000 2020',
#    'favourites_count': 8252,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 3244,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1333778197964414980/i2Mdbhee_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1333778197964414980/i2Mdbhee_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1274728090749394945/1606471692',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 06:59:39 +0000 2020',
#    'id': 1340552428416995328,
#    'id_str': '1340552428416995328',
#    'text': 'Do jism ek jaan . So truly said \n#SidNaazKiPyaariDuniya',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#       'indices': [33, 55]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1340283982345211904,
#     'id_str': '1340283982345211904',
#     'name': 'SidNaaz Love',
#     'screen_name': 'SidNaaz92012982',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 5,
#     'friends_count': 25,
#     'listed_count': 0,
#     'created_at': 'Sat Dec 19 13:13:10 +0000 2020',
#     'favourites_count': 15,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 46,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1340311405459750914/b45w5AUH_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1340311405459750914/b45w5AUH_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'hi'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'hi'},
#  {'created_at': 'Sun Dec 20 07:00:13 +0000 2020',
#   'id': 1340552568221536258,
#   'id_str': '1340552568221536258',
#   'text': 'RT @iBeingAman: Trend Tagline Out Now !!!\n\nCopy &amp; Paste Everyone Fast !!!\n\n&gt;&gt; #SidNaazKiPyaariDuniya ✓✓',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#      'indices': [88, 110]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'iBeingAman',
#      'name': 'BEING AMAN RAJ',
#      'id': 2849859583,
#      'id_str': '2849859583',
#      'indices': [3, 14]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1269528558537338880,
#    'id_str': '1269528558537338880',
#    'name': 'Chaitali D',
#    'screen_name': 'SonaliD42497127',
#    'location': 'Mumbai, India',
#    'description': '#sidnaaz',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 41,
#    'friends_count': 104,
#    'listed_count': 0,
#    'created_at': 'Sun Jun 07 07:17:07 +0000 2020',
#    'favourites_count': 295,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 1906,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1302522623918632960/N1xk9jvx_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1302522623918632960/N1xk9jvx_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 06:32:05 +0000 2020',
#    'id': 1340545489519820801,
#    'id_str': '1340545489519820801',
#    'text': 'Trend Tagline Out Now !!!\n\nCopy &amp; Paste Everyone Fast !!!\n\n&gt;&gt; #SidNaazKiPyaariDuniya ✓✓',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#       'indices': [72, 94]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2849859583,
#     'id_str': '2849859583',
#     'name': 'BEING AMAN RAJ',
#     'screen_name': 'iBeingAman',
#     'location': '',
#     'description': 'I Met Salman Khan on 28/12/19 Dream Comes True❤️\nI Met Sid Two Times After BB13 on 4 & 5 March💎\nLATEST UPDATES , PICS & VIDEO🌟 |\nFAN ACCOUNT ✌️',
#     'url': 'https://t.co/WqeS9UKlQZ',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/WqeS9UKlQZ',
#         'expanded_url': 'https://instagram.com/beingaman.ig?igshid=1vrztlmjbzsqi',
#         'display_url': 'instagram.com/beingaman.ig?i…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 16641,
#     'friends_count': 140,
#     'listed_count': 11,
#     'created_at': 'Fri Oct 10 06:53:48 +0000 2014',
#     'favourites_count': 8462,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 29725,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1254996853071835136/6KPfiiEr_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1254996853071835136/6KPfiiEr_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2849859583/1587956684',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 543,
#    'favorite_count': 162,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 543,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 20 07:00:13 +0000 2020',
#   'id': 1340552568137789440,
#   'id_str': '1340552568137789440',
#   'text': 'RT @OneIndianGirl__: Emotional attachment\n#SidNaazKiPyaariDuniya',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#      'indices': [42, 64]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'OneIndianGirl__',
#      'name': 'Nishi🦋 🎅',
#      'id': 1295441687037149184,
#      'id_str': '1295441687037149184',
#      'indices': [3, 19]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1337403276782800896,
#    'id_str': '1337403276782800896',
#    'name': 'Sidnazshivani',
#    'screen_name': 'sidnazshivani',
#    'location': '',
#    'description': '#bhuladunga,#shonashona,#dilkokararaaya,#waadahai',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 10,
#    'friends_count': 13,
#    'listed_count': 0,
#    'created_at': 'Fri Dec 11 14:26:12 +0000 2020',
#    'favourites_count': 40,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1926,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1337403394315571200/OG56Uav2_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1337403394315571200/OG56Uav2_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1337403276782800896/1607705127',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 06:56:21 +0000 2020',
#    'id': 1340551596741017603,
#    'id_str': '1340551596741017603',
#    'text': 'Emotional attachment\n#SidNaazKiPyaariDuniya',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'SidNaazKiPyaariDuniya',
#       'indices': [21, 43]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1295441687037149184,
#     'id_str': '1295441687037149184',
#     'name': 'Nishi🦋 🎅',
#     'screen_name': 'OneIndianGirl__',
#     'location': 'Bengaluru, India',
#     'description': 'Rain Tea Book and Window side - Perfect life❤️',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 106,
#     'friends_count': 154,
#     'listed_count': 0,
#     'created_at': 'Mon Aug 17 19:25:58 +0000 2020',
#     'favourites_count': 9045,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 9809,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1340171075217321984/OekJmY7A_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1340171075217321984/OekJmY7A_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1295441687037149184/1607326725',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'}]

# %%
## get 100000 tweets

tweets = []

old_len = 0

while len(tweets) < 1000:
    if len(tweets) == 0:
        tweets = api.search(q=top_trending_hashtag, count=100)
    else:
        lowest_tweet_id = tweets[len(tweets)-100]._json['id']
        for tweet in tweets:
            tweet_id = tweet._json['id']
            if tweet_id < lowest_tweet_id:
                lowest_tweet_id = tweet_id
        lowest_tweet_id -= 1
        tweets += api.search(q=top_trending_hashtag, count=100, max_id=lowest_tweet_id)
    print(len(tweets))
    if len(tweets) == old_len:
        break
    old_len = len(tweets)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000

# %%
# low_id

# %%
tweets[0].author
# Out:
# User(_api=<tweepy.api.API object at 0x7f71c482ccd0>, _json={'id': 1317801760052817920, 'id_str': '1317801760052817920', 'name': 'Kaur Param❤', 'screen_name': 'KaurParam5', 'location': '', 'description': '#SidNaaz  is love❤', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 176, 'friends_count': 217, 'listed_count': 0, 'created_at': 'Sun Oct 18 12:16:52 +0000 2020', 'favourites_count': 307, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1078, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1337425429037137923/IMsFEuCu_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1337425429037137923/IMsFEuCu_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1317801760052817920/1607702047', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, id=1317801760052817920, id_str='1317801760052817920', name='Kaur Param❤', screen_name='KaurParam5', location='', description='#SidNaaz  is love❤', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=176, friends_count=217, listed_count=0, created_at=datetime.datetime(2020, 10, 18, 12, 16, 52), favourites_count=307, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=1078, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='F5F8FA', profile_background_image_url=None, profile_background_image_url_https=None, profile_background_tile=False, profile_image_url='http://pbs.twimg.com/profile_images/1337425429037137923/IMsFEuCu_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1337425429037137923/IMsFEuCu_normal.jpg', profile_banner_url='https://pbs.twimg.com/profile_banners/1317801760052817920/1607702047', profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, has_extended_profile=True, default_profile=True, default_profile_image=False, following=False, follow_request_sent=False, notifications=False, translator_type='none')

# %%
# api.help()

# %%
#fetch languages

# url = "https://api.twitter.com/1.1/help/languages.json"
# languages = requests.get(url, auth=auth).json()

languages = {
    "ab": {
        "name": "Abkhaz",
            "nativeName": "аҧсуа"
    },
        "aa": {
        "name": "Afar",
            "nativeName": "Afaraf"
    },
        "af": {
        "name": "Afrikaans",
            "nativeName": "Afrikaans"
    },
        "ak": {
        "name": "Akan",
            "nativeName": "Akan"
    },
        "sq": {
        "name": "Albanian",
            "nativeName": "Shqip"
    },
        "am": {
        "name": "Amharic",
            "nativeName": "አማርኛ"
    },
        "ar": {
        "name": "Arabic",
            "nativeName": "العربية"
    },
        "an": {
        "name": "Aragonese",
            "nativeName": "Aragonés"
    },
        "hy": {
        "name": "Armenian",
            "nativeName": "Հայերեն"
    },
        "as": {
        "name": "Assamese",
            "nativeName": "অসমীয়া"
    },
        "av": {
        "name": "Avaric",
            "nativeName": "авар мацӀ, магӀарул мацӀ"
    },
        "ae": {
        "name": "Avestan",
            "nativeName": "avesta"
    },
        "ay": {
        "name": "Aymara",
            "nativeName": "aymar aru"
    },
        "az": {
        "name": "Azerbaijani",
            "nativeName": "azərbaycan dili"
    },
        "bm": {
        "name": "Bambara",
            "nativeName": "bamanankan"
    },
        "ba": {
        "name": "Bashkir",
            "nativeName": "башҡорт теле"
    },
        "eu": {
        "name": "Basque",
            "nativeName": "euskara, euskera"
    },
        "be": {
        "name": "Belarusian",
            "nativeName": "Беларуская"
    },
        "bn": {
        "name": "Bengali",
            "nativeName": "বাংলা"
    },
        "bh": {
        "name": "Bihari",
            "nativeName": "भोजपुरी"
    },
        "bi": {
        "name": "Bislama",
            "nativeName": "Bislama"
    },
        "bs": {
        "name": "Bosnian",
            "nativeName": "bosanski jezik"
    },
        "br": {
        "name": "Breton",
            "nativeName": "brezhoneg"
    },
        "bg": {
        "name": "Bulgarian",
            "nativeName": "български език"
    },
        "my": {
        "name": "Burmese",
            "nativeName": "ဗမာစာ"
    },
        "ca": {
        "name": "Catalan; Valencian",
            "nativeName": "Català"
    },
        "ch": {
        "name": "Chamorro",
            "nativeName": "Chamoru"
    },
        "ce": {
        "name": "Chechen",
            "nativeName": "нохчийн мотт"
    },
        "ny": {
        "name": "Chichewa; Chewa; Nyanja",
            "nativeName": "chiCheŵa, chinyanja"
    },
        "zh": {
        "name": "Chinese",
            "nativeName": "中文 (Zhōngwén), 汉语, 漢語"
    },
        "cv": {
        "name": "Chuvash",
            "nativeName": "чӑваш чӗлхи"
    },
        "kw": {
        "name": "Cornish",
            "nativeName": "Kernewek"
    },
        "co": {
        "name": "Corsican",
            "nativeName": "corsu, lingua corsa"
    },
        "cr": {
        "name": "Cree",
            "nativeName": "ᓀᐦᐃᔭᐍᐏᐣ"
    },
        "hr": {
        "name": "Croatian",
            "nativeName": "hrvatski"
    },
        "cs": {
        "name": "Czech",
            "nativeName": "česky, čeština"
    },
        "da": {
        "name": "Danish",
            "nativeName": "dansk"
    },
        "dv": {
        "name": "Divehi; Dhivehi; Maldivian;",
            "nativeName": "ދިވެހި"
    },
        "nl": {
        "name": "Dutch",
            "nativeName": "Nederlands, Vlaams"
    },
        "en": {
        "name": "English",
            "nativeName": "English"
    },
        "eo": {
        "name": "Esperanto",
            "nativeName": "Esperanto"
    },
        "et": {
        "name": "Estonian",
            "nativeName": "eesti, eesti keel"
    },
        "ee": {
        "name": "Ewe",
            "nativeName": "Eʋegbe"
    },
        "fo": {
        "name": "Faroese",
            "nativeName": "føroyskt"
    },
        "fj": {
        "name": "Fijian",
            "nativeName": "vosa Vakaviti"
    },
        "fi": {
        "name": "Finnish",
            "nativeName": "suomi, suomen kieli"
    },
        "fr": {
        "name": "French",
            "nativeName": "français, langue française"
    },
        "ff": {
        "name": "Fula; Fulah; Pulaar; Pular",
            "nativeName": "Fulfulde, Pulaar, Pular"
    },
        "gl": {
        "name": "Galician",
            "nativeName": "Galego"
    },
        "ka": {
        "name": "Georgian",
            "nativeName": "ქართული"
    },
        "de": {
        "name": "German",
            "nativeName": "Deutsch"
    },
        "el": {
        "name": "Greek, Modern",
            "nativeName": "Ελληνικά"
    },
        "gn": {
        "name": "Guaraní",
            "nativeName": "Avañeẽ"
    },
        "gu": {
        "name": "Gujarati",
            "nativeName": "ગુજરાતી"
    },
        "ht": {
        "name": "Haitian; Haitian Creole",
            "nativeName": "Kreyòl ayisyen"
    },
        "ha": {
        "name": "Hausa",
            "nativeName": "Hausa, هَوُسَ"
    },
        "he": {
        "name": "Hebrew (modern)",
            "nativeName": "עברית"
    },
        "hz": {
        "name": "Herero",
            "nativeName": "Otjiherero"
    },
        "hi": {
        "name": "Hindi",
            "nativeName": "हिन्दी, हिंदी"
    },
        "ho": {
        "name": "Hiri Motu",
            "nativeName": "Hiri Motu"
    },
        "hu": {
        "name": "Hungarian",
            "nativeName": "Magyar"
    },
        "ia": {
        "name": "Interlingua",
            "nativeName": "Interlingua"
    },
        "id": {
        "name": "Indonesian",
            "nativeName": "Bahasa Indonesia"
    },
        "ie": {
        "name": "Interlingue",
            "nativeName": "Originally called Occidental; then Interlingue after WWII"
    },
        "ga": {
        "name": "Irish",
            "nativeName": "Gaeilge"
    },
        "ig": {
        "name": "Igbo",
            "nativeName": "Asụsụ Igbo"
    },
        "ik": {
        "name": "Inupiaq",
            "nativeName": "Iñupiaq, Iñupiatun"
    },
        "io": {
        "name": "Ido",
            "nativeName": "Ido"
    },
        "is": {
        "name": "Icelandic",
            "nativeName": "Íslenska"
    },
        "it": {
        "name": "Italian",
            "nativeName": "Italiano"
    },
        "iu": {
        "name": "Inuktitut",
            "nativeName": "ᐃᓄᒃᑎᑐᑦ"
    },
        "ja": {
        "name": "Japanese",
            "nativeName": "日本語 (にほんご／にっぽんご)"
    },
        "jv": {
        "name": "Javanese",
            "nativeName": "basa Jawa"
    },
        "kl": {
        "name": "Kalaallisut, Greenlandic",
            "nativeName": "kalaallisut, kalaallit oqaasii"
    },
        "kn": {
        "name": "Kannada",
            "nativeName": "ಕನ್ನಡ"
    },
        "kr": {
        "name": "Kanuri",
            "nativeName": "Kanuri"
    },
        "ks": {
        "name": "Kashmiri",
            "nativeName": "कश्मीरी, كشميري‎"
    },
        "kk": {
        "name": "Kazakh",
            "nativeName": "Қазақ тілі"
    },
        "km": {
        "name": "Khmer",
            "nativeName": "ភាសាខ្មែរ"
    },
        "ki": {
        "name": "Kikuyu, Gikuyu",
            "nativeName": "Gĩkũyũ"
    },
        "rw": {
        "name": "Kinyarwanda",
            "nativeName": "Ikinyarwanda"
    },
        "ky": {
        "name": "Kirghiz, Kyrgyz",
            "nativeName": "кыргыз тили"
    },
        "kv": {
        "name": "Komi",
            "nativeName": "коми кыв"
    },
        "kg": {
        "name": "Kongo",
            "nativeName": "KiKongo"
    },
        "ko": {
        "name": "Korean",
            "nativeName": "한국어 (韓國語), 조선말 (朝鮮語)"
    },
        "ku": {
        "name": "Kurdish",
            "nativeName": "Kurdî, كوردی‎"
    },
        "kj": {
        "name": "Kwanyama, Kuanyama",
            "nativeName": "Kuanyama"
    },
        "la": {
        "name": "Latin",
            "nativeName": "latine, lingua latina"
    },
        "lb": {
        "name": "Luxembourgish, Letzeburgesch",
            "nativeName": "Lëtzebuergesch"
    },
        "lg": {
        "name": "Luganda",
            "nativeName": "Luganda"
    },
        "li": {
        "name": "Limburgish, Limburgan, Limburger",
            "nativeName": "Limburgs"
    },
        "ln": {
        "name": "Lingala",
            "nativeName": "Lingála"
    },
        "lo": {
        "name": "Lao",
            "nativeName": "ພາສາລາວ"
    },
        "lt": {
        "name": "Lithuanian",
            "nativeName": "lietuvių kalba"
    },
        "lu": {
        "name": "Luba-Katanga",
            "nativeName": ""
    },
        "lv": {
        "name": "Latvian",
            "nativeName": "latviešu valoda"
    },
        "gv": {
        "name": "Manx",
            "nativeName": "Gaelg, Gailck"
    },
        "mk": {
        "name": "Macedonian",
            "nativeName": "македонски јазик"
    },
        "mg": {
        "name": "Malagasy",
            "nativeName": "Malagasy fiteny"
    },
        "ms": {
        "name": "Malay",
            "nativeName": "bahasa Melayu, بهاس ملايو‎"
    },
        "ml": {
        "name": "Malayalam",
            "nativeName": "മലയാളം"
    },
        "mt": {
        "name": "Maltese",
            "nativeName": "Malti"
    },
        "mi": {
        "name": "Māori",
            "nativeName": "te reo Māori"
    },
        "mr": {
        "name": "Marathi (Marāṭhī)",
            "nativeName": "मराठी"
    },
        "mh": {
        "name": "Marshallese",
            "nativeName": "Kajin M̧ajeļ"
    },
        "mn": {
        "name": "Mongolian",
            "nativeName": "монгол"
    },
        "na": {
        "name": "Nauru",
            "nativeName": "Ekakairũ Naoero"
    },
        "nv": {
        "name": "Navajo, Navaho",
            "nativeName": "Diné bizaad, Dinékʼehǰí"
    },
        "nb": {
        "name": "Norwegian Bokmål",
            "nativeName": "Norsk bokmål"
    },
        "nd": {
        "name": "North Ndebele",
            "nativeName": "isiNdebele"
    },
        "ne": {
        "name": "Nepali",
            "nativeName": "नेपाली"
    },
        "ng": {
        "name": "Ndonga",
            "nativeName": "Owambo"
    },
        "nn": {
        "name": "Norwegian Nynorsk",
            "nativeName": "Norsk nynorsk"
    },
        "no": {
        "name": "Norwegian",
            "nativeName": "Norsk"
    },
        "ii": {
        "name": "Nuosu",
            "nativeName": "ꆈꌠ꒿ Nuosuhxop"
    },
        "nr": {
        "name": "South Ndebele",
            "nativeName": "isiNdebele"
    },
        "oc": {
        "name": "Occitan",
            "nativeName": "Occitan"
    },
        "oj": {
        "name": "Ojibwe, Ojibwa",
            "nativeName": "ᐊᓂᔑᓈᐯᒧᐎᓐ"
    },
        "cu": {
        "name": "Old Church Slavonic, Church Slavic, Church Slavonic, Old Bulgarian, Old Slavonic",
            "nativeName": "ѩзыкъ словѣньскъ"
    },
        "om": {
        "name": "Oromo",
            "nativeName": "Afaan Oromoo"
    },
        "or": {
        "name": "Oriya",
            "nativeName": "ଓଡ଼ିଆ"
    },
        "os": {
        "name": "Ossetian, Ossetic",
            "nativeName": "ирон æвзаг"
    },
        "pa": {
        "name": "Panjabi, Punjabi",
            "nativeName": "ਪੰਜਾਬੀ, پنجابی‎"
    },
        "pi": {
        "name": "Pāli",
            "nativeName": "पाऴि"
    },
        "fa": {
        "name": "Persian",
            "nativeName": "فارسی"
    },
        "pl": {
        "name": "Polish",
            "nativeName": "polski"
    },
        "ps": {
        "name": "Pashto, Pushto",
            "nativeName": "پښتو"
    },
        "pt": {
        "name": "Portuguese",
            "nativeName": "Português"
    },
        "qu": {
        "name": "Quechua",
            "nativeName": "Runa Simi, Kichwa"
    },
        "rm": {
        "name": "Romansh",
            "nativeName": "rumantsch grischun"
    },
        "rn": {
        "name": "Kirundi",
            "nativeName": "kiRundi"
    },
        "ro": {
        "name": "Romanian, Moldavian, Moldovan",
            "nativeName": "română"
    },
        "ru": {
        "name": "Russian",
            "nativeName": "русский язык"
    },
        "sa": {
        "name": "Sanskrit (Saṁskṛta)",
            "nativeName": "संस्कृतम्"
    },
        "sc": {
        "name": "Sardinian",
            "nativeName": "sardu"
    },
        "sd": {
        "name": "Sindhi",
            "nativeName": "सिन्धी, سنڌي، سندھی‎"
    },
        "se": {
        "name": "Northern Sami",
            "nativeName": "Davvisámegiella"
    },
        "sm": {
        "name": "Samoan",
            "nativeName": "gagana faa Samoa"
    },
        "sg": {
        "name": "Sango",
            "nativeName": "yângâ tî sängö"
    },
        "sr": {
        "name": "Serbian",
            "nativeName": "српски језик"
    },
        "gd": {
        "name": "Scottish Gaelic; Gaelic",
            "nativeName": "Gàidhlig"
    },
        "sn": {
        "name": "Shona",
            "nativeName": "chiShona"
    },
        "si": {
        "name": "Sinhala, Sinhalese",
            "nativeName": "සිංහල"
    },
        "sk": {
        "name": "Slovak",
            "nativeName": "slovenčina"
    },
        "sl": {
        "name": "Slovene",
            "nativeName": "slovenščina"
    },
        "so": {
        "name": "Somali",
            "nativeName": "Soomaaliga, af Soomaali"
    },
        "st": {
        "name": "Southern Sotho",
            "nativeName": "Sesotho"
    },
        "es": {
        "name": "Spanish; Castilian",
            "nativeName": "español, castellano"
    },
        "su": {
        "name": "Sundanese",
            "nativeName": "Basa Sunda"
    },
        "sw": {
        "name": "Swahili",
            "nativeName": "Kiswahili"
    },
        "ss": {
        "name": "Swati",
            "nativeName": "SiSwati"
    },
        "sv": {
        "name": "Swedish",
            "nativeName": "svenska"
    },
        "ta": {
        "name": "Tamil",
            "nativeName": "தமிழ்"
    },
        "te": {
        "name": "Telugu",
            "nativeName": "తెలుగు"
    },
        "tg": {
        "name": "Tajik",
            "nativeName": "тоҷикӣ, toğikī, تاجیکی‎"
    },
        "th": {
        "name": "Thai",
            "nativeName": "ไทย"
    },
        "ti": {
        "name": "Tigrinya",
            "nativeName": "ትግርኛ"
    },
        "bo": {
        "name": "Tibetan Standard, Tibetan, Central",
            "nativeName": "བོད་ཡིག"
    },
        "tk": {
        "name": "Turkmen",
            "nativeName": "Türkmen, Түркмен"
    },
        "tl": {
        "name": "Tagalog",
            "nativeName": "Wikang Tagalog, ᜏᜒᜃᜅ᜔ ᜆᜄᜎᜓᜄ᜔"
    },
        "tn": {
        "name": "Tswana",
            "nativeName": "Setswana"
    },
        "to": {
        "name": "Tonga (Tonga Islands)",
            "nativeName": "faka Tonga"
    },
        "tr": {
        "name": "Turkish",
            "nativeName": "Türkçe"
    },
        "ts": {
        "name": "Tsonga",
            "nativeName": "Xitsonga"
    },
        "tt": {
        "name": "Tatar",
            "nativeName": "татарча, tatarça, تاتارچا‎"
    },
        "tw": {
        "name": "Twi",
            "nativeName": "Twi"
    },
        "ty": {
        "name": "Tahitian",
            "nativeName": "Reo Tahiti"
    },
        "ug": {
        "name": "Uighur, Uyghur",
            "nativeName": "Uyƣurqə, ئۇيغۇرچە‎"
    },
        "uk": {
        "name": "Ukrainian",
            "nativeName": "українська"
    },
        "ur": {
        "name": "Urdu",
            "nativeName": "اردو"
    },
        "uz": {
        "name": "Uzbek",
            "nativeName": "zbek, Ўзбек, أۇزبېك‎"
    },
        "ve": {
        "name": "Venda",
            "nativeName": "Tshivenḓa"
    },
        "vi": {
        "name": "Vietnamese",
            "nativeName": "Tiếng Việt"
    },
        "vo": {
        "name": "Volapük",
            "nativeName": "Volapük"
    },
        "wa": {
        "name": "Walloon",
            "nativeName": "Walon"
    },
        "cy": {
        "name": "Welsh",
            "nativeName": "Cymraeg"
    },
        "wo": {
        "name": "Wolof",
            "nativeName": "Wollof"
    },
        "fy": {
        "name": "Western Frisian",
            "nativeName": "Frysk"
    },
        "xh": {
        "name": "Xhosa",
            "nativeName": "isiXhosa"
    },
        "yi": {
        "name": "Yiddish",
            "nativeName": "ייִדיש"
    },
        "yo": {
        "name": "Yoruba",
            "nativeName": "Yorùbá"
    },
        "za": {
        "name": "Zhuang, Chuang",
            "nativeName": "Saɯ cueŋƅ, Saw cuengh"
    },
}

def get_lang_text(code):
    if code in languages.keys():
        return languages[code]["name"]
    return "Unknown"
# search_resp = requests.get(, head)
# search_resp

# %%
# for language aspect

lang_cnt={}

for tweet in tweets:
    lang=get_lang_text(tweet.lang)
    if lang not in lang_cnt:
        lang_cnt[lang] = 0
    lang_cnt[lang]+=1

# %%
print(lang_cnt)
# for code in lang_cnt.keys():
#     print(get_lang_text(code))

language_code = []
language_freq = []

most_used_lang = []
max_lang_freq = 0

for code in lang_cnt.keys():
    language_code.append(code)
    language_freq.append(lang_cnt[code])
    
    if lang_cnt[code] == max_lang_freq:
        most_used_lang.append(code)
    elif lang_cnt[code] > max_lang_freq:
        most_used_lang = []
        most_used_lang.append(code)
        max_lang_freq = lang_cnt[code]

plt.figure(figsize=(20, 10))
plt.bar(language_code, language_freq)
plt.xlabel('Languages')
plt.ylabel('Tweet Count')
plt.show()



print('{} {} among the tweets.'.format(', '.join(str(e) for e in most_used_lang), 'is the most used language' if len(most_used_lang)==1 else 'are the most used languages'))
# Out:
# {'English': 847, 'Hindi': 73, 'Tagalog': 14, 'Estonian': 22, 'Unknown': 37, 'Swedish': 2, 'Catalan; Valencian': 1, 'French': 1, 'Haitian; Haitian Creole': 1, 'Portuguese': 1, 'Basque': 1}
# English is the most used language among the tweets.

# %%
# users

user_verification={"Verified": 0, "Non-Verified": 0}
users={}

for tweet in tweets:
    author=tweet.author
    if author._json['screen_name'] not in users.keys():   
        if author.verified == True:
            user_verification["Verified"]+=1
        else:
            user_verification["Non-Verified"]+=1
    users[author._json['screen_name']] = {'statuses_count':author._json['statuses_count'], 'followers_count':author._json['followers_count'], 'friends_count':author._json['friends_count']}

#     print(author._json['statuses_count'])
#     print(author._json['followers_count'])
#     print(author._json['friends_count'])
#     print(author._json['followers_count'])
        
# plt.figure(figsize=(20, 10))
# plt.bar(list(user_verification.keys()), list(user_verification.values()))


plt.figure(figsize =(10, 10)) 
plt.pie(list(user_verification.values()), labels = list(user_verification.keys()), autopct='%1.1f%%',shadow=True, startangle=90)
plt.legend(loc="upper right")
plt.title("Tweets from Verified vs Non-Verified Users")
plt.show()

# plt.xlabel('Users')
# plt.ylabel('Frequency')
# plt.show()

print("{}% of users who posted this hashtag are verified".format(100*(user_verification["Verified"]/(user_verification["Verified"]+user_verification["Non-Verified"]))))
# Out:
# 0.0% of users who posted this hashtag are verified

# %%
# verified vs non verified
# location
# most followed users
# newly joined

#tweet histogram with time
#location of followers
#followed by verified users
#% of followers with < 50% tweets from user

# %%
def get_user_info(id):
    user = api.get_user(screen_name=id)
    user_txt = "{} (@{})".format(user._json['name'], user._json['screen_name'])
    return user_txt

# %%
# for max tweets
status = dict(sorted(users.items(), key=lambda item: item[1]['statuses_count'], reverse=True))
status_cnt = [x['statuses_count'] for x in status.values()]
status = list(status.keys())

fig = plt.figure(figsize =(20, 10))
plt.bar(status[:50], status_cnt[:50])
plt.xticks(rotation=90)
plt.title('Top 50 active users')
plt.xlabel('User Ids')
plt.ylabel('Tweet count')
plt.show()


print("{}, {}, and {} are the most active users among all the users available.".format(get_user_info(status[0]), get_user_info(status[1]), get_user_info(status[2])))
# Out:
# 𝑹𝒖𝒕𝒖𝒋𝒂🦋 (@rutuja_13), Peace matters💘 (@Anu93480876), and Bikash #ShonaShona (@Bikuengr) are the most active users among all the users available.

# %%
# max followers_count
labels = dict(sorted(users.items(), key=lambda item: item[1]['followers_count'], reverse=True))
follower_cnt = [x['followers_count'] for x in labels.values()]
labels = list(labels.keys())

fig = plt.figure(figsize =(20, 10))
plt.bar(labels[:50], follower_cnt[:50])
plt.xticks(rotation=90)
plt.title('Top 50 most followed users')
plt.xlabel('User Ids')
plt.ylabel('Follower count')
plt.show()


print("{}, {}, and {} are the top 3 most followed users among all the users available.".format(get_user_info(labels[0]), get_user_info(labels[1]), get_user_info(labels[2])))
# Out:
# PG (@PG_Edits_), 𝑹𝒖𝒕𝒖𝒋𝒂🦋 (@rutuja_13), and 🅲🆈🅽 (@DilDiyaGallan) are the top 3 most followed users among all the users available.

# %%
# max friends_cnt
labels = dict(sorted(users.items(), key=lambda item: item[1]['friends_count'], reverse=True))
follower_cnt = [x['friends_count'] for x in labels.values()]
labels = list(labels.keys())

fig = plt.figure(figsize =(20, 10))
plt.bar(labels[:50], follower_cnt[:50])
plt.xticks(rotation=90)
plt.title('Top 50 users with maximum number of friends')
plt.xlabel('User Ids')
plt.ylabel('Friends count')
plt.show()


print("{}, {}, and {} are the top 3 users with maximum number of friends among all the users available.".format(get_user_info(labels[0]), get_user_info(labels[1]), get_user_info(labels[2])))
# Out:
# Akshay {Sidnaazians} shona shona (@AkshayK38905919), Ayaat #SidNaazKiPyaariDuniya (@ayaat_sidnaaz), and Shaikh Anas (@SHAIKHANAS0786) are the top 3 users with maximum number of friends among all the users available.
