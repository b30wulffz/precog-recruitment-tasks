# %%
# API key: 3CPSX6vE31S6wiyUFpc45wqd6
# API Secret Key: mbuRYtNTaFLYC5IRrW2Dz6mj5fXlkv0SgIk5OCSLqLYHQMXR0O
# Access Token: 391364404-IiRlLVX4KO1OiTFbtpMEWjzNoV07AJI7YPd8z1kD
# Access Token Secret: qvmLo4zi3tcQWJIYZQkrB2P0iwcuzHLaLmTBpo98HYmNg
# Bearer Token: AAAAAAAAAAAAAAAAAAAAANb5KgEAAAAA4ekthlHPKw6igRtOWh7JwrT7v4Q%3Dsl2xPlwhys2Lkd26GlhymYSzRVYeLL7a0DowLnLxXRuus15lYw

# %%
consumer_key = "3CPSX6vE31S6wiyUFpc45wqd6"
consumer_key_secret = "mbuRYtNTaFLYC5IRrW2Dz6mj5fXlkv0SgIk5OCSLqLYHQMXR0O"
access_token = "391364404-IiRlLVX4KO1OiTFbtpMEWjzNoV07AJI7YPd8z1kD"
access_token_secret = "qvmLo4zi3tcQWJIYZQkrB2P0iwcuzHLaLmTBpo98HYmNg"
bearer_token = "AAAAAAAAAAAAAAAAAAAAANb5KgEAAAAA4ekthlHPKw6igRtOWh7JwrT7v4Q%3Dsl2xPlwhys2Lkd26GlhymYSzRVYeLL7a0DowLnLxXRuus15lYw"

# %%
# authentication for URL based api

import requests
from requests_oauthlib import OAuth1

auth = OAuth1(consumer_key, consumer_key_secret, access_token, access_token_secret)

# %%
import tweepy
import matplotlib.pyplot as plt
import pytz

auth = tweepy.OAuthHandler("3CPSX6vE31S6wiyUFpc45wqd6", "mbuRYtNTaFLYC5IRrW2Dz6mj5fXlkv0SgIk5OCSLqLYHQMXR0O")
auth.set_access_token("391364404-IiRlLVX4KO1OiTFbtpMEWjzNoV07AJI7YPd8z1kD", "qvmLo4zi3tcQWJIYZQkrB2P0iwcuzHLaLmTBpo98HYmNg")

api = tweepy.API(auth)

# %%
trends_raw = api.trends_place(id=20070458)
trends_raw
# Out:
# [{'trends': [{'name': '#WestBengal',
#     'url': 'http://twitter.com/search?q=%23WestBengal',
#     'promoted_content': None,
#     'query': '%23WestBengal',
#     'tweet_volume': None},
#    {'name': '#SidNaazKiPyaariDuniya',
#     'url': 'http://twitter.com/search?q=%23SidNaazKiPyaariDuniya',
#     'promoted_content': None,
#     'query': '%23SidNaazKiPyaariDuniya',
#     'tweet_volume': 720942},
#    {'name': 'Queen Shehnaaz',
#     'url': 'http://twitter.com/search?q=%22Queen+Shehnaaz%22',
#     'promoted_content': None,
#     'query': '%22Queen+Shehnaaz%22',
#     'tweet_volume': 44915},
#    {'name': '#BengalWithBJP',
#     'url': 'http://twitter.com/search?q=%23BengalWithBJP',
#     'promoted_content': None,
#     'query': '%23BengalWithBJP',
#     'tweet_volume': 375672},
#    {'name': '#IndiaUnsafeUnderBJP',
#     'url': 'http://twitter.com/search?q=%23IndiaUnsafeUnderBJP',
#     'promoted_content': None,
#     'query': '%23IndiaUnsafeUnderBJP',
#     'tweet_volume': 38488},
#    {'name': 'Nawazuddin Wins Filmfare',
#     'url': 'http://twitter.com/search?q=%22Nawazuddin+Wins+Filmfare%22',
#     'promoted_content': None,
#     'query': '%22Nawazuddin+Wins+Filmfare%22',
#     'tweet_volume': None},
#    {'name': '#IndiaRoars4SSR',
#     'url': 'http://twitter.com/search?q=%23IndiaRoars4SSR',
#     'promoted_content': None,
#     'query': '%23IndiaRoars4SSR',
#     'tweet_volume': 268702},
#    {'name': 'Bolpur',
#     'url': 'http://twitter.com/search?q=Bolpur',
#     'promoted_content': None,
#     'query': 'Bolpur',
#     'tweet_volume': 40620},
#    {'name': '78th Golden Globe Awards',
#     'url': 'http://twitter.com/search?q=%2278th+Golden+Globe+Awards%22',
#     'promoted_content': None,
#     'query': '%2278th+Golden+Globe+Awards%22',
#     'tweet_volume': None},
#    {'name': 'WE STAND BY YOU LISA',
#     'url': 'http://twitter.com/search?q=%22WE+STAND+BY+YOU+LISA%22',
#     'promoted_content': None,
#     'query': '%22WE+STAND+BY+YOU+LISA%22',
#     'tweet_volume': 241773},
#    {'name': 'Gurudwara',
#     'url': 'http://twitter.com/search?q=Gurudwara',
#     'promoted_content': None,
#     'query': 'Gurudwara',
#     'tweet_volume': 36817},
#    {'name': '6 years of amaal mallik',
#     'url': 'http://twitter.com/search?q=%226+years+of+amaal+mallik%22',
#     'promoted_content': None,
#     'query': '%226+years+of+amaal+mallik%22',
#     'tweet_volume': None},
#    {'name': 'Elon',
#     'url': 'http://twitter.com/search?q=Elon',
#     'promoted_content': None,
#     'query': 'Elon',
#     'tweet_volume': 20325},
#    {'name': 'Sonar Bangla',
#     'url': 'http://twitter.com/search?q=%22Sonar+Bangla%22',
#     'promoted_content': None,
#     'query': '%22Sonar+Bangla%22',
#     'tweet_volume': 36911},
#    {'name': 'Hafeez',
#     'url': 'http://twitter.com/search?q=Hafeez',
#     'promoted_content': None,
#     'query': 'Hafeez',
#     'tweet_volume': 11967},
#    {'name': 'ankita',
#     'url': 'http://twitter.com/search?q=ankita',
#     'promoted_content': None,
#     'query': 'ankita',
#     'tweet_volume': 25467},
#    {'name': 'Sant Rampal Ji Maharaj',
#     'url': 'http://twitter.com/search?q=%22Sant+Rampal+Ji+Maharaj%22',
#     'promoted_content': None,
#     'query': '%22Sant+Rampal+Ji+Maharaj%22',
#     'tweet_volume': 94647},
#    {'name': 'Sandeep Singh',
#     'url': 'http://twitter.com/search?q=%22Sandeep+Singh%22',
#     'promoted_content': None,
#     'query': '%22Sandeep+Singh%22',
#     'tweet_volume': None},
#    {'name': 'सिंह रावत',
#     'url': 'http://twitter.com/search?q=%22%E0%A4%B8%E0%A4%BF%E0%A4%82%E0%A4%B9+%E0%A4%B0%E0%A4%BE%E0%A4%B5%E0%A4%A4%22',
#     'promoted_content': None,
#     'query': '%22%E0%A4%B8%E0%A4%BF%E0%A4%82%E0%A4%B9+%E0%A4%B0%E0%A4%BE%E0%A4%B5%E0%A4%A4%22',
#     'tweet_volume': None},
#    {'name': 'Shri',
#     'url': 'http://twitter.com/search?q=Shri',
#     'promoted_content': None,
#     'query': 'Shri',
#     'tweet_volume': 279373},
#    {'name': 'Aurangzeb',
#     'url': 'http://twitter.com/search?q=Aurangzeb',
#     'promoted_content': None,
#     'query': 'Aurangzeb',
#     'tweet_volume': None},
#    {'name': 'मुख्यमंत्री श्री',
#     'url': 'http://twitter.com/search?q=%22%E0%A4%AE%E0%A5%81%E0%A4%96%E0%A5%8D%E0%A4%AF%E0%A4%AE%E0%A4%82%E0%A4%A4%E0%A5%8D%E0%A4%B0%E0%A5%80+%E0%A4%B6%E0%A5%8D%E0%A4%B0%E0%A5%80%22',
#     'promoted_content': None,
#     'query': '%22%E0%A4%AE%E0%A5%81%E0%A4%96%E0%A5%8D%E0%A4%AF%E0%A4%AE%E0%A4%82%E0%A4%A4%E0%A5%8D%E0%A4%B0%E0%A5%80+%E0%A4%B6%E0%A5%8D%E0%A4%B0%E0%A5%80%22',
#     'tweet_volume': 15667},
#    {'name': 'दहेज मुक्त',
#     'url': 'http://twitter.com/search?q=%22%E0%A4%A6%E0%A4%B9%E0%A5%87%E0%A4%9C+%E0%A4%AE%E0%A5%81%E0%A4%95%E0%A5%8D%E0%A4%A4%22',
#     'promoted_content': None,
#     'query': '%22%E0%A4%A6%E0%A4%B9%E0%A5%87%E0%A4%9C+%E0%A4%AE%E0%A5%81%E0%A4%95%E0%A5%8D%E0%A4%A4%22',
#     'tweet_volume': 96924},
#    {'name': '#StandWithPopularFront',
#     'url': 'http://twitter.com/search?q=%23StandWithPopularFront',
#     'promoted_content': None,
#     'query': '%23StandWithPopularFront',
#     'tweet_volume': 59849},
#    {'name': '#ThankYouSottaVijay',
#     'url': 'http://twitter.com/search?q=%23ThankYouSottaVijay',
#     'promoted_content': None,
#     'query': '%23ThankYouSottaVijay',
#     'tweet_volume': 84222},
#    {'name': '#sundayvibes',
#     'url': 'http://twitter.com/search?q=%23sundayvibes',
#     'promoted_content': None,
#     'query': '%23sundayvibes',
#     'tweet_volume': None},
#    {'name': '#FarmActsAreUnconstitutional',
#     'url': 'http://twitter.com/search?q=%23FarmActsAreUnconstitutional',
#     'promoted_content': None,
#     'query': '%23FarmActsAreUnconstitutional',
#     'tweet_volume': 108605},
#    {'name': '#WeRejectADMK',
#     'url': 'http://twitter.com/search?q=%23WeRejectADMK',
#     'promoted_content': None,
#     'query': '%23WeRejectADMK',
#     'tweet_volume': 165044},
#    {'name': '#ThankYouPottaAJITH',
#     'url': 'http://twitter.com/search?q=%23ThankYouPottaAJITH',
#     'promoted_content': None,
#     'query': '%23ThankYouPottaAJITH',
#     'tweet_volume': 57449},
#    {'name': '#2साल_कांग्रेस_बना_काल',
#     'url': 'http://twitter.com/search?q=%232%E0%A4%B8%E0%A4%BE%E0%A4%B2_%E0%A4%95%E0%A4%BE%E0%A4%82%E0%A4%97%E0%A5%8D%E0%A4%B0%E0%A5%87%E0%A4%B8_%E0%A4%AC%E0%A4%A8%E0%A4%BE_%E0%A4%95%E0%A4%BE%E0%A4%B2',
#     'promoted_content': None,
#     'query': '%232%E0%A4%B8%E0%A4%BE%E0%A4%B2_%E0%A4%95%E0%A4%BE%E0%A4%82%E0%A4%97%E0%A5%8D%E0%A4%B0%E0%A5%87%E0%A4%B8_%E0%A4%AC%E0%A4%A8%E0%A4%BE_%E0%A4%95%E0%A4%BE%E0%A4%B2',
#     'tweet_volume': 14618},
#    {'name': '#Nepal',
#     'url': 'http://twitter.com/search?q=%23Nepal',
#     'promoted_content': None,
#     'query': '%23Nepal',
#     'tweet_volume': None},
#    {'name': '#IndianWomenOurPride',
#     'url': 'http://twitter.com/search?q=%23IndianWomenOurPride',
#     'promoted_content': None,
#     'query': '%23IndianWomenOurPride',
#     'tweet_volume': 11824},
#    {'name': '#NZvPAK',
#     'url': 'http://twitter.com/search?q=%23NZvPAK',
#     'promoted_content': None,
#     'query': '%23NZvPAK',
#     'tweet_volume': 10697},
#    {'name': '#Asuran',
#     'url': 'http://twitter.com/search?q=%23Asuran',
#     'promoted_content': None,
#     'query': '%23Asuran',
#     'tweet_volume': 14664},
#    {'name': '#Marriage_In_17Minutes',
#     'url': 'http://twitter.com/search?q=%23Marriage_In_17Minutes',
#     'promoted_content': None,
#     'query': '%23Marriage_In_17Minutes',
#     'tweet_volume': 406741},
#    {'name': '#RaashiKhanna',
#     'url': 'http://twitter.com/search?q=%23RaashiKhanna',
#     'promoted_content': None,
#     'query': '%23RaashiKhanna',
#     'tweet_volume': None},
#    {'name': '#Dahej_Mukt_Bharat',
#     'url': 'http://twitter.com/search?q=%23Dahej_Mukt_Bharat',
#     'promoted_content': None,
#     'query': '%23Dahej_Mukt_Bharat',
#     'tweet_volume': 350547},
#    {'name': '#TaimurAliKhan',
#     'url': 'http://twitter.com/search?q=%23TaimurAliKhan',
#     'promoted_content': None,
#     'query': '%23TaimurAliKhan',
#     'tweet_volume': None},
#    {'name': '#AmaaliansSunday',
#     'url': 'http://twitter.com/search?q=%23AmaaliansSunday',
#     'promoted_content': None,
#     'query': '%23AmaaliansSunday',
#     'tweet_volume': None},
#    {'name': '#KGFChapter2UpdateTomorrow',
#     'url': 'http://twitter.com/search?q=%23KGFChapter2UpdateTomorrow',
#     'promoted_content': None,
#     'query': '%23KGFChapter2UpdateTomorrow',
#     'tweet_volume': 61643},
#    {'name': '#BBTeluguGrandFinale',
#     'url': 'http://twitter.com/search?q=%23BBTeluguGrandFinale',
#     'promoted_content': None,
#     'query': '%23BBTeluguGrandFinale',
#     'tweet_volume': 35264},
#    {'name': '#100MostHandsome2020',
#     'url': 'http://twitter.com/search?q=%23100MostHandsome2020',
#     'promoted_content': None,
#     'query': '%23100MostHandsome2020',
#     'tweet_volume': 29251},
#    {'name': '#HBDNazriyaNazim',
#     'url': 'http://twitter.com/search?q=%23HBDNazriyaNazim',
#     'promoted_content': None,
#     'query': '%23HBDNazriyaNazim',
#     'tweet_volume': None},
#    {'name': '#1YrOfRevolutionaryHero',
#     'url': 'http://twitter.com/search?q=%231YrOfRevolutionaryHero',
#     'promoted_content': None,
#     'query': '%231YrOfRevolutionaryHero',
#     'tweet_volume': 45804},
#    {'name': '#BengalWave',
#     'url': 'http://twitter.com/search?q=%23BengalWave',
#     'promoted_content': None,
#     'query': '%23BengalWave',
#     'tweet_volume': None},
#    {'name': '#Save21LakhParivar',
#     'url': 'http://twitter.com/search?q=%23Save21LakhParivar',
#     'promoted_content': None,
#     'query': '%23Save21LakhParivar',
#     'tweet_volume': 19156},
#    {'name': '#KICCHATheBrandOfSandalwood',
#     'url': 'http://twitter.com/search?q=%23KICCHATheBrandOfSandalwood',
#     'promoted_content': None,
#     'query': '%23KICCHATheBrandOfSandalwood',
#     'tweet_volume': 109574},
#    {'name': '#DheerajDhoopar',
#     'url': 'http://twitter.com/search?q=%23DheerajDhoopar',
#     'promoted_content': None,
#     'query': '%23DheerajDhoopar',
#     'tweet_volume': None},
#    {'name': '#HappyBirthdayNazriya',
#     'url': 'http://twitter.com/search?q=%23HappyBirthdayNazriya',
#     'promoted_content': None,
#     'query': '%23HappyBirthdayNazriya',
#     'tweet_volume': None},
#    {'name': '#SundayFunday',
#     'url': 'http://twitter.com/search?q=%23SundayFunday',
#     'promoted_content': None,
#     'query': '%23SundayFunday',
#     'tweet_volume': None}],
#   'as_of': '2020-12-20T11:39:41Z',
#   'created_at': '2020-12-19T19:24:22Z',
#   'locations': [{'name': 'Delhi', 'woeid': 20070458}]}]

# %%
top_trending_hashtag = trends_raw[0]['trends'][0]['name']
top_trending_hashtag
# Out:
# '#WestBengal'

# %%
tweets = tweepy.Cursor(api.search,
              q=top_trending_hashtag).items(50)

# %%
tweets

# %%
# [tweet.text for tweet in tweets]

# %%
tweets = api.search(q=top_trending_hashtag, count=100)

# %%
# tweets

# %%
for tweet in tweets:
    print(tweet._json['text'])
    print('----------')
# Out:
# RT @ZeeNews: 'ऐसा रोड शो में मैंने अब तक नहीं देखा, ये परिवर्तन की लहर है- अमित शाह
#
# #WestBengal @AmitShah #RoadShow
#
# https://t.co/jhafhPM…
# ----------
# RT @aajtak: अमित शाह के मेगा रोड शो में हजारों की संख्या में समर्थक उमड़े
# #WestBengal #AmitShah #Video
# https://t.co/tL0ZQqMqP9
# ----------
# RT @ZeeNews: 'ऐसा रोड शो में मैंने अब तक नहीं देखा, ये परिवर्तन की लहर है- अमित शाह
#
# #WestBengal @AmitShah #RoadShow
#
# https://t.co/jhafhPM…
# ----------
# RT @TV9Bharatvarsh: कौन जीतेंगे बंगाल..पूरा हिसाब...#TV9Bharatvarsh पर देखिए  बंग युद्ध..
# #WestBengal | #WestBengalPolitics | #WestBengalEl…
# ----------
# RT @TV9Bharatvarsh: 2021 में बोलपुर का बलवान कौन ?
#
# #WestBengal | #WestBengalPolitics | #WestBengalElection2021 | #TMC | #BJP | #MamataBane…
# ----------
# RT @ZeeNews: 'ऐसा रोड शो में मैंने अब तक नहीं देखा, ये परिवर्तन की लहर है- अमित शाह
#
# #WestBengal @AmitShah #RoadShow
#
# https://t.co/jhafhPM…
# ----------
# RT @aajtak: ममता बनर्जी पिछले तीन साल से बंगाल के लोगों को ठग रहीं हैं: अवनिजेश अवस्थी, राजनीतिक विश्लेषक
# #AmitShah #WestBengal #politics…
# ----------
# RT @ZeeNews: 'ऐसा रोड शो में मैंने अब तक नहीं देखा, ये परिवर्तन की लहर है- अमित शाह
#
# #WestBengal @AmitShah #RoadShow
#
# https://t.co/jhafhPM…
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @IndiaToday: People have decided they want change in #Bengal:
# @AmitShah at #Bolpur rally.
# #ITVideo #WestBengal https://t.co/YAvQl0PEx1
# ----------
# RT @TV9Bharatvarsh: जहां बीजेपी को मौका मिला वहां विकास हुआ-अमित शाह
# #WestBengal | #WestBengalPolitics | #WestBengalElection2021 | #TMC | #…
# ----------
# ममता बनर्जी पिछले तीन साल से बंगाल के लोगों को ठग रहीं हैं: अवनिजेश अवस्थी, राजनीतिक विश्लेषक
# #AmitShah… https://t.co/DKhIYYhLrh
# ----------
# @ArjunsinghWB गुरुकुल में गर्जना...शिक्षा के मठ से सन्देश
#
# #BengalWithBJP   🌼   #WestBengal https://t.co/OEP2kw72Ky
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @rohit_chahal: Will be Live on #Tv9BharatVarsh at 1 Pm on #WestBengal
# ----------
# @ArjunsinghWB गुरुकुल में गर्जना...शिक्षा के मठ से सन्देश
#
# #BengalWithBJP   🌼   #WestBengal https://t.co/OEP2kw72Ky
# ----------
# @ArjunsinghWB गुरुकुल में गर्जना...शिक्षा के मठ से सन्देश
#
# #BengalWithBJP   🌼   #WestBengal https://t.co/OEP2kw72Ky
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# कौन जीतेंगे बंगाल..पूरा हिसाब...#TV9Bharatvarsh पर देखिए  बंग युद्ध..
# #WestBengal | #WestBengalPolitics |… https://t.co/Q7XWH0d9UN
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @KunalChoudhary_: 9 MLA, 1 सांसद, 1 मंत्री
#
# मतलब साफ है, भाजपा अपनी विचारधारा पर नहीं, जयचंदों की वजह से जीतती है। #WestBengal
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @ZeeNews: 'ऐसा रोड शो में मैंने अब तक नहीं देखा, ये परिवर्तन की लहर है- अमित शाह
#
# #WestBengal @AmitShah #RoadShow
#
# https://t.co/jhafhPM…
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @aajtak: ममता बनर्जी के गढ़ में अमित शाह का शक्ति प्रदर्शन
#  #AmitShah #WestBengal #politics #MamataBanerjee
# देखें #Dangal @chitraaum…
# ----------
# RT @aajtak: अमित शाह ने कहा कि आज साफ हो गया है कि बंगाल की जनता परिवर्तन चाहती है
# #WestBengal #Video #AmitShah
# https://t.co/X5enmgGwZm
# ----------
# RT @ikunalshukal: पश्चिम बंगाल : केंद्रीय गृहमंत्री @AmitShah, @KailashOnline आणि @DilipGhoshBJP आदी सर्वांनी पश्चिम मेंदीनीपूर जिल्यातील…
# ----------
# RT @Ok_Bharatiya: ममता दीदी को घृणा है उसी "जय श्रीराम" के नारों से मोटा भाईने आज बंगाल में भाजपा का सफर शुरू कर दिया है! 🔥🤩
#
# भगवामय बंगाल…
# ----------
# RT @aajtak: अमित शाह के मेगा रोड शो में हजारों की संख्या में समर्थक उमड़े
# #WestBengal #AmitShah #Video
# https://t.co/tL0ZQqMqP9
# ----------
# RT @news24tvchannel: बंगाल की जनता चाहती है परिवर्तन, 10 साल ममता दीदी के राज में नहीं हुआ विकास...
#
# @AmitShah
# @BJP4Bengal
# #WestBengal #Ben…
# ----------
# Few more MLA's to shift from #TMC to #BJP at #WestBengal : Sources
# ----------
# अमित शाह ने कहा कि आज साफ हो गया है कि बंगाल की जनता परिवर्तन चाहती है
# #WestBengal #Video #AmitShah
# https://t.co/X5enmgGwZm
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @aajtak: 5 साल में हम सोनार बांग्ला बनाएंगे: अमित शाह
# #WestBengal #AmitShah #ATVideo https://t.co/JgpVtU2Qhq
# ----------
# RT @ZeeNews: 'ऐसा रोड शो में मैंने अब तक नहीं देखा, ये परिवर्तन की लहर है- अमित शाह
#
# #WestBengal @AmitShah #RoadShow
#
# https://t.co/jhafhPM…
# ----------
# 2021 में बोलपुर का बलवान कौन ?
#
# #WestBengal | #WestBengalPolitics | #WestBengalElection2021 | #TMC | #BJP |… https://t.co/OfCmcMpGCk
# ----------
# RT @ikunalshukal: ये बोल रहा है बंगाल में सबको भाजपा जॉइन करा दु या कुछ बाकी रखना है 😁😂
# #BengalSupportsBJP #WestBengal #AmitShah #AmitShah…
# ----------
# RT @rohit_chahal: Will be Live on #Tv9BharatVarsh at 1 Pm on #WestBengal
# ----------
# RT @aajtak: अमित शाह के मेगा रोड शो में हजारों की संख्या में समर्थक उमड़े
# #WestBengal #AmitShah #Video
# https://t.co/tL0ZQqMqP9
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @OpIndia_in: ‘TMC के खिलाफ एक भी वोट पड़ा तो खून की नदियाँ बहा देंगे’: पश्चिम बंगाल की दीवारों पर मतदाताओं को धमकी
#
# #WestBengal #TMC #BJ…
# ----------
# RT @ZeeNews: 'ऐसा रोड शो में मैंने अब तक नहीं देखा, ये परिवर्तन की लहर है- अमित शाह
#
# #WestBengal @AmitShah #RoadShow
#
# https://t.co/jhafhPM…
# ----------
# RT @OpIndia_in: ‘TMC के खिलाफ एक भी वोट पड़ा तो खून की नदियाँ बहा देंगे’: पश्चिम बंगाल की दीवारों पर मतदाताओं को धमकी
#
# #WestBengal #TMC #BJ…
# ----------
# RT @aajtak: अमित शाह के मेगा रोड शो में हजारों की संख्या में समर्थक उमड़े
# #WestBengal #AmitShah #Video
# https://t.co/tL0ZQqMqP9
# ----------
# RT @kanpurtak: #WestBengal: ममता के गढ़ मे केंद्रीय गृह मंत्री @AmitShah के रोड शो में उमड़ा भारी जन सैलाब, बंगाल मे सियासी युद्ध की कवरेज.…
# ----------
# RT @ZeeNews: 'ऐसा रोड शो में मैंने अब तक नहीं देखा, ये परिवर्तन की लहर है- अमित शाह
#
# #WestBengal @AmitShah #RoadShow
#
# https://t.co/jhafhPM…
# ----------
# RT @aajtak: ममता बनर्जी के गढ़ में अमित शाह का शक्ति प्रदर्शन
#  #AmitShah #WestBengal #politics #MamataBanerjee
# देखें #Dangal @chitraaum…
# ----------
# RT @kanpurtak: #WestBengal | पश्चिम बंगाल: केंद्रीय गृह मंत्री अमित शाह @AmitShah ने बीरभूम जिले के बोलपुर में रोड शो किया। रोड शो हनुमान…
# ----------
# RT @OpIndia_in: ‘TMC के खिलाफ एक भी वोट पड़ा तो खून की नदियाँ बहा देंगे’: पश्चिम बंगाल की दीवारों पर मतदाताओं को धमकी
#
# #WestBengal #TMC #BJ…
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @SDey83: A very short story......
#
# #CPIM party office was there. TMC forcefully occupied that some years ago. Few days ago Comrades have…
# ----------
# ಪಶ್ಚಿಮ ಬಂಗಾಳದಲ್ಲಿ ಅಮಿತ್ ಶಾ: ವೀಂದ್ರನಾಥ ಟ್ಯಾಗೋರ್‌ ಸ್ಮಾರಕಕ್ಕೆ ಪುಷ್ಪ ನಮನ
#    #Westbengal  https://t.co/rH6PmftwWB
# ----------
# RT @aajtak: ममता बनर्जी के गढ़ में अमित शाह का शक्ति प्रदर्शन
#  #AmitShah #WestBengal #politics #MamataBanerjee
# देखें #Dangal @chitraaum…
# ----------
# RT @news24tvchannel: बंगाल की जनता चाहती है परिवर्तन, 10 साल ममता दीदी के राज में नहीं हुआ विकास...
#
# @AmitShah
# @BJP4Bengal
# #WestBengal #Ben…
# ----------
# RT @ZeeNews: 'ऐसा रोड शो में मैंने अब तक नहीं देखा, ये परिवर्तन की लहर है- अमित शाह
#
# #WestBengal @AmitShah #RoadShow
#
# https://t.co/jhafhPM…
# ----------
# RT @DDBanglaNews: কোভিড বিধি মেনে বড়দিনের উৎসবে সামিল হওয়ার আর্জি রাজ্য সরকারের পক্ষ থেকে।
# #Covid_19 #Christmas #WestBengal #DDNewsBangla…
# ----------
# गृह मंत्री के रोड शो में उमड़ा जन सैलाब, शाह बोले- 5 साल में सोनार बांग्ला के लिए काम करेगी BJP
#
#  #amitshah… https://t.co/7hhASFPWX3
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @OpIndia_in: ‘TMC के खिलाफ एक भी वोट पड़ा तो खून की नदियाँ बहा देंगे’: पश्चिम बंगाल की दीवारों पर मतदाताओं को धमकी
#
# #WestBengal #TMC #BJ…
# ----------
# RT @maheshu483: Dear #WestBengal voters.
# Check #UP before you vote, where love is being criminalised and hate being dignified. Where crimi…
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @rose_k01: JAI JAI SHRI RAM!! 🙏🚩 ELECTRIC Atmosphere &amp; MASSIVE CROWDS at Shri Amit Shah @AmitShah Rally in #WestBengal Didi must be SHIV…
# ----------
# बंगाल की जनता चाहती है परिवर्तन, 10 साल ममता दीदी के राज में नहीं हुआ विकास...
#
# @AmitShah
# @BJP4Bengal
# #WestBengal… https://t.co/7SFWApiI9Z
# ----------
# RT @aajtak: बंगाल में आज अमित शाह का रोड शो. शाह आज विश्व भारती विश्वविद्यालय, शांति निकेतन में एक गैर सरकारी कार्यक्रम में हिस्सा भी लेंगे…
# ----------
# RT @ZeeNewsEnglish: #WestBengal is yearning for change, says #AmitShah during roadshow in #Bolpur
#
# Follow live updates on https://t.co/jEa…
# ----------
# अमित शाह के मेगा रोड शो में हजारों की संख्या में समर्थक उमड़े
# #WestBengal #AmitShah #Video
# https://t.co/tL0ZQqMqP9
# ----------
# 'ऐसा रोड शो में मैंने अब तक नहीं देखा, ये परिवर्तन की लहर है- अमित शाह
#
# #WestBengal @AmitShah #RoadShow
#
# https://t.co/jhafhPMLad
# ----------
# जहां बीजेपी को मौका मिला वहां विकास हुआ-अमित शाह
# #WestBengal | #WestBengalPolitics | #WestBengalElection2021 | #TMC… https://t.co/yHr02iR7y2
# ----------
# RT @ThanthiTV: என் வாழ்க்கையில், இது போன்றதொரு வரவேற்பை பார்த்ததில்லை
#
# * மேற்கு வங்க மக்கள் மாற்றத்தை விரும்புகிறார்கள் - மத்திய உள்துறை அ…
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# 🤡दाढ़ी बढ़ा लेने से कोई टैगोर नहीं बन जाता , नाही पगड़ी बाँध लेने से ने से कोई सिख बन जाता है! दोनों के लिए "चरि… https://t.co/AHGIMBSzlV
# ----------
# WEST BENGAL: अमित के रोड़ शो में उमड़ा जन सैलाब, कहा- बंगाल में जो परिवर्तन होने वाला है
# https://t.co/KFy0GRCzGQ… https://t.co/duwLmcWRJP
# ----------
# 🤡दाढ़ी बढ़ा लेने से कोई टैगोर नहीं बन जाता , नाही पगड़ी बाँध लेने से ने से कोई सिख बन जाता है! दोनों के लिए "चरि… https://t.co/JUAzPFK9eW
# ----------
# बंगाल की जनता चाहती है परिवर्तन, 10 साल ममता दीदी के राज में नहीं हुआ विकास...
#
# @AmitShah
# @BJP4Bengal
# #WestBengal #BengalElections
# ----------
# RT @aajtak: 5 साल में हम सोनार बांग्ला बनाएंगे: अमित शाह
# #WestBengal #AmitShah #ATVideo https://t.co/JgpVtU2Qhq
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @tv9gujarati: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader @AmitShah at…
# ----------
# RT @polimernews: கொல்கத்தா அருகே பாஜக நிர்வாகிகள் கார்கள் மீது வன்முறைத் தாக்குதல் #WestBengal | #BJP | #BJPFollowers | #Attack  https://t.…
# ----------
# RT @SandipGhose: BJP does not have to prove it is more Bengali than TMC - just that it is not as much of an "outsider" as it is made out to…
# ----------
# RT @KunalChoudhary_: 9 MLA, 1 सांसद, 1 मंत्री
#
# मतलब साफ है, भाजपा अपनी विचारधारा पर नहीं, जयचंदों की वजह से जीतती है। #WestBengal
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @shishirkb: People of #WestBengal all set to end @AITCofficial welcome @BJP4Bengal government
# Very evident from the spontaneous huge tu…
# ----------
# RT @ThanthiTV: என் வாழ்க்கையில், இது போன்றதொரு வரவேற்பை பார்த்ததில்லை
#
# * மேற்கு வங்க மக்கள் மாற்றத்தை விரும்புகிறார்கள் - மத்திய உள்துறை அ…
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @shadabmoizee: #Congress खुद ही बैठकर खुद के नेता को चुनने में माथा पच्ची कर रही है, और BJP बंगाल में दूसरे के नेता को अपना बनाने में..…
# ----------
# RT @MhnParee: #DidiStinks #BengalWithBJP
# #PoliticalKillings #SonarBangla
# #ShahStormsBengal #AmitShahInBengal #BattleForBengal
# In some s…
# ----------
# RT @ThanthiTV: என் வாழ்க்கையில், இது போன்றதொரு வரவேற்பை பார்த்ததில்லை
#
# * மேற்கு வங்க மக்கள் மாற்றத்தை விரும்புகிறார்கள் - மத்திய உள்துறை அ…
# ----------
# #AmitShah: Union HM &amp; BJP leader Amit Shah holds a roadshow in Bolpur, Birbhum of West Bengal. #AmitShahInBengal… https://t.co/ZW18tzNoag
# ----------
# RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…
# ----------
# RT @SudheenKulkarni: Dear #UddhavThackeray ji, #Maharashtra should show solidarity with the People, Government and the Chief Minister of #W…
# ----------
# RT @OpIndia_in: ‘TMC के खिलाफ एक भी वोट पड़ा तो खून की नदियाँ बहा देंगे’: पश्चिम बंगाल की दीवारों पर मतदाताओं को धमकी
#
# #WestBengal #TMC #BJ…
# ----------

# %%
for tweet in tweets:
    print(tweet._json['lang'])
    print('----------')
# Out:
# hi
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# hi
# ----------
# hi
# ----------
# en
# ----------
# en
# ----------
# hi
# ----------
# en
# ----------
# hi
# ----------
# en
# ----------
# hi
# ----------
# en
# ----------
# hi
# ----------
# hi
# ----------
# mr
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# en
# ----------
# hi
# ----------
# en
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# en
# ----------
# hi
# ----------
# en
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# kn
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# bn
# ----------
# hi
# ----------
# en
# ----------
# hi
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# hi
# ----------
# hi
# ----------
# en
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# ta
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# hi
# ----------
# en
# ----------
# en
# ----------
# ta
# ----------
# en
# ----------
# hi
# ----------
# en
# ----------
# en
# ----------
# ta
# ----------
# en
# ----------
# en
# ----------
# hi
# ----------
# en
# ----------
# ta
# ----------
# en
# ----------
# en
# ----------
# en
# ----------
# hi
# ----------

# %%
for tweet in tweets:
    print(tweet._json['retweeted'])
    print('----------')
# Out:
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------
# False
# ----------

# %%
tweets[0]
# Out:
# Status(_api=<tweepy.api.API object at 0x7fb3a4224cd0>, _json={'created_at': 'Sun Dec 20 11:53:47 +0000 2020', 'id': 1340626447237451776, 'id_str': '1340626447237451776', 'text': "RT @ANI: Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit Shah at a roadsh…", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'ANI', 'name': 'ANI', 'id': 355989081, 'id_str': '355989081', 'indices': [3, 7]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1117741895772332032, 'id_str': '1117741895772332032', 'name': 'jai sri ram....', 'screen_name': 'KaushikSujata1', 'location': '', 'description': 'I love my india 😍', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 287, 'friends_count': 905, 'listed_count': 0, 'created_at': 'Mon Apr 15 10:50:09 +0000 2019', 'favourites_count': 16025, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 6151, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1294662956991488000/UsNos9zq_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1294662956991488000/UsNos9zq_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1117741895772332032/1560272190', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Dec 20 10:49:21 +0000 2020', 'id': 1340610232175628288, 'id_str': '1340610232175628288', 'text': "Give one chance to Narendra Modi. We will make 'Sonar Bangla' in 5 years: Union Home Minister and BJP leader Amit S… https://t.co/SUhJ2vAcGV", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/SUhJ2vAcGV', 'expanded_url': 'https://twitter.com/i/web/status/1340610232175628288', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 355989081, 'id_str': '355989081', 'name': 'ANI', 'screen_name': 'ANI', 'location': 'India', 'description': 'Asian News International. Multi-media news agency, content for information platforms: TV, Internet, broadband, newspapers, mobiles https://t.co/PjGRhL4qvg', 'url': 'http://t.co/sFNGg4bASa', 'entities': {'url': {'urls': [{'url': 'http://t.co/sFNGg4bASa', 'expanded_url': 'http://www.aninews.in', 'display_url': 'aninews.in', 'indices': [0, 22]}]}, 'description': {'urls': [{'url': 'https://t.co/PjGRhL4qvg', 'expanded_url': 'http://facebook.com/ANINEWS.IN', 'display_url': 'facebook.com/ANINEWS.IN', 'indices': [131, 154]}]}}, 'protected': False, 'followers_count': 5028679, 'friends_count': 0, 'listed_count': 4902, 'created_at': 'Tue Aug 16 05:23:41 +0000 2011', 'fav ...

# %%
import json
tweetJson = []
for tweet in tweets:
    tweetJson.append(tweet._json)

# %%
tweetJson
# Out:
# [{'created_at': 'Sun Dec 20 11:39:53 +0000 2020',
#   'id': 1340622950484111360,
#   'id_str': '1340622950484111360',
#   'text': "RT @ZeeNews: 'ऐसा रोड शो में मैंने अब तक नहीं देखा, ये परिवर्तन की लहर है- अमित शाह \n\n#WestBengal @AmitShah #RoadShow\n\nhttps://t.co/jhafhPM…",
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'WestBengal', 'indices': [86, 97]},
#     {'text': 'RoadShow', 'indices': [108, 117]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ZeeNews',
#      'name': 'Zee News',
#      'id': 461841349,
#      'id_str': '461841349',
#      'indices': [3, 11]},
#     {'screen_name': 'AmitShah',
#      'name': 'Amit Shah',
#      'id': 1447949844,
#      'id_str': '1447949844',
#      'indices': [98, 107]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 4066968497,
#    'id_str': '4066968497',
#    'name': 'AvengersFan',
#    'screen_name': 'AvengersFan2908',
#    'location': '',
#    'description': 'Teacher,Textiles,Equities,Cricketer,InsuranceAdvr,GST,TaxAudit,Acnts,WLTHMgr.Donator+Motivational Speaker+GymCoach. politics,jokes,temples,environment,solarpowe',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 2577,
#    'friends_count': 3105,
#    'listed_count': 3,
#    'created_at': 'Thu Oct 29 09:55:34 +0000 2015',
#    'favourites_count': 402,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 88027,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1256295026964996096/9_7QgxMx_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1256295026964996096/9_7QgxMx_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4066968497/1588359050',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 11:34:09 +0000 2020',
#    'id': 1340621506154393600,
#    'id_str': '1340621506154393600',
#    'text': "'ऐसा रोड शो में मैंने अब तक नहीं देखा, ये परिवर्तन की लहर है- अमित शाह \n\n#WestBengal @AmitShah #RoadShow\n\nhttps://t.co/jhafhPMLad",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'WestBengal', 'indices': [73, 84]},
#      {'text': 'RoadShow', 'indices': [95, 104]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'AmitShah',
#       'name': 'Amit Shah',
#       'id': 1447949844,
#       'id_str': '1447949844',
#       'indices': [85, 94]}],
#     'urls': [{'url': 'https://t.co/jhafhPMLad',
#       'expanded_url': 'https://zeenews.india.com/hindi/india/birbhum-west-bengal-home-minister-amit-shah-holds-roadshow-from-hanuman-mandir-latest-update/810891',
#       'display_url': 'zeenews.india.com/hindi/india/bi…',
#       'indices': [106, 129]}]},
#    'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 461841349,
#     'id_str': '461841349',
#     'name': 'Zee News',
#     'screen_name': 'ZeeNews',
#     'location': 'India',
#     'description': 'ज़ी न्\u200dयूज हिंदी भाषी पाठकों के लिए पेश करता है बेहद सटीक, ताजा एवं विश्\u200dवसनीय खबरें। For English @zeenewsenglish',
#     'url': 'http://t.co/iza5ttB15R',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/iza5ttB15R',
#         'expanded_url': 'http://www.zeehindi.com',
#         'display_url': 'zeehindi.com',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4430193,
#     'friends_count': 31,
#     'listed_count': 1606,
#     'created_at': 'Thu Jan 12 07:52:31 +0000 2012',
#     'favourites_count': 10,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 269013,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/919586418174783489/usRQmm1H_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/919586418174783489/usRQmm1H_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/461841349/1608028579',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 77,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'hi'},
#   'is_quote_status': False,
#   'retweet_count': 9,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'hi'},
#  {'created_at': 'Sun Dec 20 11:39:51 +0000 2020',
#   'id': 1340622942548344832,
#   'id_str': '1340622942548344832',
#   'text': 'RT @aajtak: अमित शाह के मेगा रोड शो में हजारों की संख्या में समर्थक उमड़े \n#WestBengal #AmitShah #Video \nhttps://t.co/tL0ZQqMqP9',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'WestBengal', 'indices': [75, 86]},
#     {'text': 'AmitShah', 'indices': [87, 96]},
#     {'text': 'Video', 'indices': [97, 103]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'aajtak',
#      'name': 'AajTak',
#      'id': 42606652,
#      'id_str': '42606652',
#      'indices': [3, 10]}],
#    'urls': [{'url': 'https://t.co/tL0ZQqMqP9',
#      'expanded_url': 'https://www.aajtak.in/india/news/video/amit-shah-in-bengal-massive-crowd-in-bolpur-roadshow-bolpur-shah-pays-floral-tributes-to-rabindranath-tagore-1179935-2020-12-20',
#      'display_url': 'aajtak.in/india/news/vid…',
#      'indices': [105, 128]}]},
#   'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1302099397799366656,
#    'id_str': '1302099397799366656',
#    'name': 'Raghuraj',
#    'screen_name': 'Raghura82791716',
#    'location': '',
#    'description': '🇮🇳🇮🇳🇮🇳🇮🇳 Proud Indian.🇮🇳',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 230,
#    'friends_count': 325,
#    'listed_count': 0,
#    'created_at': 'Sat Sep 05 04:21:12 +0000 2020',
#    'favourites_count': 53475,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 33885,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1331843238995476480/OOfSz1LX_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1331843238995476480/OOfSz1LX_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 11:34:32 +0000 2020',
#    'id': 1340621603273523201,
#    'id_str': '1340621603273523201',
#    'text': 'अमित शाह के मेगा रोड शो में हजारों की संख्या में समर्थक उमड़े \n#WestBengal #AmitShah #Video \nhttps://t.co/tL0ZQqMqP9',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'WestBengal', 'indices': [63, 74]},
#      {'text': 'AmitShah', 'indices': [75, 84]},
#      {'text': 'Video', 'indices': [85, 91]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/tL0ZQqMqP9',
#       'expanded_url': 'https://www.aajtak.in/india/news/video/amit-shah-in-bengal-massive-crowd-in-bolpur-roadshow-bolpur-shah-pays-floral-tributes-to-rabindranath-tagore-1179935-2020-12-20',
#       'display_url': 'aajtak.in/india/news/vid…',
#       'indices': [93, 116]}]},
#    'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 42606652,
#     'id_str': '42606652',
#     'name': 'AajTak',
#     'screen_name': 'aajtak',
#     'location': 'India',
#     'description': 'AajTak covers breaking news, latest news in politics, sports, business & cinema. Follow us & stay ahead! Download the App:   https://t.co/Pkxqc2EN5z',
#     'url': 'https://t.co/YI9ZR7M9YW',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/YI9ZR7M9YW',
#         'expanded_url': 'http://www.aajtak.in',
#         'display_url': 'aajtak.in',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/Pkxqc2EN5z',
#         'expanded_url': 'https://aajtak.app.link/QFAp3ZaHmQ',
#         'display_url': 'aajtak.app.link/QFAp3ZaHmQ',
#         'indices': [125, 148]}]}},
#     'protected': False,
#     'followers_count': 11575531,
#     'friends_count': 374,
#     'listed_count': 3771,
#     'created_at': 'Tue May 26 11:31:00 +0000 2009',
#     'favourites_count': 16828,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 480105,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '9AE4E8',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1179039747273940992/ZGQ_ibsP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1179039747273940992/ZGQ_ibsP_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/42606652/1608398359',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'BDDCAD',
#     'profile_sidebar_fill_color': 'DDFFCC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 46,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'hi'},
#   'is_quote_status': False,
#   'retweet_count': 5,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'hi'},
#  {'created_at': 'Sun Dec 20 11:39:29 +0000 2020',
#   'id': 1340622850646921223,
#   'id_str': '1340622850646921223',
#   'text': "RT @ZeeNews: 'ऐसा रोड शो में मैंने अब तक नहीं देखा, ये परिवर्तन की लहर है- अमित शाह \n\n#WestBengal @AmitShah #RoadShow\n\nhttps://t.co/jhafhPM…",
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'WestBengal', 'indices': [86, 97]},
#     {'text': 'RoadShow', 'indices': [108, 117]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ZeeNews',
#      'name': 'Zee News',
#      'id': 461841349,
#      'id_str': '461841349',
#      'indices': [3, 11]},
#     {'screen_name': 'AmitShah',
#      'name': 'Amit Shah',
#      'id': 1447949844,
#      'id_str': '1447949844',
#      'indices': [98, 107]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1321481910858575872,
#    'id_str': '1321481910858575872',
#    'name': 'SAMSHER SINGH RATHORE',
#    'screen_name': 'RathoreSamsher7',
#    'location': 'Jodhpur, India',
#    'description': 'Rajput Karni Sena Raj. politically analysis',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 495,
#    'friends_count': 3202,
#    'listed_count': 0,
#    'created_at': 'Wed Oct 28 16:00:43 +0000 2020',
#    'favourites_count': 5926,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 5520,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1339599298653114370/u1zjmttF_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1339599298653114370/u1zjmttF_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1321481910858575872/1608220336',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 11:34:09 +0000 2020',
#    'id': 1340621506154393600,
#    'id_str': '1340621506154393600',
#    'text': "'ऐसा रोड शो में मैंने अब तक नहीं देखा, ये परिवर्तन की लहर है- अमित शाह \n\n#WestBengal @AmitShah #RoadShow\n\nhttps://t.co/jhafhPMLad",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'WestBengal', 'indices': [73, 84]},
#      {'text': 'RoadShow', 'indices': [95, 104]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'AmitShah',
#       'name': 'Amit Shah',
#       'id': 1447949844,
#       'id_str': '1447949844',
#       'indices': [85, 94]}],
#     'urls': [{'url': 'https://t.co/jhafhPMLad',
#       'expanded_url': 'https://zeenews.india.com/hindi/india/birbhum-west-bengal-home-minister-amit-shah-holds-roadshow-from-hanuman-mandir-latest-update/810891',
#       'display_url': 'zeenews.india.com/hindi/india/bi…',
#       'indices': [106, 129]}]},
#    'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 461841349,
#     'id_str': '461841349',
#     'name': 'Zee News',
#     'screen_name': 'ZeeNews',
#     'location': 'India',
#     'description': 'ज़ी न्\u200dयूज हिंदी भाषी पाठकों के लिए पेश करता है बेहद सटीक, ताजा एवं विश्\u200dवसनीय खबरें। For English @zeenewsenglish',
#     'url': 'http://t.co/iza5ttB15R',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/iza5ttB15R',
#         'expanded_url': 'http://www.zeehindi.com',
#         'display_url': 'zeehindi.com',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4430193,
#     'friends_count': 31,
#     'listed_count': 1606,
#     'created_at': 'Thu Jan 12 07:52:31 +0000 2012',
#     'favourites_count': 10,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 269013,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/919586418174783489/usRQmm1H_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/919586418174783489/usRQmm1H_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/461841349/1608028579',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 77,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'hi'},
#   'is_quote_status': False,
#   'retweet_count': 9,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'hi'},
#  {'created_at': 'Sun Dec 20 11:39:25 +0000 2020',
#   'id': 1340622831617417223,
#   'id_str': '1340622831617417223',
#   'text': 'RT @TV9Bharatvarsh: कौन जीतेंगे बंगाल..पूरा हिसाब...#TV9Bharatvarsh पर देखिए  बंग युद्ध..\n#WestBengal | #WestBengalPolitics | #WestBengalEl…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'TV9Bharatvarsh', 'indices': [52, 67]},
#     {'text': 'WestBengal', 'indices': [90, 101]},
#     {'text': 'WestBengalPolitics', 'indices': [104, 123]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'TV9Bharatvarsh',
#      'name': 'TV9 Bharatvarsh',
#      'id': 1039759933728645120,
#      'id_str': '1039759933728645120',
#      'indices': [3, 18]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 209663295,
#    'id_str': '209663295',
#    'name': 'Gaurav Agrawal',
#    'screen_name': 'GauravAgrawaal',
#    'location': 'India',
#    'description': 'Anchor/Sr. Producer @TV9Bharatvarsh | विचार निजी हैं और सोच सकारात्मक। जन्मस्थली #Bahraich और कर्मस्थली पूरी धरती। इसके आगे जानने की चाह है तो फॉलो कीजिये।',
#    'url': 'https://t.co/fzfqyj7wJm',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/fzfqyj7wJm',
#        'expanded_url': 'https://www.facebook.com/gaurav.agrawal.73345048',
#        'display_url': 'facebook.com/gaurav.agrawal…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 2781,
#    'friends_count': 1211,
#    'listed_count': 11,
#    'created_at': 'Fri Oct 29 17:00:55 +0000 2010',
#    'favourites_count': 10805,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 10080,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '7A7A0A',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1283034350997721090/ih4Ysxr1_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1283034350997721090/ih4Ysxr1_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/209663295/1580466214',
#    'profile_link_color': '981CEB',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '200C63',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 11:38:03 +0000 2020',
#    'id': 1340622487088820224,
#    'id_str': '1340622487088820224',
#    'text': 'कौन जीतेंगे बंगाल..पूरा हिसाब...#TV9Bharatvarsh पर देखिए  बंग युद्ध..\n#WestBengal | #WestBengalPolitics |… https://t.co/Q7XWH0d9UN',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'TV9Bharatvarsh', 'indices': [32, 47]},
#      {'text': 'WestBengal', 'indices': [70, 81]},
#      {'text': 'WestBengalPolitics', 'indices': [84, 103]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/Q7XWH0d9UN',
#       'expanded_url': 'https://twitter.com/i/web/status/1340622487088820224',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [107, 130]}]},
#    'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#    'source': '<a href="https://www.twitter.com/" rel="nofollow">Twitter Media Studio - LiveCut</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1039759933728645120,
#     'id_str': '1039759933728645120',
#     'name': 'TV9 Bharatvarsh',
#     'screen_name': 'TV9Bharatvarsh',
#     'location': 'Noida, India',
#     'description': 'Official handle of National Hindi News Channel TV9 भारतवर्ष. After @TV9Telugu @tv9kannada @tv9gujarati @TV9Marathi We are here to say हिंदी हैं हम !!',
#     'url': 'https://t.co/y2Hb9F9pqi',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/y2Hb9F9pqi',
#         'expanded_url': 'https://www.tv9hindi.com',
#         'display_url': 'tv9hindi.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 128697,
#     'friends_count': 16,
#     'listed_count': 127,
#     'created_at': 'Wed Sep 12 06:17:40 +0000 2018',
#     'favourites_count': 4,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 108232,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1239416273743699968/OTHxWPty_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1239416273743699968/OTHxWPty_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1039759933728645120/1607433776',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'hi'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'hi'},
#  {'created_at': 'Sun Dec 20 11:39:25 +0000 2020',
#   'id': 1340622831617331200,
#   'id_str': '1340622831617331200',
#   'text': 'RT @TV9Bharatvarsh: 2021 में बोलपुर का बलवान कौन ?\n\n#WestBengal | #WestBengalPolitics | #WestBengalElection2021 | #TMC | #BJP | #MamataBane…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'WestBengal', 'indices': [52, 63]},
#     {'text': 'WestBengalPolitics', 'indices': [66, 85]},
#     {'text': 'WestBengalElection2021', 'indices': [88, 111]},
#     {'text': 'TMC', 'indices': [114, 118]},
#     {'text': 'BJP', 'indices': [121, 125]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'TV9Bharatvarsh',
#      'name': 'TV9 Bharatvarsh',
#      'id': 1039759933728645120,
#      'id_str': '1039759933728645120',
#      'indices': [3, 18]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 209663295,
#    'id_str': '209663295',
#    'name': 'Gaurav Agrawal',
#    'screen_name': 'GauravAgrawaal',
#    'location': 'India',
#    'description': 'Anchor/Sr. Producer @TV9Bharatvarsh | विचार निजी हैं और सोच सकारात्मक। जन्मस्थली #Bahraich और कर्मस्थली पूरी धरती। इसके आगे जानने की चाह है तो फॉलो कीजिये।',
#    'url': 'https://t.co/fzfqyj7wJm',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/fzfqyj7wJm',
#        'expanded_url': 'https://www.facebook.com/gaurav.agrawal.73345048',
#        'display_url': 'facebook.com/gaurav.agrawal…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 2781,
#    'friends_count': 1211,
#    'listed_count': 11,
#    'created_at': 'Fri Oct 29 17:00:55 +0000 2010',
#    'favourites_count': 10805,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 10080,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '7A7A0A',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1283034350997721090/ih4Ysxr1_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1283034350997721090/ih4Ysxr1_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/209663295/1580466214',
#    'profile_link_color': '981CEB',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '200C63',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 11:37:05 +0000 2020',
#    'id': 1340622244968423424,
#    'id_str': '1340622244968423424',
#    'text': '2021 में बोलपुर का बलवान कौन ?\n\n#WestBengal | #WestBengalPolitics | #WestBengalElection2021 | #TMC | #BJP |… https://t.co/OfCmcMpGCk',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'WestBengal', 'indices': [32, 43]},
#      {'text': 'WestBengalPolitics', 'indices': [46, 65]},
#      {'text': 'WestBengalElection2021', 'indices': [68, 91]},
#      {'text': 'TMC', 'indices': [94, 98]},
#      {'text': 'BJP', 'indices': [101, 105]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/OfCmcMpGCk',
#       'expanded_url': 'https://twitter.com/i/web/status/1340622244968423424',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [109, 132]}]},
#    'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#    'source': '<a href="https://www.twitter.com/" rel="nofollow">Twitter Media Studio - LiveCut</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1039759933728645120,
#     'id_str': '1039759933728645120',
#     'name': 'TV9 Bharatvarsh',
#     'screen_name': 'TV9Bharatvarsh',
#     'location': 'Noida, India',
#     'description': 'Official handle of National Hindi News Channel TV9 भारतवर्ष. After @TV9Telugu @tv9kannada @tv9gujarati @TV9Marathi We are here to say हिंदी हैं हम !!',
#     'url': 'https://t.co/y2Hb9F9pqi',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/y2Hb9F9pqi',
#         'expanded_url': 'https://www.tv9hindi.com',
#         'display_url': 'tv9hindi.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 128697,
#     'friends_count': 16,
#     'listed_count': 127,
#     'created_at': 'Wed Sep 12 06:17:40 +0000 2018',
#     'favourites_count': 4,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 108232,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1239416273743699968/OTHxWPty_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1239416273743699968/OTHxWPty_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1039759933728645120/1607433776',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 4,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'hi'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'hi'},
#  {'created_at': 'Sun Dec 20 11:39:19 +0000 2020',
#   'id': 1340622805423943684,
#   'id_str': '1340622805423943684',
#   'text': "RT @ZeeNews: 'ऐसा रोड शो में मैंने अब तक नहीं देखा, ये परिवर्तन की लहर है- अमित शाह \n\n#WestBengal @AmitShah #RoadShow\n\nhttps://t.co/jhafhPM…",
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'WestBengal', 'indices': [86, 97]},
#     {'text': 'RoadShow', 'indices': [108, 117]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ZeeNews',
#      'name': 'Zee News',
#      'id': 461841349,
#      'id_str': '461841349',
#      'indices': [3, 11]},
#     {'screen_name': 'AmitShah',
#      'name': 'Amit Shah',
#      'id': 1447949844,
#      'id_str': '1447949844',
#      'indices': [98, 107]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 4751176937,
#    'id_str': '4751176937',
#    'name': 'Naresh Upreti🇮🇳',
#    'screen_name': 'NareshUpreti',
#    'location': 'हिंदुस्तान',
#    'description': 'आँधियों में भी जो जलता हुआ मिल जाएगा...!!\nउस दिये से पूछना मेरा पता मिल जाएगा...\n#जयहिंद 🚩 वन्देमातरम् 🚩',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 10122,
#    'friends_count': 7411,
#    'listed_count': 10,
#    'created_at': 'Sat Jan 09 04:53:34 +0000 2016',
#    'favourites_count': 7397,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 52688,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1335892306835042305/18H9A-tX_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1335892306835042305/18H9A-tX_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4751176937/1593157033',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 11:34:09 +0000 2020',
#    'id': 1340621506154393600,
#    'id_str': '1340621506154393600',
#    'text': "'ऐसा रोड शो में मैंने अब तक नहीं देखा, ये परिवर्तन की लहर है- अमित शाह \n\n#WestBengal @AmitShah #RoadShow\n\nhttps://t.co/jhafhPMLad",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'WestBengal', 'indices': [73, 84]},
#      {'text': 'RoadShow', 'indices': [95, 104]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'AmitShah',
#       'name': 'Amit Shah',
#       'id': 1447949844,
#       'id_str': '1447949844',
#       'indices': [85, 94]}],
#     'urls': [{'url': 'https://t.co/jhafhPMLad',
#       'expanded_url': 'https://zeenews.india.com/hindi/india/birbhum-west-bengal-home-minister-amit-shah-holds-roadshow-from-hanuman-mandir-latest-update/810891',
#       'display_url': 'zeenews.india.com/hindi/india/bi…',
#       'indices': [106, 129]}]},
#    'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 461841349,
#     'id_str': '461841349',
#     'name': 'Zee News',
#     'screen_name': 'ZeeNews',
#     'location': 'India',
#     'description': 'ज़ी न्\u200dयूज हिंदी भाषी पाठकों के लिए पेश करता है बेहद सटीक, ताजा एवं विश्\u200dवसनीय खबरें। For English @zeenewsenglish',
#     'url': 'http://t.co/iza5ttB15R',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/iza5ttB15R',
#         'expanded_url': 'http://www.zeehindi.com',
#         'display_url': 'zeehindi.com',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4430193,
#     'friends_count': 31,
#     'listed_count': 1606,
#     'created_at': 'Thu Jan 12 07:52:31 +0000 2012',
#     'favourites_count': 10,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 269013,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/919586418174783489/usRQmm1H_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/919586418174783489/usRQmm1H_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/461841349/1608028579',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 77,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'hi'},
#   'is_quote_status': False,
#   'retweet_count': 9,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'hi'},
#  {'created_at': 'Sun Dec 20 11:39:19 +0000 2020',
#   'id': 1340622805293883398,
#   'id_str': '1340622805293883398',
#   'text': 'RT @aajtak: ममता बनर्जी पिछले तीन साल से बंगाल के लोगों को ठग रहीं हैं: अवनिजेश अवस्थी, राजनीतिक विश्लेषक \n#AmitShah #WestBengal #politics…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'AmitShah', 'indices': [107, 116]},
#     {'text': 'WestBengal', 'indices': [117, 128]},
#     {'text': 'politics', 'indices': [129, 138]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'aajtak',
#      'name': 'AajTak',
#      'id': 42606652,
#      'id_str': '42606652',
#      'indices': [3, 10]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 752528946789507072,
#    'id_str': '752528946789507072',
#    'name': 'Ramesh Siyag BJP 🇮🇳',
#    'screen_name': 'I4Ramesh',
#    'location': 'India',
#    'description': 'Lawyer,  @RSSorg.  Advocate Rajasthan High Court Jodhpur. Work BJP Rajasthan. Jay Shree Ram.🚩',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4488,
#    'friends_count': 440,
#    'listed_count': 1,
#    'created_at': 'Mon Jul 11 15:44:17 +0000 2016',
#    'favourites_count': 62645,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 16802,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1297410978942861314/_3HYh4TM_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1297410978942861314/_3HYh4TM_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/752528946789507072/1604035648',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 11:38:48 +0000 2020',
#    'id': 1340622677854208002,
#    'id_str': '1340622677854208002',
#    'text': 'ममता बनर्जी पिछले तीन साल से बंगाल के लोगों को ठग रहीं हैं: अवनिजेश अवस्थी, राजनीतिक विश्लेषक \n#AmitShah… https://t.co/DKhIYYhLrh',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'AmitShah', 'indices': [95, 104]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/DKhIYYhLrh',
#       'expanded_url': 'https://twitter.com/i/web/status/1340622677854208002',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [106, 129]}]},
#    'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#    'source': '<a href="https://www.twitter.com/" rel="nofollow">Twitter Media Studio - LiveCut</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 42606652,
#     'id_str': '42606652',
#     'name': 'AajTak',
#     'screen_name': 'aajtak',
#     'location': 'India',
#     'description': 'AajTak covers breaking news, latest news in politics, sports, business & cinema. Follow us & stay ahead! Download the App:   https://t.co/Pkxqc2EN5z',
#     'url': 'https://t.co/YI9ZR7M9YW',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/YI9ZR7M9YW',
#         'expanded_url': 'http://www.aajtak.in',
#         'display_url': 'aajtak.in',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/Pkxqc2EN5z',
#         'expanded_url': 'https://aajtak.app.link/QFAp3ZaHmQ',
#         'display_url': 'aajtak.app.link/QFAp3ZaHmQ',
#         'indices': [125, 148]}]}},
#     'protected': False,
#     'followers_count': 11575531,
#     'friends_count': 374,
#     'listed_count': 3771,
#     'created_at': 'Tue May 26 11:31:00 +0000 2009',
#     'favourites_count': 16828,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 480105,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '9AE4E8',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1179039747273940992/ZGQ_ibsP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1179039747273940992/ZGQ_ibsP_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/42606652/1608398359',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'BDDCAD',
#     'profile_sidebar_fill_color': 'DDFFCC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'hi'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'hi'},
#  {'created_at': 'Sun Dec 20 11:39:13 +0000 2020',
#   'id': 1340622782099378177,
#   'id_str': '1340622782099378177',
#   'text': "RT @ZeeNews: 'ऐसा रोड शो में मैंने अब तक नहीं देखा, ये परिवर्तन की लहर है- अमित शाह \n\n#WestBengal @AmitShah #RoadShow\n\nhttps://t.co/jhafhPM…",
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'WestBengal', 'indices': [86, 97]},
#     {'text': 'RoadShow', 'indices': [108, 117]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ZeeNews',
#      'name': 'Zee News',
#      'id': 461841349,
#      'id_str': '461841349',
#      'indices': [3, 11]},
#     {'screen_name': 'AmitShah',
#      'name': 'Amit Shah',
#      'id': 1447949844,
#      'id_str': '1447949844',
#      'indices': [98, 107]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2547407815,
#    'id_str': '2547407815',
#    'name': 'Anil Joshi',
#    'screen_name': 'AnilJoshi952',
#    'location': 'New Delhi',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 26,
#    'friends_count': 281,
#    'listed_count': 0,
#    'created_at': 'Thu Jun 05 04:56:44 +0000 2014',
#    'favourites_count': 528,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 104,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1180420001926221826/HxeNi49r_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1180420001926221826/HxeNi49r_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2547407815/1411430272',
#    'profile_link_color': '3B94D9',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
# ...
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 20 11:31:29 +0000 2020',
#   'id': 1340620836688912384,
#   'id_str': '1340620836688912384',
#   'text': 'RT @SudheenKulkarni: Dear #UddhavThackeray ji, #Maharashtra should show solidarity with the People, Government and the Chief Minister of #W…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'UddhavThackeray', 'indices': [26, 42]},
#     {'text': 'Maharashtra', 'indices': [47, 59]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'SudheenKulkarni',
#      'name': 'Sudheendra Kulkarni',
#      'id': 358127438,
#      'id_str': '358127438',
#      'indices': [3, 19]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1180514314576203778,
#    'id_str': '1180514314576203778',
#    'name': 'Sanatan Army 🚩🚩💪💪',
#    'screen_name': 'army_sanatan',
#    'location': '',
#    'description': "If you are a human , you are a Sanatani . We believe in peace but also it's our Dharma to rise against adharma , not staying mum *Freethinker , no P . Party*",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 272,
#    'friends_count': 88,
#    'listed_count': 0,
#    'created_at': 'Sat Oct 05 16:05:44 +0000 2019',
#    'favourites_count': 22099,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 18523,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1333321042396233730/kW2Y3JHf_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1333321042396233730/kW2Y3JHf_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1180514314576203778/1606738241',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 11:13:27 +0000 2020',
#    'id': 1340616298137415685,
#    'id_str': '1340616298137415685',
#    'text': 'Dear #UddhavThackeray ji, #Maharashtra should show solidarity with the People, Government and the Chief Minister of… https://t.co/QMeK4uJ4Di',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'UddhavThackeray', 'indices': [5, 21]},
#      {'text': 'Maharashtra', 'indices': [26, 38]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/QMeK4uJ4Di',
#       'expanded_url': 'https://twitter.com/i/web/status/1340616298137415685',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 358127438,
#     'id_str': '358127438',
#     'name': 'Sudheendra Kulkarni',
#     'screen_name': 'SudheenKulkarni',
#     'location': 'Bombay, India',
#     'description': "A socio-political activist and columnist. Author of 'MUSIC OF THE SPINNING WHEEL: Mahatma Gandhi's Manifesto for the Internet Age'",
#     'url': 'http://t.co/eeRpYI49',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/eeRpYI49',
#         'expanded_url': 'http://musicofthespinningwheel.com/',
#         'display_url': 'musicofthespinningwheel.com',
#         'indices': [0, 20]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 65971,
#     'friends_count': 15059,
#     'listed_count': 258,
#     'created_at': 'Fri Aug 19 12:30:57 +0000 2011',
#     'favourites_count': 19584,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 12873,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3049602263/4a5f6fc2c37ce87fbd5a51cdf752ea5a_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3049602263/4a5f6fc2c37ce87fbd5a51cdf752ea5a_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/358127438/1515851296',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1340605231910948865,
#    'quoted_status_id_str': '1340605231910948865',
#    'quoted_status': {'created_at': 'Sun Dec 20 10:29:29 +0000 2020',
#     'id': 1340605231910948865,
#     'id_str': '1340605231910948865',
#     'text': 'Centre is brazenly interfering with State Govt functioning by transferring police officers. My gratitude to… https://t.co/LUMsrZKZZE',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/LUMsrZKZZE',
#        'expanded_url': 'https://twitter.com/i/web/status/1340605231910948865',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [109, 132]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2526794479,
#      'id_str': '2526794479',
#      'name': 'Mamata Banerjee',
#      'screen_name': 'MamataOfficial',
#      'location': 'Kolkata, India',
#      'description': 'The official Twitter page of Mamata Banerjee, founder Chairperson All India Trinamool Congress. Honourable Chief Minister, West Bengal.',
#      'url': 'https://t.co/Qpf9G3CVE4',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Qpf9G3CVE4',
#          'expanded_url': 'http://aitcofficial.org',
#          'display_url': 'aitcofficial.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 5016275,
#      'friends_count': 31,
#      'listed_count': 1145,
#      'created_at': 'Tue May 27 07:12:07 +0000 2014',
#      'favourites_count': 5,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 7377,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1252529768110493696/iUA4KZFK_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1252529768110493696/iUA4KZFK_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2526794479/1583318873',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 542,
#     'favorite_count': 2502,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'retweet_count': 2,
#    'favorite_count': 10,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': True,
#   'quoted_status_id': 1340605231910948865,
#   'quoted_status_id_str': '1340605231910948865',
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Dec 20 11:31:28 +0000 2020',
#   'id': 1340620831253151746,
#   'id_str': '1340620831253151746',
#   'text': 'RT @OpIndia_in: ‘TMC के खिलाफ एक भी वोट पड़ा तो खून की नदियाँ बहा देंगे’: पश्चिम बंगाल की दीवारों पर मतदाताओं को धमकी\n\n#WestBengal #TMC #BJ…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'WestBengal', 'indices': [119, 130]},
#     {'text': 'TMC', 'indices': [131, 135]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'OpIndia_in',
#      'name': 'ऑपइंडिया',
#      'id': 1068155700168126464,
#      'id_str': '1068155700168126464',
#      'indices': [3, 14]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 954373995842842624,
#    'id_str': '954373995842842624',
#    'name': 'आनन्द त्रिपाठी (एक भक्त)',
#    'screen_name': 'anandtripathi64',
#    'location': 'Gorakhpur, India',
#    'description': 'एक सच्चा देश भक्त जय माँ भारती (RSS) 🚩🚩\nअब तक बहुत सुने अब नहीं सुनेंगे। भारत के कोने - कोने में भगवा झंडा लहराएंगे।बस इसी रास्ते पे चलना है।',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 135,
#    'friends_count': 127,
#    'listed_count': 0,
#    'created_at': 'Fri Jan 19 15:24:26 +0000 2018',
#    'favourites_count': 10241,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 2563,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1294885973843566592/Fvq8pZE5_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1294885973843566592/Fvq8pZE5_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/954373995842842624/1586234478',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Dec 20 08:47:02 +0000 2020',
#    'id': 1340579450740621312,
#    'id_str': '1340579450740621312',
#    'text': '‘TMC के खिलाफ एक भी वोट पड़ा तो खून की नदियाँ बहा देंगे’: पश्चिम बंगाल की दीवारों पर मतदाताओं को धमकी\n\n#WestBengal… https://t.co/maelv0R19I',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'WestBengal', 'indices': [103, 114]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/maelv0R19I',
#       'expanded_url': 'https://twitter.com/i/web/status/1340579450740621312',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1068155700168126464,
#     'id_str': '1068155700168126464',
#     'name': 'ऑपइंडिया',
#     'screen_name': 'OpIndia_in',
#     'location': 'New Delhi, India',
#     'description': "भारत के समाचार और भारत के विचार, ख़बरों के 'राइट' एंगल के साथ | यूट्यूब: https://t.co/Nt2ynIlKyE",
#     'url': 'https://t.co/x0pKhZC2cF',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/x0pKhZC2cF',
#         'expanded_url': 'http://www.opindia.in',
#         'display_url': 'opindia.in',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/Nt2ynIlKyE',
#         'expanded_url': 'http://youtube.com/c/OpIndiaHindi',
#         'display_url': 'youtube.com/c/OpIndiaHindi',
#         'indices': [73, 96]}]}},
#     'protected': False,
#     'followers_count': 80721,
#     'friends_count': 7,
#     'listed_count': 74,
#     'created_at': 'Thu Nov 29 14:52:19 +0000 2018',
#     'favourites_count': 104,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 33057,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1083918226931601408/UjvBQ-vg_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1083918226931601408/UjvBQ-vg_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1068155700168126464/1547259917',
#     'profile_link_color': 'FB5100',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 149,
#    'favorite_count': 380,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'hi'},
#   'is_quote_status': False,
#   'retweet_count': 149,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'hi'}]

# %%
## get 100000 tweets

tweets = []

old_len = 0

while len(tweets) < 1000:
    if len(tweets) == 0:
        tweets = api.search(q=top_trending_hashtag, count=100)
    else:
        lowest_tweet_id = tweets[len(tweets)-100]._json['id']
        for tweet in tweets:
            tweet_id = tweet._json['id']
            if tweet_id < lowest_tweet_id:
                lowest_tweet_id = tweet_id
        lowest_tweet_id -= 1
        tweets += api.search(q=top_trending_hashtag, count=100, max_id=lowest_tweet_id)
    print(len(tweets))
    if len(tweets) == old_len:
        break
    old_len = len(tweets)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 774
# 874
# 974
# 1074

# %%
# low_id

# %%
tweets[0].author
# Out:
# User(_api=<tweepy.api.API object at 0x7fb3a4224cd0>, _json={'id': 995337114169495553, 'id_str': '995337114169495553', 'name': 'प्रिया राजपूत', 'screen_name': 'RealPriyaRajput', 'location': 'जहाँ कोई, आता जाता नही', 'description': 'DM में प्रवेश वर्जित है / रिट्वीट का मतलब ये नहीं कि मैं सहमत हूं।', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 12780, 'friends_count': 654, 'listed_count': 5, 'created_at': 'Sat May 12 16:17:15 +0000 2018', 'favourites_count': 14538, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 9053, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1336218258463023104/IQdzBYdu_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1336218258463023104/IQdzBYdu_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/995337114169495553/1607011586', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, id=995337114169495553, id_str='995337114169495553', name='प्रिया राजपूत', screen_name='RealPriyaRajput', location='जहाँ कोई, आता जाता नही', description='DM में प्रवेश वर्जित है / रिट्वीट का मतलब ये नहीं कि मैं सहमत हूं।', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=12780, friends_count=654, listed_count=5, created_at=datetime.datetime(2018, 5, 12, 16, 17, 15), favourites_count=14538, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=9053, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='F5F8FA', profile_background_image_url=None, profile_background_image_url_https=None, profile_background_tile=False, profile_image_url='http://pbs.twimg.com/profile_images/1336218258463023104/IQdzBYdu_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/1336218258463023104/IQdzBYdu_normal.jpg', profile_banner_url='https://pbs.twimg.com/profile_banners/995337114169495553/1607011586', profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, has_extended_profile=False, default_profile=True, default_profile_image=False, following=False, follow_request_sent=False, notifications=False, translator_type='none')

# %%
# api.help()

# %%
#fetch languages

# url = "https://api.twitter.com/1.1/help/languages.json"
# languages = requests.get(url, auth=auth).json()

languages = {
    "ab": {
        "name": "Abkhaz",
            "nativeName": "аҧсуа"
    },
        "aa": {
        "name": "Afar",
            "nativeName": "Afaraf"
    },
        "af": {
        "name": "Afrikaans",
            "nativeName": "Afrikaans"
    },
        "ak": {
        "name": "Akan",
            "nativeName": "Akan"
    },
        "sq": {
        "name": "Albanian",
            "nativeName": "Shqip"
    },
        "am": {
        "name": "Amharic",
            "nativeName": "አማርኛ"
    },
        "ar": {
        "name": "Arabic",
            "nativeName": "العربية"
    },
        "an": {
        "name": "Aragonese",
            "nativeName": "Aragonés"
    },
        "hy": {
        "name": "Armenian",
            "nativeName": "Հայերեն"
    },
        "as": {
        "name": "Assamese",
            "nativeName": "অসমীয়া"
    },
        "av": {
        "name": "Avaric",
            "nativeName": "авар мацӀ, магӀарул мацӀ"
    },
        "ae": {
        "name": "Avestan",
            "nativeName": "avesta"
    },
        "ay": {
        "name": "Aymara",
            "nativeName": "aymar aru"
    },
        "az": {
        "name": "Azerbaijani",
            "nativeName": "azərbaycan dili"
    },
        "bm": {
        "name": "Bambara",
            "nativeName": "bamanankan"
    },
        "ba": {
        "name": "Bashkir",
            "nativeName": "башҡорт теле"
    },
        "eu": {
        "name": "Basque",
            "nativeName": "euskara, euskera"
    },
        "be": {
        "name": "Belarusian",
            "nativeName": "Беларуская"
    },
        "bn": {
        "name": "Bengali",
            "nativeName": "বাংলা"
    },
        "bh": {
        "name": "Bihari",
            "nativeName": "भोजपुरी"
    },
        "bi": {
        "name": "Bislama",
            "nativeName": "Bislama"
    },
        "bs": {
        "name": "Bosnian",
            "nativeName": "bosanski jezik"
    },
        "br": {
        "name": "Breton",
            "nativeName": "brezhoneg"
    },
        "bg": {
        "name": "Bulgarian",
            "nativeName": "български език"
    },
        "my": {
        "name": "Burmese",
            "nativeName": "ဗမာစာ"
    },
        "ca": {
        "name": "Catalan; Valencian",
            "nativeName": "Català"
    },
        "ch": {
        "name": "Chamorro",
            "nativeName": "Chamoru"
    },
        "ce": {
        "name": "Chechen",
            "nativeName": "нохчийн мотт"
    },
        "ny": {
        "name": "Chichewa; Chewa; Nyanja",
            "nativeName": "chiCheŵa, chinyanja"
    },
        "zh": {
        "name": "Chinese",
            "nativeName": "中文 (Zhōngwén), 汉语, 漢語"
    },
        "cv": {
        "name": "Chuvash",
            "nativeName": "чӑваш чӗлхи"
    },
        "kw": {
        "name": "Cornish",
            "nativeName": "Kernewek"
    },
        "co": {
        "name": "Corsican",
            "nativeName": "corsu, lingua corsa"
    },
        "cr": {
        "name": "Cree",
            "nativeName": "ᓀᐦᐃᔭᐍᐏᐣ"
    },
        "hr": {
        "name": "Croatian",
            "nativeName": "hrvatski"
    },
        "cs": {
        "name": "Czech",
            "nativeName": "česky, čeština"
    },
        "da": {
        "name": "Danish",
            "nativeName": "dansk"
    },
        "dv": {
        "name": "Divehi; Dhivehi; Maldivian;",
            "nativeName": "ދިވެހި"
    },
        "nl": {
        "name": "Dutch",
            "nativeName": "Nederlands, Vlaams"
    },
        "en": {
        "name": "English",
            "nativeName": "English"
    },
        "eo": {
        "name": "Esperanto",
            "nativeName": "Esperanto"
    },
        "et": {
        "name": "Estonian",
            "nativeName": "eesti, eesti keel"
    },
        "ee": {
        "name": "Ewe",
            "nativeName": "Eʋegbe"
    },
        "fo": {
        "name": "Faroese",
            "nativeName": "føroyskt"
    },
        "fj": {
        "name": "Fijian",
            "nativeName": "vosa Vakaviti"
    },
        "fi": {
        "name": "Finnish",
            "nativeName": "suomi, suomen kieli"
    },
        "fr": {
        "name": "French",
            "nativeName": "français, langue française"
    },
        "ff": {
        "name": "Fula; Fulah; Pulaar; Pular",
            "nativeName": "Fulfulde, Pulaar, Pular"
    },
        "gl": {
        "name": "Galician",
            "nativeName": "Galego"
    },
        "ka": {
        "name": "Georgian",
            "nativeName": "ქართული"
    },
        "de": {
        "name": "German",
            "nativeName": "Deutsch"
    },
        "el": {
        "name": "Greek, Modern",
            "nativeName": "Ελληνικά"
    },
        "gn": {
        "name": "Guaraní",
            "nativeName": "Avañeẽ"
    },
        "gu": {
        "name": "Gujarati",
            "nativeName": "ગુજરાતી"
    },
        "ht": {
        "name": "Haitian; Haitian Creole",
            "nativeName": "Kreyòl ayisyen"
    },
        "ha": {
        "name": "Hausa",
            "nativeName": "Hausa, هَوُسَ"
    },
        "he": {
        "name": "Hebrew (modern)",
            "nativeName": "עברית"
    },
        "hz": {
        "name": "Herero",
            "nativeName": "Otjiherero"
    },
        "hi": {
        "name": "Hindi",
            "nativeName": "हिन्दी, हिंदी"
    },
        "ho": {
        "name": "Hiri Motu",
            "nativeName": "Hiri Motu"
    },
        "hu": {
        "name": "Hungarian",
            "nativeName": "Magyar"
    },
        "ia": {
        "name": "Interlingua",
            "nativeName": "Interlingua"
    },
        "id": {
        "name": "Indonesian",
            "nativeName": "Bahasa Indonesia"
    },
        "ie": {
        "name": "Interlingue",
            "nativeName": "Originally called Occidental; then Interlingue after WWII"
    },
        "ga": {
        "name": "Irish",
            "nativeName": "Gaeilge"
    },
        "ig": {
        "name": "Igbo",
            "nativeName": "Asụsụ Igbo"
    },
        "ik": {
        "name": "Inupiaq",
            "nativeName": "Iñupiaq, Iñupiatun"
    },
        "io": {
        "name": "Ido",
            "nativeName": "Ido"
    },
        "is": {
        "name": "Icelandic",
            "nativeName": "Íslenska"
    },
        "it": {
        "name": "Italian",
            "nativeName": "Italiano"
    },
        "iu": {
        "name": "Inuktitut",
            "nativeName": "ᐃᓄᒃᑎᑐᑦ"
    },
        "ja": {
        "name": "Japanese",
            "nativeName": "日本語 (にほんご／にっぽんご)"
    },
        "jv": {
        "name": "Javanese",
            "nativeName": "basa Jawa"
    },
        "kl": {
        "name": "Kalaallisut, Greenlandic",
            "nativeName": "kalaallisut, kalaallit oqaasii"
    },
        "kn": {
        "name": "Kannada",
            "nativeName": "ಕನ್ನಡ"
    },
        "kr": {
        "name": "Kanuri",
            "nativeName": "Kanuri"
    },
        "ks": {
        "name": "Kashmiri",
            "nativeName": "कश्मीरी, كشميري‎"
    },
        "kk": {
        "name": "Kazakh",
            "nativeName": "Қазақ тілі"
    },
        "km": {
        "name": "Khmer",
            "nativeName": "ភាសាខ្មែរ"
    },
        "ki": {
        "name": "Kikuyu, Gikuyu",
            "nativeName": "Gĩkũyũ"
    },
        "rw": {
        "name": "Kinyarwanda",
            "nativeName": "Ikinyarwanda"
    },
        "ky": {
        "name": "Kirghiz, Kyrgyz",
            "nativeName": "кыргыз тили"
    },
        "kv": {
        "name": "Komi",
            "nativeName": "коми кыв"
    },
        "kg": {
        "name": "Kongo",
            "nativeName": "KiKongo"
    },
        "ko": {
        "name": "Korean",
            "nativeName": "한국어 (韓國語), 조선말 (朝鮮語)"
    },
        "ku": {
        "name": "Kurdish",
            "nativeName": "Kurdî, كوردی‎"
    },
        "kj": {
        "name": "Kwanyama, Kuanyama",
            "nativeName": "Kuanyama"
    },
        "la": {
        "name": "Latin",
            "nativeName": "latine, lingua latina"
    },
        "lb": {
        "name": "Luxembourgish, Letzeburgesch",
            "nativeName": "Lëtzebuergesch"
    },
        "lg": {
        "name": "Luganda",
            "nativeName": "Luganda"
    },
        "li": {
        "name": "Limburgish, Limburgan, Limburger",
            "nativeName": "Limburgs"
    },
        "ln": {
        "name": "Lingala",
            "nativeName": "Lingála"
    },
        "lo": {
        "name": "Lao",
            "nativeName": "ພາສາລາວ"
    },
        "lt": {
        "name": "Lithuanian",
            "nativeName": "lietuvių kalba"
    },
        "lu": {
        "name": "Luba-Katanga",
            "nativeName": ""
    },
        "lv": {
        "name": "Latvian",
            "nativeName": "latviešu valoda"
    },
        "gv": {
        "name": "Manx",
            "nativeName": "Gaelg, Gailck"
    },
        "mk": {
        "name": "Macedonian",
            "nativeName": "македонски јазик"
    },
        "mg": {
        "name": "Malagasy",
            "nativeName": "Malagasy fiteny"
    },
        "ms": {
        "name": "Malay",
            "nativeName": "bahasa Melayu, بهاس ملايو‎"
    },
        "ml": {
        "name": "Malayalam",
            "nativeName": "മലയാളം"
    },
        "mt": {
        "name": "Maltese",
            "nativeName": "Malti"
    },
        "mi": {
        "name": "Māori",
            "nativeName": "te reo Māori"
    },
        "mr": {
        "name": "Marathi (Marāṭhī)",
            "nativeName": "मराठी"
    },
        "mh": {
        "name": "Marshallese",
            "nativeName": "Kajin M̧ajeļ"
    },
        "mn": {
        "name": "Mongolian",
            "nativeName": "монгол"
    },
        "na": {
        "name": "Nauru",
            "nativeName": "Ekakairũ Naoero"
    },
        "nv": {
        "name": "Navajo, Navaho",
            "nativeName": "Diné bizaad, Dinékʼehǰí"
    },
        "nb": {
        "name": "Norwegian Bokmål",
            "nativeName": "Norsk bokmål"
    },
        "nd": {
        "name": "North Ndebele",
            "nativeName": "isiNdebele"
    },
        "ne": {
        "name": "Nepali",
            "nativeName": "नेपाली"
    },
        "ng": {
        "name": "Ndonga",
            "nativeName": "Owambo"
    },
        "nn": {
        "name": "Norwegian Nynorsk",
            "nativeName": "Norsk nynorsk"
    },
        "no": {
        "name": "Norwegian",
            "nativeName": "Norsk"
    },
        "ii": {
        "name": "Nuosu",
            "nativeName": "ꆈꌠ꒿ Nuosuhxop"
    },
        "nr": {
        "name": "South Ndebele",
            "nativeName": "isiNdebele"
    },
        "oc": {
        "name": "Occitan",
            "nativeName": "Occitan"
    },
        "oj": {
        "name": "Ojibwe, Ojibwa",
            "nativeName": "ᐊᓂᔑᓈᐯᒧᐎᓐ"
    },
        "cu": {
        "name": "Old Church Slavonic, Church Slavic, Church Slavonic, Old Bulgarian, Old Slavonic",
            "nativeName": "ѩзыкъ словѣньскъ"
    },
        "om": {
        "name": "Oromo",
            "nativeName": "Afaan Oromoo"
    },
        "or": {
        "name": "Oriya",
            "nativeName": "ଓଡ଼ିଆ"
    },
        "os": {
        "name": "Ossetian, Ossetic",
            "nativeName": "ирон æвзаг"
    },
        "pa": {
        "name": "Panjabi, Punjabi",
            "nativeName": "ਪੰਜਾਬੀ, پنجابی‎"
    },
        "pi": {
        "name": "Pāli",
            "nativeName": "पाऴि"
    },
        "fa": {
        "name": "Persian",
            "nativeName": "فارسی"
    },
        "pl": {
        "name": "Polish",
            "nativeName": "polski"
    },
        "ps": {
        "name": "Pashto, Pushto",
            "nativeName": "پښتو"
    },
        "pt": {
        "name": "Portuguese",
            "nativeName": "Português"
    },
        "qu": {
        "name": "Quechua",
            "nativeName": "Runa Simi, Kichwa"
    },
        "rm": {
        "name": "Romansh",
            "nativeName": "rumantsch grischun"
    },
        "rn": {
        "name": "Kirundi",
            "nativeName": "kiRundi"
    },
        "ro": {
        "name": "Romanian, Moldavian, Moldovan",
            "nativeName": "română"
    },
        "ru": {
        "name": "Russian",
            "nativeName": "русский язык"
    },
        "sa": {
        "name": "Sanskrit (Saṁskṛta)",
            "nativeName": "संस्कृतम्"
    },
        "sc": {
        "name": "Sardinian",
            "nativeName": "sardu"
    },
        "sd": {
        "name": "Sindhi",
            "nativeName": "सिन्धी, سنڌي، سندھی‎"
    },
        "se": {
        "name": "Northern Sami",
            "nativeName": "Davvisámegiella"
    },
        "sm": {
        "name": "Samoan",
            "nativeName": "gagana faa Samoa"
    },
        "sg": {
        "name": "Sango",
            "nativeName": "yângâ tî sängö"
    },
        "sr": {
        "name": "Serbian",
            "nativeName": "српски језик"
    },
        "gd": {
        "name": "Scottish Gaelic; Gaelic",
            "nativeName": "Gàidhlig"
    },
        "sn": {
        "name": "Shona",
            "nativeName": "chiShona"
    },
        "si": {
        "name": "Sinhala, Sinhalese",
            "nativeName": "සිංහල"
    },
        "sk": {
        "name": "Slovak",
            "nativeName": "slovenčina"
    },
        "sl": {
        "name": "Slovene",
            "nativeName": "slovenščina"
    },
        "so": {
        "name": "Somali",
            "nativeName": "Soomaaliga, af Soomaali"
    },
        "st": {
        "name": "Southern Sotho",
            "nativeName": "Sesotho"
    },
        "es": {
        "name": "Spanish; Castilian",
            "nativeName": "español, castellano"
    },
        "su": {
        "name": "Sundanese",
            "nativeName": "Basa Sunda"
    },
        "sw": {
        "name": "Swahili",
            "nativeName": "Kiswahili"
    },
        "ss": {
        "name": "Swati",
            "nativeName": "SiSwati"
    },
        "sv": {
        "name": "Swedish",
            "nativeName": "svenska"
    },
        "ta": {
        "name": "Tamil",
            "nativeName": "தமிழ்"
    },
        "te": {
        "name": "Telugu",
            "nativeName": "తెలుగు"
    },
        "tg": {
        "name": "Tajik",
            "nativeName": "тоҷикӣ, toğikī, تاجیکی‎"
    },
        "th": {
        "name": "Thai",
            "nativeName": "ไทย"
    },
        "ti": {
        "name": "Tigrinya",
            "nativeName": "ትግርኛ"
    },
        "bo": {
        "name": "Tibetan Standard, Tibetan, Central",
            "nativeName": "བོད་ཡིག"
    },
        "tk": {
        "name": "Turkmen",
            "nativeName": "Türkmen, Түркмен"
    },
        "tl": {
        "name": "Tagalog",
            "nativeName": "Wikang Tagalog, ᜏᜒᜃᜅ᜔ ᜆᜄᜎᜓᜄ᜔"
    },
        "tn": {
        "name": "Tswana",
            "nativeName": "Setswana"
    },
        "to": {
        "name": "Tonga (Tonga Islands)",
            "nativeName": "faka Tonga"
    },
        "tr": {
        "name": "Turkish",
            "nativeName": "Türkçe"
    },
        "ts": {
        "name": "Tsonga",
            "nativeName": "Xitsonga"
    },
        "tt": {
        "name": "Tatar",
            "nativeName": "татарча, tatarça, تاتارچا‎"
    },
        "tw": {
        "name": "Twi",
            "nativeName": "Twi"
    },
        "ty": {
        "name": "Tahitian",
            "nativeName": "Reo Tahiti"
    },
        "ug": {
        "name": "Uighur, Uyghur",
            "nativeName": "Uyƣurqə, ئۇيغۇرچە‎"
    },
        "uk": {
        "name": "Ukrainian",
            "nativeName": "українська"
    },
        "ur": {
        "name": "Urdu",
            "nativeName": "اردو"
    },
        "uz": {
        "name": "Uzbek",
            "nativeName": "zbek, Ўзбек, أۇزبېك‎"
    },
        "ve": {
        "name": "Venda",
            "nativeName": "Tshivenḓa"
    },
        "vi": {
        "name": "Vietnamese",
            "nativeName": "Tiếng Việt"
    },
        "vo": {
        "name": "Volapük",
            "nativeName": "Volapük"
    },
        "wa": {
        "name": "Walloon",
            "nativeName": "Walon"
    },
        "cy": {
        "name": "Welsh",
            "nativeName": "Cymraeg"
    },
        "wo": {
        "name": "Wolof",
            "nativeName": "Wollof"
    },
        "fy": {
        "name": "Western Frisian",
            "nativeName": "Frysk"
    },
        "xh": {
        "name": "Xhosa",
            "nativeName": "isiXhosa"
    },
        "yi": {
        "name": "Yiddish",
            "nativeName": "ייִדיש"
    },
        "yo": {
        "name": "Yoruba",
            "nativeName": "Yorùbá"
    },
        "za": {
        "name": "Zhuang, Chuang",
            "nativeName": "Saɯ cueŋƅ, Saw cuengh"
    },
}

def get_lang_text(code):
    if code in languages.keys():
        return languages[code]["name"]
    return "Unknown"
# search_resp = requests.get(, head)
# search_resp

# %%
# for language aspect

lang_cnt={}

for tweet in tweets:
    lang=get_lang_text(tweet.lang)
    if lang not in lang_cnt:
        lang_cnt[lang] = 0
    lang_cnt[lang]+=1

# %%
print(lang_cnt)
# for code in lang_cnt.keys():
#     print(get_lang_text(code))

language_code = []
language_freq = []

most_used_lang = []
max_lang_freq = 0

for code in lang_cnt.keys():
    language_code.append(code)
    language_freq.append(lang_cnt[code])
    
    if lang_cnt[code] == max_lang_freq:
        most_used_lang.append(code)
    elif lang_cnt[code] > max_lang_freq:
        most_used_lang = []
        most_used_lang.append(code)
        max_lang_freq = lang_cnt[code]

plt.figure(figsize=(20, 10))
plt.bar(language_code, language_freq)
plt.xticks(rotation=90)
plt.xlabel('Languages')
plt.ylabel('Tweet Count')
plt.show()



print('{} {} among the tweets.'.format(', '.join(str(e) for e in most_used_lang), 'is the most used language' if len(most_used_lang)==1 else 'are the most used languages'))
# Out:
# {'English': 5266, 'Hindi': 3872, 'Tamil': 178, 'Unknown': 180, 'Marathi (Marāṭhī)': 233, 'Kannada': 21, 'Bengali': 129, 'Oriya': 10, 'Gujarati': 44, 'Tagalog': 28, 'Malayalam': 20, 'Swedish': 1, 'Telugu': 22, 'Estonian': 10, 'Slovene': 2, 'Haitian; Haitian Creole': 6, 'Basque': 1, 'Urdu': 3, 'Lithuanian': 5, 'Panjabi, Punjabi': 3, 'Danish': 1}
# English is the most used language among the tweets.

# %%
# users

user_verification={"Verified": 0, "Non-Verified": 0}
users={}

for tweet in tweets:
    author=tweet.author
    if author._json['screen_name'] not in users.keys():   
        if author.verified == True:
            user_verification["Verified"]+=1
        else:
            user_verification["Non-Verified"]+=1
    users[author._json['screen_name']] = {'statuses_count':author._json['statuses_count'], 'followers_count':author._json['followers_count'], 'friends_count':author._json['friends_count'], 'created_at':author.created_at}

#     print(author._json['statuses_count'])
#     print(author._json['followers_count'])
#     print(author._json['friends_count'])
#     print(author._json['followers_count'])
        
# plt.figure(figsize=(20, 10))
# plt.bar(list(user_verification.keys()), list(user_verification.values()))


plt.figure(figsize =(10, 10)) 
plt.pie(list(user_verification.values()), labels = list(user_verification.keys()), autopct='%1.1f%%',shadow=True, startangle=90)
plt.legend(loc="upper right")
plt.title("Tweets from Verified vs Non-Verified Users")
plt.show()

# plt.xlabel('Users')
# plt.ylabel('Frequency')
# plt.show()

print("{}% of users who posted this hashtag are verified".format(100*(user_verification["Verified"]/(user_verification["Verified"]+user_verification["Non-Verified"]))))
# Out:
# 5.030674846625767% of users who posted this hashtag are verified

# %%
# verified vs non verified
# location
# most followed users
# newly joined

#tweet histogram with time
#location of followers
#followed by verified users
#% of followers with < 50% tweets from user

# %%
def get_user_info(id):
    user = api.get_user(screen_name=id)
    user_txt = "{} (@{})".format(user._json['name'], user._json['screen_name'])
    return user_txt

# %%
# for max tweets
status = dict(sorted(users.items(), key=lambda item: item[1]['statuses_count'], reverse=True))
status_cnt = [x['statuses_count'] for x in status.values()]
status = list(status.keys())

fig = plt.figure(figsize =(20, 10))
plt.bar(status[:50], status_cnt[:50])
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
plt.title('Top 50 active users')
plt.xlabel('User Ids')
plt.ylabel('Tweet count')
plt.show()


print("{}, {}, and {} are the most active users among all the users available.".format(get_user_info(status[0]), get_user_info(status[1]), get_user_info(status[2])))
# Out:
# 🚩 परशुराम ॐ जयहिंदश्रीराम ॐ 🚩 O+ (@mithu796311), Mohit Andurkar (@mohitsmartlove), and IndiaToday (@IndiaToday) are the most active users among all the users available.

# %%
# max followers_count
labels = dict(sorted(users.items(), key=lambda item: item[1]['followers_count'], reverse=True))
follower_cnt = [x['followers_count'] for x in labels.values()]
labels = list(labels.keys())

fig = plt.figure(figsize =(20, 10))
plt.bar(labels[:50], follower_cnt[:50])
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
plt.title('Top 50 most followed users')
plt.xlabel('User Ids')
plt.ylabel('Follower count')
plt.show()


print("{}, {}, and {} are the top 3 most followed users among all the users available.".format(get_user_info(labels[0]), get_user_info(labels[1]), get_user_info(labels[2])))
# Out:
# NDTV (@ndtv), The Times Of India (@timesofindia), and AajTak (@aajtak) are the top 3 most followed users among all the users available.

# %%
# max friends_cnt
labels = dict(sorted(users.items(), key=lambda item: item[1]['friends_count'], reverse=True))
follower_cnt = [x['friends_count'] for x in labels.values()]
labels = list(labels.keys())

fig = plt.figure(figsize =(20, 10))
plt.bar(labels[:50], follower_cnt[:50])
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
plt.title('Top 50 users with maximum number of friends')
plt.xlabel('User Ids')
plt.ylabel('Friends count')
plt.show()


print("{}, {}, and {} are the top 3 users with maximum number of friends among all the users available.".format(get_user_info(labels[0]), get_user_info(labels[1]), get_user_info(labels[2])))
# Out:
# रोहिणी प्रजापति 🇮🇳🚩🚩 (@Rohani86699020), चौधरी जी.सिंह🇮🇳 (@samarsanatan), and THAKUR AZAD SINGH🇮🇳🇮🇳 (@THAKURAZADINDIA) are the top 3 users with maximum number of friends among all the users available.

# %%
# year of account creation

years_cnt = {2016:0}

for user in users:
    year = users[user]['created_at'].year
    if year not in years_cnt.keys():
        years_cnt[year] = 0
    years_cnt[year] += 1

for year in range(min(years_cnt.keys()), 2020+1):
    if year not in years_cnt.keys():
        years_cnt[year] = 0

years_cnt = dict(sorted(years_cnt.items(), key=lambda item: item[0]))
labels = [str(i) for i in years_cnt.keys()]

plt.figure(figsize=(20,10))
plt.bar(labels, years_cnt.values())
plt.ticklabel_format(style='plain', axis='y')
plt.xlabel('Year')
plt.ylabel('Count of Registrations')
plt.title('User Registrations vs Year')
plt.show()

max_year = max(years_cnt.keys(), key=(lambda key: years_cnt[key]))
print("A maximum of {} users registered during {}.".format(years_cnt[max_year], max_year))
# Out:
# A maximum of 223 users registered during 2020.

# %%
i=0
tweet_time = {}
for tweet in tweets:
#     print(tweet.created_at)
    time_val = tweet.created_at
    time_val = time_val.replace(minute=(time_val.minute//2)*2, second=0)
    if time_val not in tweet_time.keys():
        tweet_time[time_val]=0
    tweet_time[time_val]+=1
    i+=1
#     if i>=1:
#         break

# label = [pytz.timezone().localize(i) for i in tweet_time.keys()]

plt.figure(figsize=(20,10))
plt.ylim(0, max(tweet_time.values())+5)
plt.gca().xaxis_date('Asia/Kolkata')
plt.plot(list(tweet_time.keys()),tweet_time.values(),  linestyle='-', marker='o')
plt.xlabel('Time (in IST)')
plt.ylabel('Tweet Count')
plt.show()

# %%
time_val
# Out:
# datetime.datetime(2020, 12, 20, 10, 52)

# %%
tmp = tweets[0].created_at
tmp.minute/5
# Out:
# 4.0

# %%
import pytz

# %%
time_val = pytz.timezone('Asia/Kolkata').localize(time_val)

# %%
tmp
# Out:
# datetime.datetime(2020, 12, 20, 12, 20, 34)

# %%
time_val
# Out:
# datetime.datetime(2020, 12, 20, 10, 52, tzinfo=<DstTzInfo 'Asia/Kolkata' IST+5:30:00 STD>)

# %%
time_val.tzinfo
# Out:
# <DstTzInfo 'Asia/Kolkata' IST+5:30:00 STD>
