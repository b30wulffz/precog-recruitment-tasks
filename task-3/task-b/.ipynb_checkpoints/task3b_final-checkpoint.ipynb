# %%
import json
import xmltodict
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
def parse_and_save_in_db(path):

    file = open(path, 'r')
    i = 0

    num_lines = sum(1 for line in file)

    file.seek(0)

    # extracting tags from file and parsing them to JSON

    data = []

    for line in file:
        if i>1 and i<(num_lines-1):
            tmp = xmltodict.parse(line)
            tmp = tmp['row']
            obj = {}

            for item in tmp:
                obj[item[1:]] = tmp[item]
            data.append(obj)
        i+=1
        
    return data

# %%
badges = parse_and_save_in_db('./stackoverflow.com/Badges.xml')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/xmltodict.py in push_data(self, item, key, data)
#     163         try:
# --> 164             value = item[key]
#     165             if isinstance(value, list):
#
# KeyError: 'row'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-5143bff7044f> in <module>
# ----> 1 parse_and_save_in_db('./stackoverflow.com/Badges.xml')
#
# <ipython-input-5-fbaf4da7d3c0> in parse_and_save_in_db(path)
#      14     for line in file:
#      15         if i>1 and i<(num_lines-1):
# ---> 16             tmp = xmltodict.parse(line)
#      17             tmp = tmp['row']
#      18             obj = {}
#
# ~/anaconda3/lib/python3.8/site-packages/xmltodict.py in parse(xml_input, encoding, expat, process_namespaces, namespace_separator, disable_entities, **kwargs)
#     325         parser.ParseFile(xml_input)
#     326     else:
# --> 327         parser.Parse(xml_input, True)
#     328     return handler.item
#     329
#
# /tmp/build/80754af9/python_1599203911753/work/Modules/pyexpat.c in EndElement()
#
# ~/anaconda3/lib/python3.8/site-packages/xmltodict.py in endElement(self, full_name)
#     139                 if data:
#     140                     self.push_data(item, self.cdata_key, data)
# --> 141                 self.item = self.push_data(self.item, name, item)
#     142             else:
#     143                 self.item = self.push_data(self.item, name, data)
#
# ~/anaconda3/lib/python3.8/site-packages/xmltodict.py in push_data(self, item, key, data)
#     168                 item[key] = [value, data]
#     169         except KeyError:
# --> 170             if self._should_force_list(key, data):
#     171                 item[key] = [data]
#     172             else:
#
# KeyboardInterrupt:

# %%
tags = parse_and_save_in_db('./stackoverflow.com/Tags.xml')
# Out:
# [{'Id': '1',
#   'TagName': '.net',
#   'Count': '293379',
#   'ExcerptPostId': '3624959',
#   'WikiPostId': '3607476'},
#  {'Id': '2',
#   'TagName': 'html',
#   'Count': '970699',
#   'ExcerptPostId': '3673183',
#   'WikiPostId': '3673182'},
#  {'Id': '3',
#   'TagName': 'javascript',
#   'Count': '1955557',
#   'ExcerptPostId': '3624960',
#   'WikiPostId': '3607052'},
#  {'Id': '4',
#   'TagName': 'css',
#   'Count': '649436',
#   'ExcerptPostId': '3644670',
#   'WikiPostId': '3644669'},
#  {'Id': '5',
#   'TagName': 'php',
#   'Count': '1335050',
#   'ExcerptPostId': '3624936',
#   'WikiPostId': '3607050'},
#  {'Id': '8',
#   'TagName': 'c',
#   'Count': '322600',
#   'ExcerptPostId': '3624961',
#   'WikiPostId': '3607013'},
#  {'Id': '9',
#   'TagName': 'c#',
#   'Count': '1385220',
#   'ExcerptPostId': '3624962',
#   'WikiPostId': '3607007'},
#  {'Id': '10',
#   'TagName': 'c++',
#   'Count': '656969',
#   'ExcerptPostId': '3624963',
#   'WikiPostId': '3606997'},
#  {'Id': '12',
#   'TagName': 'ruby',
#   'Count': '211299',
#   'ExcerptPostId': '3624964',
#   'WikiPostId': '3607043'},
#  {'Id': '14',
#   'TagName': 'lisp',
#   'Count': '6066',
#   'ExcerptPostId': '3656743',
#   'WikiPostId': '3656742'},
#  {'Id': '16',
#   'TagName': 'python',
#   'Count': '1359126',
#   'ExcerptPostId': '3624965',
#   'WikiPostId': '3607014'},
#  {'Id': '17',
#   'TagName': 'java',
#   'Count': '1641102',
#   'ExcerptPostId': '3624966',
#   'WikiPostId': '3607018'},
#  {'Id': '18',
#   'TagName': 'regex',
#   'Count': '221640',
#   'ExcerptPostId': '3624967',
#   'WikiPostId': '3607017'},
#  {'Id': '19',
#   'TagName': 'xml',
#   'Count': '190684',
#   'ExcerptPostId': '3624968',
#   'WikiPostId': '3607588'},
#  {'Id': '21',
#   'TagName': 'mysql',
#   'Count': '587525',
#   'ExcerptPostId': '3624969',
#   'WikiPostId': '3607033'},
#  {'Id': '22',
#   'TagName': 'sql',
#   'Count': '530169',
#   'ExcerptPostId': '3625226',
#   'WikiPostId': '3607304'},
#  {'Id': '23',
#   'TagName': 'tsql',
#   'Count': '61236',
#   'ExcerptPostId': '4777787',
#   'WikiPostId': '4777786'},
#  {'Id': '26',
#   'TagName': 'j#',
#   'Count': '62',
#   'ExcerptPostId': '8355939',
#   'WikiPostId': '8355938'},
#  {'Id': '27',
#   'TagName': 'browser',
#   'Count': '23003',
#   'ExcerptPostId': '5388160',
#   'WikiPostId': '5388159'},
#  {'Id': '28',
#   'TagName': 'linq',
#   'Count': '77200',
#   'ExcerptPostId': '4890031',
#   'WikiPostId': '4890030'},
#  {'Id': '30',
#   'TagName': 'database',
#   'Count': '164126',
#   'ExcerptPostId': '4973766',
#   'WikiPostId': '4973765'},
#  {'Id': '33',
#   'TagName': 'language-agnostic',
#   'Count': '8004',
#   'ExcerptPostId': '5197182',
#   'WikiPostId': '5197181'},
#  {'Id': '34',
#   'TagName': 'unix',
#   'Count': '42712',
#   'ExcerptPostId': '4957075',
#   'WikiPostId': '4957074'},
#  {'Id': '35',
#   'TagName': 'sockets',
#   'Count': '57914',
#   'ExcerptPostId': '5253586',
#   'WikiPostId': '5253585'},
#  {'Id': '38',
#   'TagName': 'apache-flex',
#   'Count': '24197',
#   'ExcerptPostId': '3625227',
#   'WikiPostId': '3608598'},
#  {'Id': '41',
#   'TagName': 'vb.net',
#   'Count': '128414',
#   'ExcerptPostId': '3625228',
#   'WikiPostId': '3607042'},
#  {'Id': '44',
#   'TagName': 'structuremap',
#   'Count': '1728',
#   'ExcerptPostId': '5007962',
#   'WikiPostId': '5007961'},
#  {'Id': '46',
#   'TagName': 'alt.net',
#   'Count': '9',
#   'ExcerptPostId': '25220551',
#   'WikiPostId': '25220550'},
#  {'Id': '48',
#   'TagName': 'architecture',
#   'Count': '14563',
#   'ExcerptPostId': '4083816',
#   'WikiPostId': '4083815'},
#  {'Id': '49',
#   'TagName': 'forms',
#   'Count': '99624',
#   'ExcerptPostId': '5602245',
#   'WikiPostId': '5602244'},
#  {'Id': '52',
#   'TagName': 'aptana',
#   'Count': '1782',
#   'ExcerptPostId': '5726271',
#   'WikiPostId': '5726270'},
#  {'Id': '53',
#   'TagName': 'eclipse',
#   'Count': '118832',
#   'ExcerptPostId': '3625229',
#   'WikiPostId': '3607482'},
#  {'Id': '55',
#   'TagName': 'subclipse',
#   'Count': '698',
#   'ExcerptPostId': '5488734',
#   'WikiPostId': '5488733'},
#  {'Id': '57',
#   'TagName': 'air',
#   'Count': '7788',
#   'ExcerptPostId': '4913302',
#   'WikiPostId': '4913301'},
#  {'Id': '58',
#   'TagName': 'linux',
#   'Count': '185387',
#   'ExcerptPostId': '3625112',
#   'WikiPostId': '3607012'},
#  {'Id': '61',
#   'TagName': 'memory',
#   'Count': '30131',
#   'ExcerptPostId': '5009628',
#   'WikiPostId': '5009627'},
#  {'Id': '63',
#   'TagName': 'svn',
#   'Count': '26185',
#   'ExcerptPostId': '3696944',
#   'WikiPostId': '3696943'},
#  {'Id': '64',
#   'TagName': 'windows',
#   'Count': '137588',
#   'ExcerptPostId': '3625230',
#   'WikiPostId': '3609881'},
#  {'Id': '65',
#   'TagName': 'sitemap',
#   'Count': '1900',
#   'ExcerptPostId': '5146483',
#   'WikiPostId': '5146482'},
#  {'Id': '66',
#   'TagName': 'navigation',
#   'Count': '11443',
#   'ExcerptPostId': '9678906',
#   'WikiPostId': '9678905'},
#  {'Id': '67',
#   'TagName': 'membership',
#   'Count': '923',
#   'ExcerptPostId': '9956567',
#   'WikiPostId': '9956566'},
#  {'Id': '71',
#   'TagName': 'theory',
#   'Count': '1626',
#   'ExcerptPostId': '18267058',
#   'WikiPostId': '18267057'},
#  {'Id': '72',
#   'TagName': 'sql-server',
#   'Count': '279394',
#   'ExcerptPostId': '3625231',
#   'WikiPostId': '3607030'},
#  {'Id': '73',
#   'TagName': 'csv',
#   'Count': '67474',
#   'ExcerptPostId': '4913959',
#   'WikiPostId': '4913958'},
#  {'Id': '75',
#   'TagName': 'sysadmin',
#   'Count': '521',
#   'ExcerptPostId': '8582713',
#   'WikiPostId': '8582712'},
#  {'Id': '76',
#   'TagName': 'compression',
#   'Count': '7814',
#   'ExcerptPostId': '6110824',
#   'WikiPostId': '6110823'},
#  {'Id': '80',
#   'TagName': 'apache',
#   'Count': '86266',
#   'ExcerptPostId': '4979625',
#   'WikiPostId': '4979624'},
#  {'Id': '81',
#   'TagName': 'versioning',
#   'Count': '2707',
#   'ExcerptPostId': '6352292',
#   'WikiPostId': '6352291'},
#  {'Id': '82',
#   'TagName': 'media',
#   'Count': '3065',
#   'ExcerptPostId': '12858677',
#   'WikiPostId': '12858676'},
#  {'Id': '83',
#   'TagName': 'embed',
#   'Count': '3984',
#   'ExcerptPostId': '7538285',
#   'WikiPostId': '7538284'},
#  {'Id': '87',
#   'TagName': 'printing',
#   'Count': '19834',
#   'ExcerptPostId': '6077509',
#   'WikiPostId': '6077508'},
#  {'Id': '88',
#   'TagName': 'youtube',
#   'Count': '13985',
#   'ExcerptPostId': '5304815',
#   'WikiPostId': '5304814'},
#  {'Id': '90',
#   'TagName': 'pdf',
#   'Count': '41830',
#   'ExcerptPostId': '4541006',
#   'WikiPostId': '4541005'},
#  {'Id': '95',
#   'TagName': 'convention',
#   'Count': '366',
#   'ExcerptPostId': '22836385',
#   'WikiPostId': '22836384'},
#  {'Id': '96',
#   'TagName': 'asp.net',
#   'Count': '353369',
#   'ExcerptPostId': '3625232',
#   'WikiPostId': '3607037'},
#  {'Id': '97',
#   'TagName': 'migration',
#   'Count': '8612',
#   'ExcerptPostId': '7982742',
#   'WikiPostId': '7982741'},
#  {'Id': '99',
#   'TagName': 'filesystems',
#   'Count': '8079',
#   'ExcerptPostId': '5378877',
#   'WikiPostId': '5378876'},
#  {'Id': '100',
#   'TagName': 'stack-overflow',
#   'Count': '3639',
#   'ExcerptPostId': '5796105',
#   'WikiPostId': '5796104'},
#  {'Id': '102',
#   'TagName': 'hardware',
#   'Count': '2682',
#   'ExcerptPostId': '5108397',
#   'WikiPostId': '5108396'},
#  {'Id': '105',
#   'TagName': 'hdd',
#   'Count': '22',
#   'ExcerptPostId': '13419617',
#   'WikiPostId': '13419616'},
#  {'Id': '110',
#   'TagName': 'ide',
#   'Count': '9538',
#   'ExcerptPostId': '4915532',
#   'WikiPostId': '4915531'},
#  {'Id': '114',
#   'TagName': 'arrays',
#   'Count': '320168',
#   'ExcerptPostId': '4969094',
#   'WikiPostId': '4969093'},
#  {'Id': '115',
#   'TagName': 'tags',
#   'Count': '9784',
#   'ExcerptPostId': '6575746',
#   'WikiPostId': '6575745'},
#  {'Id': '116',
#   'TagName': 'cloud',
#   'Count': '6859',
#   'ExcerptPostId': '4112372',
#   'WikiPostId': '4112371'},
#  {'Id': '117',
#   'TagName': 'mailto',
#   'Count': '980',
#   'ExcerptPostId': '10293284',
#   'WikiPostId': '10293283'},
#  {'Id': '118',
#   'TagName': 'delphi',
#   'Count': '45260',
#   'ExcerptPostId': '3625233',
#   'WikiPostId': '3607016'},
#  {'Id': '119',
#   'TagName': 'git',
#   'Count': '119048',
#   'ExcerptPostId': '3625234',
#   'WikiPostId': '3607047'},
#  {'Id': '121',
#   'TagName': 'sqlite',
#   'Count': '81002',
#   'ExcerptPostId': '3625235',
#   'WikiPostId': '3607650'},
#  {'Id': '125',
#   'TagName': 'compiler-construction',
#   'Count': '10730',
#   'ExcerptPostId': '3625236',
#   'WikiPostId': '3607487'},
#  {'Id': '126',
#   'TagName': 'x11',
#   'Count': '2773',
#   'ExcerptPostId': '6053748',
#   'WikiPostId': '6053747'},
#  {'Id': '127',
#   'TagName': 'gtk',
#   'Count': '7279',
#   'ExcerptPostId': '5125644',
#   'WikiPostId': '5125643'},
#  {'Id': '129',
#   'TagName': 'opengl',
#   'Count': '33872',
#   'ExcerptPostId': '4058612',
#   'WikiPostId': '4058611'},
#  {'Id': '131',
#   'TagName': 'collaboration',
#   'Count': '484',
#   'ExcerptPostId': '11751342',
#   'WikiPostId': '11751341'},
#  {'Id': '134',
#   'TagName': 'sorting',
#   'Count': '60557',
#   'ExcerptPostId': '5009631',
#   'WikiPostId': '5009630'},
#  {'Id': '136',
#   'TagName': 'security',
#   'Count': '49288',
#   'ExcerptPostId': '3625053',
#   'WikiPostId': '3612218'},
#  {'Id': '137',
#   'TagName': 'oop',
#   'Count': '50873',
#   'ExcerptPostId': '4913607',
#   'WikiPostId': '4913606'},
#  {'Id': '139',
#   'TagName': 'string',
#   'Count': '148785',
#   'ExcerptPostId': '4887591',
#   'WikiPostId': '4887590'},
#  {'Id': '142',
#   'TagName': 'ant',
#   'Count': '14971',
#   'ExcerptPostId': '3625237',
#   'WikiPostId': '3607490'},
#  {'Id': '143',
#   'TagName': 'phing',
#   'Count': '380',
#   'ExcerptPostId': '4886597',
#   'WikiPostId': '4886596'},
#  {'Id': '146',
#   'TagName': 'email',
#   'Count': '52095',
#   'ExcerptPostId': '5483666',
#   'WikiPostId': '5483665'},
#  {'Id': '148',
#   'TagName': 'generics',
#   'Count': '39992',
#   'ExcerptPostId': '4890360',
#   'WikiPostId': '4890359'},
#  {'Id': '152',
#   'TagName': 'lucene',
#   'Count': '11277',
#   'ExcerptPostId': '3625238',
#   'WikiPostId': '3607502'},
#  {'Id': '153',
#   'TagName': 'vb6',
#   'Count': '10145',
#   'ExcerptPostId': '3625239',
#   'WikiPostId': '3607228'},
#  {'Id': '154',
#   'TagName': 'iphone',
#   'Count': '220135',
#   'ExcerptPostId': '3625240',
#   'WikiPostId': '3607496'},
#  {'Id': '162',
#   'TagName': 'com',
#   'Count': '11295',
#   'ExcerptPostId': '4377329',
#   'WikiPostId': '4377328'},
#  {'Id': '169',
#   'TagName': 'openid',
#   'Count': '3274',
#   'ExcerptPostId': '4903934',
#   'WikiPostId': '4903933'},
#  {'Id': '171',
#   'TagName': 'photoshop',
#   'Count': '2178',
#   'ExcerptPostId': '5516368',
#   'WikiPostId': '5516367'},
#  {'Id': '173',
#   'TagName': 'data-binding',
#   'Count': '21116',
#   'ExcerptPostId': '5253639',
#   'WikiPostId': '5253638'},
#  {'Id': '176',
#   'TagName': 'beta',
#   'Count': '569',
#   'ExcerptPostId': '12471310',
#   'WikiPostId': '12471309'},
#  {'Id': '178',
#   'TagName': 'crash',
#   'Count': '11559',
#   'ExcerptPostId': '6967482',
#   'WikiPostId': '6967481'},
#  {'Id': '183',
#   'TagName': 'authentication',
#   'Count': '43612',
#   'ExcerptPostId': '5253712',
#   'WikiPostId': '5253711'},
#  {'Id': '186',
#   'TagName': 'testing',
#   'Count': '38078',
#   'ExcerptPostId': '4922785',
#   'WikiPostId': '4922784'},
#  {'Id': '189',
#   'TagName': 'trust',
#   'Count': '164',
#   'ExcerptPostId': '11291048',
#   'WikiPostId': '11291047'},
#  {'Id': '190',
#   'TagName': 'deployment',
#   'Count': '20117',
#   'ExcerptPostId': '5047602',
#   'WikiPostId': '5047601'},
#  {'Id': '194',
#   'TagName': 'oracle',
#   'Count': '119311',
#   'ExcerptPostId': '3625242',
#   'WikiPostId': '3607031'},
#  {'Id': '197',
#   'TagName': 'random',
#   'Count': '27783',
#   'ExcerptPostId': '6855850',
#   'WikiPostId': '6855849'},
#  {'Id': '198', 'TagName': 'nt', 'Count': '49'},
#  {'Id': '201',
#   'TagName': 'api',
#   'Count': '74530',
#   'ExcerptPostId': '4924743',
#   'WikiPostId': '4924742'},
#  {'Id': '205',
#   'TagName': 'puzzle',
#   'Count': '751',
#   'ExcerptPostId': '8268485',
#   'WikiPostId': '8268484'},
#  {'Id': '210',
#   'TagName': 'metacity',
#   'Count': '10',
#   'ExcerptPostId': '25220570',
#   'WikiPostId': '25220569'},
#  {'Id': '211', 'TagName': 'compiz', 'Count': '39'},
#  {'Id': '215',
#   'TagName': 'iis',
#   'Count': '33404',
#   'ExcerptPostId': '4890022',
#   'WikiPostId': '4890021'},
#  {'Id': '218',
#   'TagName': 'directory',
#   'Count': '16198',
#   'ExcerptPostId': '5840336',
#   'WikiPostId': '5840335'},
#  {'Id': '219',
#   'TagName': 'encryption',
#   'Count': '30746',
#   'ExcerptPostId': '5214024',
#   'WikiPostId': '5214023'},
#  {'Id': '220',
#   'TagName': 'passwords',
#   'Count': '9314',
#   'ExcerptPostId': '7065765',
#   'WikiPostId': '7065764'},
#  {'Id': '227',
#   'TagName': 'iteration',
#   'Count': '7944',
#   'ExcerptPostId': '8364364',
#   'WikiPostId': '8364363'},
#  {'Id': '228', 'TagName': 'peripherals', 'Count': '70'},
#  {'Id': '231',
#   'TagName': 'db2',
#   'Count': '10206',
#   'ExcerptPostId': '5099503',
#   'WikiPostId': '5099502'},
#  {'Id': '236',
#   'TagName': 'embedded',
#   'Count': '8080',
#   'ExcerptPostId': '3625244',
#   'WikiPostId': '3607299'},
#  {'Id': '238',
#   'TagName': 'oledb',
#   'Count': '4036',
#   'ExcerptPostId': '5146993',
#   'WikiPostId': '5146992'},
#  {'Id': '239',
#   'TagName': 'provider',
#   'Count': '801',
#   'ExcerptPostId': '15623639',
#   'WikiPostId': '15623638'},
#  {'Id': '240',
#   'TagName': 'legacy',
#   'Count': '702',
#   'ExcerptPostId': '11277949',
#   'WikiPostId': '11277948'},
#  {'Id': '241',
#   'TagName': 'gis',
#   'Count': '4666',
#   'ExcerptPostId': '4854756',
#   'WikiPostId': '4854755'},
#  {'Id': '242',
#   'TagName': 'mapping',
#   'Count': '7400',
#   'ExcerptPostId': '8328440',
#   'WikiPostId': '8328439'},
#  {'Id': '243',
#   'TagName': 'django',
#   'Count': '221405',
#   'ExcerptPostId': '3625245',
#   'WikiPostId': '3607538'},
#  {'Id': '245',
#   'TagName': 'format',
#   'Count': '9859',
#   'ExcerptPostId': '8058534',
#   'WikiPostId': '8058533'},
#  {'Id': '246',
#   'TagName': 'title-case',
#   'Count': '64',
#   'ExcerptPostId': '17661971',
#   'WikiPostId': '17661970'},
#  {'Id': '247',
#   'TagName': 'reflection',
#   'Count': '22089',
#   'ExcerptPostId': '5329327',
#   'WikiPostId': '5329326'},
#  {'Id': '248',
#   'TagName': 'algorithm',
#   'Count': '97181',
#   'ExcerptPostId': '3625246',
#   'WikiPostId': '3620111'},
#  {'Id': '250',
#   'TagName': 'simulation',
#   'Count': '3429',
#   'ExcerptPostId': '7161885',
#   'WikiPostId': '7161884'},
#  {'Id': '251',
#   'TagName': 'poker',
#   'Count': '405',
#   'ExcerptPostId': '5399042',
#   'WikiPostId': '5399041'},
#  {'Id': '253',
#   'TagName': 'globalization',
#   'Count': '1358',
#   'ExcerptPostId': '7335990',
#   'WikiPostId': '7335989'},
#  {'Id': '256',
#   'TagName': 'postgresql',
#   'Count': '112698',
#   'ExcerptPostId': '3625247',
#   'WikiPostId': '3607532'},
#  {'Id': '259',
#   'TagName': 'math',
#   'Count': '34688',
#   'ExcerptPostId': '5104883',
#   'WikiPostId': '5104882'},
#  {'Id': '261',
#   'TagName': 'ftp',
#   'Count': '13107',
#   'ExcerptPostId': '5094700',
#   'WikiPostId': '5094699'},
#  {'Id': '263',
#   'TagName': 'registry',
#   'Count': '6358',
#   'ExcerptPostId': '6564182',
#   'WikiPostId': '6564181'},
#  {'Id': '264',
#   'TagName': 'cruisecontrol.net',
#   'Count': '1383',
#   'ExcerptPostId': '5146958',
#   'WikiPostId': '5146957'},
#  {'Id': '265',
#   'TagName': 'msbuild',
#   'Count': '13000',
#   'ExcerptPostId': '3626874',
#   'WikiPostId': '3626873'},
#  {'Id': '267',
#   'TagName': 'keyboard',
#   'Count': '10818',
#   'ExcerptPostId': '5449445',
#   'WikiPostId': '5449444'},
#  {'Id': '268',
#   'TagName': 'colemak',
#   'Count': '11',
#   'ExcerptPostId': '12367861',
#   'WikiPostId': '12367860'},
#  {'Id': '269',
#   'TagName': 'qwerty',
#   'Count': '42',
#   'ExcerptPostId': '14718469',
#   'WikiPostId': '14718468'},
#  {'Id': '270',
#   'TagName': 'dvorak',
#   'Count': '57',
#   'ExcerptPostId': '8541083',
#   'WikiPostId': '8541082'},
#  {'Id': '271',
#   'TagName': 'documentation',
#   'Count': '4113',
#   'ExcerptPostId': '5120459',
#   'WikiPostId': '5120458'},
#  {'Id': '272',
#   'TagName': 'xslt',
#   'Count': '33808',
#   'ExcerptPostId': '3625248',
#   'WikiPostId': '3609260'},
#  {'Id': '273',
#   'TagName': 'sandcastle',
#   'Count': '295',
#   'ExcerptPostId': '5955054',
#   'WikiPostId': '5955053'},
#  {'Id': '276',
#   'TagName': 'variables',
#   'Count': '44503',
#   'ExcerptPostId': '5151905',
#   'WikiPostId': '5151904'},
#  {'Id': '277',
#   'TagName': 'debugging',
#   'Count': '43717',
#   'ExcerptPostId': '4985314',
#   'WikiPostId': '4985313'},
#  {'Id': '279',
#   'TagName': 'unicode',
#   'Count': '22044',
#   'ExcerptPostId': '3625249',
#   'WikiPostId': '3607542'},
#  {'Id': '281',
#   'TagName': 'connection',
#   'Count': '8651',
#   'ExcerptPostId': '8907048',
#   'WikiPostId': '8907047'},
#  {'Id': '282',
#   'TagName': 'irc',
#   'Count': '1072',
#   'ExcerptPostId': '6959209',
#   'WikiPostId': '6959208'},
#  {'Id': '283',
#   'TagName': 'social',
#   'Count': '929',
#   'ExcerptPostId': '12248958',
#   'WikiPostId': '12248957'},
#  {'Id': '284',
#   'TagName': '.net-1.1',
#   'Count': '372',
#   'ExcerptPostId': '13154871',
#   'WikiPostId': '13154870'},
#  {'Id': '290',
#   'TagName': 'twitter',
#   'Count': '22857',
#   'ExcerptPostId': '4924829',
#   'WikiPostId': '4924828'},
#  {'Id': '291',
#   'TagName': 'yahoo',
#   'Count': '1017',
#   'ExcerptPostId': '6626298',
#   'WikiPostId': '6626297'},
#  {'Id': '292',
#   'TagName': 'cookies',
#   'Count': '29358',
#   'ExcerptPostId': '4926401',
#   'WikiPostId': '4926400'},
#  {'Id': '293',
#   'TagName': 'vi',
#   'Count': '1891',
#   'ExcerptPostId': '5310904',
#   'WikiPostId': '5310903'},
#  {'Id': '294',
#   'TagName': 'ip',
#   'Count': '7936',
#   'ExcerptPostId': '7743351',
#   'WikiPostId': '7743350'},
#  {'Id': '295', 'TagName': 'country', 'Count': '398'},
#  {'Id': '296',
#   'TagName': 'lookup',
#   'Count': '2598',
#   'ExcerptPostId': '15817463',
#   'WikiPostId': '15817462'},
#  {'Id': '299',
#   'TagName': 'flash',
#   'Count': '35209',
#   'ExcerptPostId': '3659514',
#   'WikiPostId': '3659513'},
#  {'Id': '305',
#   'TagName': 'floating-point',
#   'Count': '12086',
#   'ExcerptPostId': '5723344',
#   'WikiPostId': '5723343'},
#  {'Id': '306',
#   'TagName': 'precision',
#   'Count': '3360',
#   'ExcerptPostId': '12071700',
#   'WikiPostId': '12071699'},
#  {'Id': '308',
#   'TagName': 'directx',
#   'Count': '5320',
#   'ExcerptPostId': '5304735',
#   'WikiPostId': '5304734'},
#  {'Id': '309',
#   'TagName': '3d',
#   'Count': '14387',
#   'ExcerptPostId': '6552230',
#   'WikiPostId': '6552229'},
#  {'Id': '311',
#   'TagName': 'heap',
#   'Count': '4920',
#   'ExcerptPostId': '8087152',
#   'WikiPostId': '8087151'},
#  {'Id': '312', 'TagName': 'purify', 'Count': '28'},
#  {'Id': '314',
#   'TagName': 'size',
#   'Count': '6136',
#   'ExcerptPostId': '8745322',
#   'WikiPostId': '8745321'},
#  {'Id': '316',
#   'TagName': 'ocr',
#   'Count': '4480',
#   'ExcerptPostId': '6514707',
#   'WikiPostId': '6514706'},
#  {'Id': '317',
#   'TagName': 'indexing',
#   'Count': '26462',
#   'ExcerptPostId': '5084724',
#   'WikiPostId': '5084723'},
#  {'Id': '318',
#   'TagName': 'article',
#   'Count': '399',
#   'ExcerptPostId': '21794781',
#   'WikiPostId': '21794780'},
#  {'Id': '319',
#   'TagName': 'chm',
#   'Count': '480',
#   'ExcerptPostId': '3625251',
#   'WikiPostId': '3607541'},
#  {'Id': '321',
#   'TagName': 'malloc',
#   'Count': '7345',
#   'ExcerptPostId': '5277059',
#   'WikiPostId': '5277058'},
#  {'Id': '324',
#   'TagName': 'subdomain',
#   'Count': '5175',
#   'ExcerptPostId': '5186409',
#   'WikiPostId': '5186408'},
#  {'Id': '325',
#   'TagName': 'dns',
#   'Count': '14566',
#   'ExcerptPostId': '5286156',
#   'WikiPostId': '5286155'},
#  {'Id': '328',
#   'TagName': 'account',
#   'Count': '1072',
#   'ExcerptPostId': '16594889',
#   'WikiPostId': '16594888'},
#  {'Id': '329',
#   'TagName': 'viewstate',
#   'Count': '1567',
#   'ExcerptPostId': '6111181',
#   'WikiPostId': '6111180'},
#  {'Id': '330',
#   'TagName': 'safari',
#   'Count': '15048',
#   'ExcerptPostId': '5423429',
#   'WikiPostId': '5423428'},
#  {'Id': '334',
#   'TagName': 'csla',
#   'Count': '213',
#   'ExcerptPostId': '5332655',
#   'WikiPostId': '5332654'},
#  {'Id': '335',
#   'TagName': 'cvs',
#   'Count': '1514',
#   'ExcerptPostId': '4998437',
#   'WikiPostId': '4998436'},
#  {'Id': '339',
#   'TagName': 'meta',
#   'Count': '1415',
#   'ExcerptPostId': '10387735',
#   'WikiPostId': '10387734'},
#  {'Id': '341',
#   'TagName': 'xss',
#   'Count': '3882',
#   'ExcerptPostId': '4903911',
#   'WikiPostId': '4903910'},
#  {'Id': '342',
#   'TagName': 'queue',
#   'Count': '8956',
#   'ExcerptPostId': '5780003',
#   'WikiPostId': '5780002'},
#  {'Id': '343',
#   'TagName': 'collections',
#   'Count': '20590',
#   'ExcerptPostId': '5756317',
#   'WikiPostId': '5756316'},
#  {'Id': '344',
#   'TagName': 'nant',
#   'Count': '1050',
#   'ExcerptPostId': '3624971',
#   'WikiPostId': '3624970'},
#  {'Id': '345',
#   'TagName': 'io',
#   'Count': '15299',
#   'ExcerptPostId': '5055064',
#   'WikiPostId': '5055063'},
#  {'Id': '346',
#   'TagName': 'curses',
#   'Count': '782',
#   'ExcerptPostId': '8674918',
#   'WikiPostId': '8674917'},
#  {'Id': '347',
#   'TagName': 'rockbox',
#   'Count': '6',
#   'ExcerptPostId': '14662652',
#   'WikiPostId': '14662651'},
#  {'Id': '348',
#   'TagName': 'audio',
#   'Count': '30705',
#   'ExcerptPostId': '6072221',
#   'WikiPostId': '6072220'},
#  {'Id': '350',
#   'TagName': 'gtd',
#   'Count': '24',
#   'ExcerptPostId': '5108381',
#   'WikiPostId': '5108380'},
#  {'Id': '351',
#   'TagName': 'subsonic',
#   'Count': '1207',
#   'ExcerptPostId': '5565591',
#   'WikiPostId': '5565590'},
#  {'Id': '352',
#   'TagName': 'nhibernate',
#   'Count': '18712',
#   'ExcerptPostId': '3624972',
#   'WikiPostId': '3607611'},
#  {'Id': '353',
#   'TagName': 'parallel-processing',
#   'Count': '16485',
#   'ExcerptPostId': '8337937',
#   'WikiPostId': '8337936'},
#  {'Id': '355',
#   'TagName': 'validation',
#   'Count': '58609',
#   'ExcerptPostId': '5114527',
#   'WikiPostId': '5114526'},
#  {'Id': '357',
#   'TagName': 'xampp',
#   'Count': '10690',
#   'ExcerptPostId': '5722600',
#   'WikiPostId': '5722599'},
#  {'Id': '359',
#   'TagName': 'permissions',
#   'Count': '14598',
#   'ExcerptPostId': '5488863',
#   'WikiPostId': '5488862'},
#  {'Id': '360',
#   'TagName': 'parameters',
#   'Count': '17797',
#   'ExcerptPostId': '6477436',
#   'WikiPostId': '6477435'},
#  {'Id': '361',
#   'TagName': 'methods',
#   'Count': '25232',
#   'ExcerptPostId': '6016074',
#   'WikiPostId': '6016073'},
#  {'Id': '363',
#   'TagName': 'ajax',
#   'Count': '206289',
#   'ExcerptPostId': '3877045',
#   'WikiPostId': '3877044'},
#  {'Id': '364',
#   'TagName': 'rest',
#   'Count': '75743',
#   'ExcerptPostId': '3624973',
#   'WikiPostId': '3607594'},
#  {'Id': '365',
#   'TagName': 'url',
#   'Count': '37877',
#   'ExcerptPostId': '5147326',
#   'WikiPostId': '5147325'},
#  {'Id': '366',
#   'TagName': 'address-bar',
#   'Count': '187',
#   'ExcerptPostId': '13318988',
#   'WikiPostId': '13318987'},
#  {'Id': '367',
#   'TagName': 'syntax',
#   'Count': '18155',
#   'ExcerptPostId': '5643521',
#   'WikiPostId': '5643520'},
#  {'Id': '368',
#   'TagName': 'binary',
#   'Count': '12043',
#   'ExcerptPostId': '5329456',
#   'WikiPostId': '5329455'},
#  {'Id': '369',
#   'TagName': 'macos',
#   'Count': '97339',
#   'ExcerptPostId': '4979532',
#   'WikiPostId': '4979531'},
#  {'Id': '370',
#   'TagName': 'vim',
#   'Count': '24925',
#   'ExcerptPostId': '3624974',
#   'WikiPostId': '3607606'},
#  {'Id': '371',
#   'TagName': 'emacs',
#   'Count': '16627',
#   'ExcerptPostId': '3629398',
#   'WikiPostId': '3629397'},
#  {'Id': '373',
#   'TagName': 'favicon',
#   'Count': '1416',
#   'ExcerptPostId': '5267987',
#   'WikiPostId': '5267986'},
#  {'Id': '375',
#   'TagName': 'polymorphism',
#   'Count': '8510',
#   'ExcerptPostId': '5689310',
#   'WikiPostId': '5689309'},
#  {'Id': '376',
#   'TagName': 'silverlight',
#   'Count': '27435',
#   'ExcerptPostId': '4171248',
#   'WikiPostId': '4171247'},
#  {'Id': '378',
#   'TagName': 'wpf',
#   'Count': '154740',
#   'ExcerptPostId': '3624975',
#   'WikiPostId': '3607561'},
#  {'Id': '379',
#   'TagName': 'error-handling',
#   'Count': '19735',
#   'ExcerptPostId': '5506485',
#   'WikiPostId': '5506484'},
#  {'Id': '382',
#   'TagName': 'wordpress',
#   'Count': '159138',
#   'ExcerptPostId': '3897620',
#   'WikiPostId': '3897619'},
#  {'Id': '386',
#   'TagName': 'ssh',
#   'Count': '23259',
#   'ExcerptPostId': '5953885',
#   'WikiPostId': '5953884'},
#  {'Id': '387',
#   'TagName': 'bash',
#   'Count': '121365',
#   'ExcerptPostId': '5094497',
#   'WikiPostId': '5094496'},
#  {'Id': '390',
#   'TagName': 'shell',
#   'Count': '75431',
#   'ExcerptPostId': '4958351',
#   'WikiPostId': '4958350'},
#  {'Id': '391',
#   'TagName': 'terminal',
#   'Count': '17857',
#   'ExcerptPostId': '5094651',
#   'WikiPostId': '5094650'},
#  {'Id': '392',
#   'TagName': 'apple-touch-icon',
#   'Count': '75',
#   'ExcerptPostId': '14979993',
#   'WikiPostId': '14979992'},
#  {'Id': '393',
#   'TagName': 'usb',
#   'Count': '7028',
#   'ExcerptPostId': '4974852',
#   'WikiPostId': '4974851'},
#  {'Id': '394',
#   'TagName': 'xfdl',
#   'Count': '9',
#   'ExcerptPostId': '18903095',
#   'WikiPostId': '18903094'},
#  {'Id': '398',
#   'TagName': 'podcast',
#   'Count': '224',
#   'ExcerptPostId': '5592409',
#   'WikiPostId': '5592408'},
#  {'Id': '402',
#   'TagName': 'statistics',
#   'Count': '11680',
#   'ExcerptPostId': '5419904',
#   'WikiPostId': '5419903'},
#  {'Id': '403',
#   'TagName': 'profile',
#   'Count': '1562',
#   'ExcerptPostId': '7837221',
#   'WikiPostId': '7837220'},
#  {'Id': '405',
#   'TagName': 'lingo',
#   'Count': '45',
#   'ExcerptPostId': '8220571',
#   'WikiPostId': '8220570'},
#  {'Id': '406',
#   'TagName': 'shockwave',
#   'Count': '78',
#   'ExcerptPostId': '7246063',
#   'WikiPostId': '7246062'},
#  {'Id': '407', 'TagName': 'application-integration', 'Count': '9'},
#  {'Id': '418',
#   'TagName': 'free',
#   'Count': '2055',
#   'ExcerptPostId': '5654936',
#   'WikiPostId': '5654935'},
#  {'Id': '419',
#   'TagName': 'planning',
#   'Count': '91',
#   'ExcerptPostId': '10463243',
#   'WikiPostId': '10463242'},
#  {'Id': '421',
#   'TagName': 'environment',
#   'Count': '1966',
#   'ExcerptPostId': '8662792',
#   'WikiPostId': '8662791'},
#  {'Id': '422',
#   'TagName': 'workspace',
#   'Count': '991',
#   'ExcerptPostId': '9422829',
#   'WikiPostId': '9422828'},
#  {'Id': '423',
#   'TagName': 'mouse',
#   'Count': '3947',
#   'ExcerptPostId': '5552080',
#   'WikiPostId': '5552079'},
#  {'Id': '426',
#   'TagName': 'processing',
#   'Count': '5605',
#   'ExcerptPostId': '4424429',
#   'WikiPostId': '4424428'},
#  {'Id': '427',
#   'TagName': 'anchor',
#   'Count': '4300',
#   'ExcerptPostId': '10524861',
#   'WikiPostId': '10524860'},
#  {'Id': '430',
#   'TagName': 'quotes',
#   'Count': '1846',
#   'ExcerptPostId': '15567009',
#   'WikiPostId': '15567008'},
#  {'Id': '432',
#   'TagName': 'import',
#   'Count': '20137',
#   'ExcerptPostId': '7933864',
#   'WikiPostId': '7933863'},
#  {'Id': '438',
#   'TagName': 'ergonomics',
#   'Count': '39',
#   'ExcerptPostId': '7430281',
#   'WikiPostId': '7430280'},
#  {'Id': '444',
#   'TagName': 'model-view-controller',
#   'Count': '29711',
#   'ExcerptPostId': '4890099',
#   'WikiPostId': '4890098'},
#  {'Id': '445',
#   'TagName': 'datacontext',
#   'Count': '1391',
#   'ExcerptPostId': '6075670',
#   'WikiPostId': '6075669'},
#  {'Id': '448',
#   'TagName': 'cpu',
#   'Count': '3852',
#   'ExcerptPostId': '5188063',
#   'WikiPostId': '5188062'},
#  {'Id': '450',
#   'TagName': 'macros',
#   'Count': '11696',
#   'ExcerptPostId': '5012833',
#   'WikiPostId': '5012832'},
#  {'Id': '451',
#   'TagName': 'double',
#   'Count': '7207',
#   'ExcerptPostId': '5435813',
#   'WikiPostId': '5435812'},
#  {'Id': '452',
#   'TagName': 'int',
#   'Count': '9524',
#   'ExcerptPostId': '8683108',
#   'WikiPostId': '8683107'},
#  {'Id': '454', 'TagName': 'project-hosting', 'Count': '31'},
#  {'Id': '456',
#   'TagName': 'version-control',
#   'Count': '15591',
#   'ExcerptPostId': '3933491',
#   'WikiPostId': '3933490'},
#  {'Id': '457',
#   'TagName': 'dll',
#   'Count': '23003',
#   'ExcerptPostId': '5123223',
#   'WikiPostId': '5123222'},
#  {'Id': '458',
#   'TagName': 'tdd',
#   'Count': '5693',
#   'ExcerptPostId': '3624976',
#   'WikiPostId': '3607615'},
#  {'Id': '459',
#   'TagName': 'rss',
#   'Count': '7416',
#   'ExcerptPostId': '4998411',
#   'WikiPostId': '4998410'},
#  {'Id': '460',
#   'TagName': 'mvp',
#   'Count': '1907',
#   'ExcerptPostId': '5044695',
#   'WikiPostId': '5044694'},
#  {'Id': '463',
#   'TagName': 'coldfusion',
#   'Count': '13218',
#   'ExcerptPostId': '3625252',
#   'WikiPostId': '3607120'},
#  {'Id': '469',
#   'TagName': 'checkbox',
#   'Count': '26470',
#   'ExcerptPostId': '5289719',
#   'WikiPostId': '5289718'},
#  {'Id': '470',
#   'TagName': 'asp.net-mvc',
#   'Count': '186950',
#   'ExcerptPostId': '3625253',
#   'WikiPostId': '3607478'},
#  {'Id': '477',
#   'TagName': 'clr',
#   'Count': '3621',
#   'ExcerptPostId': '5122630',
#   'WikiPostId': '5122629'},
#  {'Id': '485',
#   'TagName': 'bdd',
#   'Count': '2889',
#   'ExcerptPostId': '4479765',
#   'WikiPostId': '4479764'},
#  {'Id': '487',
#   'TagName': 'build-automation',
#   'Count': '1764',
#   'ExcerptPostId': '8364338',
#   'WikiPostId': '8364337'},
#  {'Id': '488',
#   'TagName': 'console',
#   'Count': '11485',
#   'ExcerptPostId': '5134981',
#   'WikiPostId': '5134980'},
#  {'Id': '491',
#   'TagName': 'datatable',
#   'Count': '18338',
#   'ExcerptPostId': '5829793',
#   'WikiPostId': '5829792'},
#  {'Id': '492',
#   'TagName': 'resharper',
#   'Count': '4613',
#   'ExcerptPostId': '3626623',
#   'WikiPostId': '3626622'},
#  {'Id': '493',
#   'TagName': 'backup',
#   'Count': '5050',
#   'ExcerptPostId': '5642094',
#   'WikiPostId': '5642093'},
#  {'Id': '494',
#   'TagName': 'vbscript',
#   'Count': '17852',
#   'ExcerptPostId': '3625254',
#   'WikiPostId': '3621561'},
#  {'Id': '495',
#   'TagName': 'powerbuilder',
#   'Count': '1199',
#   'ExcerptPostId': '3625255',
#   'WikiPostId': '3611740'},
#  {'Id': '496',
#   'TagName': 'textwrangler',
#   'Count': '178',
#   'ExcerptPostId': '10507948',
#   'WikiPostId': '10507947'},
#  {'Id': '503',
#   'TagName': 'monads',
#   'Count': '2966',
#   'ExcerptPostId': '5057222',
#   'WikiPostId': '5057221'},
#  {'Id': '506',
#   'TagName': 'graphics',
#   'Count': '17916',
#   'ExcerptPostId': '5695352',
#   'WikiPostId': '5695351'},
#  {'Id': '508',
#   'TagName': 'agile',
#   'Count': '1012',
#   'ExcerptPostId': '4998356',
#   'WikiPostId': '4998355'},
#  {'Id': '511',
#   'TagName': 'concurrency',
#   'Count': '18289',
#   'ExcerptPostId': '4774687',
#   'WikiPostId': '4774686'},
#  {'Id': '514',
#   'TagName': 'diagram',
#   'Count': '1518',
#   'ExcerptPostId': '5078906',
#   'WikiPostId': '5078905'},
#  {'Id': '516',
#   'TagName': 'obfuscation',
#   'Count': '2613',
#   'ExcerptPostId': '5187702',
#   'WikiPostId': '5187701'},
#  {'Id': '517',
#   'TagName': 'treeview',
#   'Count': '8290',
#   'ExcerptPostId': '5289633',
#   'WikiPostId': '5289632'},
#  {'Id': '518',
#   'TagName': 'forum',
#   'Count': '874',
#   'ExcerptPostId': '7965566',
#   'WikiPostId': '7965565'},
#  {'Id': '519',
#   'TagName': 'video',
#   'Count': '29707',
#   'ExcerptPostId': '5006599',
#   'WikiPostId': '5006598'},
#  {'Id': '520',
#   'TagName': 'streaming',
#   'Count': '6468',
#   'ExcerptPostId': '6189684',
#   'WikiPostId': '6189683'},
#  {'Id': '521',
#   'TagName': 'payment',
#   'Count': '2663',
#   'ExcerptPostId': '10453631',
#   'WikiPostId': '10453630'},
#  {'Id': '522',
#   'TagName': 'excel',
#   'Count': '215898',
#   'ExcerptPostId': '3625256',
#   'WikiPostId': '3613237'},
#  {'Id': '523',
#   'TagName': 'grid',
#   'Count': '9791',
#   'ExcerptPostId': '6186129',
#   'WikiPostId': '6186128'},
#  {'Id': '524',
#   'TagName': 'clipboard',
#   'Count': '3183',
#   'ExcerptPostId': '5146429',
#   'WikiPostId': '5146428'},
#  {'Id': '526',
#   'TagName': 'powershell',
#   'Count': '77710',
#   'ExcerptPostId': '3625257',
#   'WikiPostId': '3609160'},
#  {'Id': '527',
#   'TagName': 'cmdlets',
#   'Count': '394',
#   'ExcerptPostId': '5237269',
#   'WikiPostId': '5237268'},
#  {'Id': '529',
#   'TagName': 'installation',
#   'Count': '12657',
#   'ExcerptPostId': '8857134',
#   'WikiPostId': '8857133'},
#  {'Id': '531',
#   'TagName': 'scripting',
#   'Count': '14899',
#   'ExcerptPostId': '5526635',
#   'WikiPostId': '5526634'},
#  {'Id': '536',
#   'TagName': 'hosting',
#   'Count': '4629',
#   'ExcerptPostId': '6254365',
#   'WikiPostId': '6254364'},
#  {'Id': '538',
#   'TagName': 'erlang',
#   'Count': '8711',
#   'ExcerptPostId': '3625258',
#   'WikiPostId': '3607505'},
#  {'Id': '540',
#   'TagName': 'verification',
#   'Count': '1157',
#   'ExcerptPostId': '7305797',
#   'WikiPostId': '7305796'},
#  {'Id': '541',
#   'TagName': 'getter',
#   'Count': '1498',
#   'ExcerptPostId': '7532733',
#   'WikiPostId': '7532732'},
#  {'Id': '542',
#   'TagName': 'setter',
#   'Count': '1494',
#   'ExcerptPostId': '7481581',
#   'WikiPostId': '7481580'},
#  {'Id': '543',
#   'TagName': 'optimization',
#   'Count': '30484',
#   'ExcerptPostId': '5112271',
#   'WikiPostId': '5112270'},
#  {'Id': '545',
#   'TagName': 'shortcuts',
#   'Count': '439',
#   'ExcerptPostId': '33797871',
#   'WikiPostId': '33797870'},
#  {'Id': '547',
#   'TagName': 'xen',
#   'Count': '415',
#   'ExcerptPostId': '5708222',
#   'WikiPostId': '5708221'},
#  {'Id': '548',
#   'TagName': 'virtualization',
#   'Count': '2116',
#   'ExcerptPostId': '8339038',
#   'WikiPostId': '8339037'},
#  {'Id': '549',
#   'TagName': 'ubuntu',
#   'Count': '47833',
#   'ExcerptPostId': '5022379',
#   'WikiPostId': '5022378'},
#  {'Id': '552',
#   'TagName': 'mono',
#   'Count': '9621',
#   'ExcerptPostId': '3625259',
#   'WikiPostId': '3607237'},
#  {'Id': '555',
#   'TagName': 'formatting',
#   'Count': '10862',
#   'ExcerptPostId': '8801319',
#   'WikiPostId': '8801318'},
#  {'Id': '556',
#   'TagName': 'paging',
#   'Count': '2184',
#   'ExcerptPostId': '7983338',
#   'WikiPostId': '7983337'},
#  {'Id': '558',
#   'TagName': 'jxta',
#   'Count': '63',
#   'ExcerptPostId': '4953240',
#   'WikiPostId': '4953239'},
#  {'Id': '559',
#   'TagName': 'hsl',
#   'Count': '206',
#   'ExcerptPostId': '15094499',
#   'WikiPostId': '15094498'},
#  {'Id': '560',
#   'TagName': 'rgb',
#   'Count': '2888',
#   'ExcerptPostId': '5310939',
#   'WikiPostId': '5310938'},
#  {'Id': '562',
#   'TagName': 'turkish',
#   'Count': '159',
#   'ExcerptPostId': '6235454',
#   'WikiPostId': '6235453'},
#  {'Id': '564',
#   'TagName': 'modi',
#   'Count': '66',
#   'ExcerptPostId': '11629758',
#   'WikiPostId': '11629757'},
#  {'Id': '565',
#   'TagName': 'dep',
#   'Count': '92',
#   'ExcerptPostId': '9962563',
#   'WikiPostId': '9962562'},
#  {'Id': '572',
#   'TagName': 'tree',
#   'Count': '13929',
#   'ExcerptPostId': '5047496',
#   'WikiPostId': '5047495'},
#  {'Id': '573',
#   'TagName': 'nslookup',
#   'Count': '197',
#   'ExcerptPostId': '9849738',
#   'WikiPostId': '9849737'},
#  {'Id': '578',
#   'TagName': 'recursion',
#   'Count': '35831',
#   'ExcerptPostId': '3724934',
#   'WikiPostId': '3724933'},
#  {'Id': '579',
#   'TagName': 'usability',
#   'Count': '864',
#   'ExcerptPostId': '5789238',
#   'WikiPostId': '5789237'},
#  {'Id': '580',
#   'TagName': 'perl',
#   'Count': '64303',
#   'ExcerptPostId': '3625260',
#   'WikiPostId': '3607675'},
#  {'Id': '581',
#   'TagName': 'hash',
#   'Count': '20922',
#   'ExcerptPostId': '5126927',
#   'WikiPostId': '5126925'},
#  {'Id': '582',
#   'TagName': 'each',
#   'Count': '3568',
#   'ExcerptPostId': '13440597',
#   'WikiPostId': '13440596'},
#  {'Id': '583',
#   'TagName': 'boot',
#   'Count': '1335',
#   'ExcerptPostId': '11481983',
#   'WikiPostId': '11481982'},
#  {'Id': '585',
#   'TagName': 'procedural',
#   'Count': '177',
#   'ExcerptPostId': '14724704',
#   'WikiPostId': '14724703'},
#  {'Id': '586',
#   'TagName': 'maintainability',
#   'Count': '289',
#   'ExcerptPostId': '13575473',
#   'WikiPostId': '13575472'},
#  {'Id': '588',
#   'TagName': 'comparison',
#   'Count': '6965',
#   'ExcerptPostId': '5804501',
#   'WikiPostId': '5804500'},
#  {'Id': '596',
#   'TagName': 'scalar',
#   'Count': '436',
#   'ExcerptPostId': '10074244',
#   'WikiPostId': '10074243'},
#  {'Id': '598',
#   'TagName': 'performance',
#   'Count': '86650',
#   'ExcerptPostId': '5048293',
#   'WikiPostId': '5048292'},
#  {'Id': '600',
#   'TagName': 'vmware',
#   'Count': '2858',
#   'ExcerptPostId': '5035375',
#   'WikiPostId': '5035374'},
#  {'Id': '601',
#   'TagName': 'cron',
#   'Count': '14300',
#   'ExcerptPostId': '5144066',
#   'WikiPostId': '5144065'},
#  {'Id': '602',
#   'TagName': 'settings',
#   'Count': '4565',
#   'ExcerptPostId': '10085602',
#   'WikiPostId': '10085601'},
#  {'Id': '603',
#   'TagName': 'time',
#   'Count': '23721',
#   'ExcerptPostId': '5674228',
#   'WikiPostId': '5674227'},
#  {'Id': '604',
#   'TagName': 'teamcity',
#   'Count': '5613',
#   'ExcerptPostId': '4890005',
#   'WikiPostId': '4890004'},
#  {'Id': '605',
#   'TagName': 'mbunit',
#   'Count': '249',
#   'ExcerptPostId': '6449532',
#   'WikiPostId': '6449531'},
#  {'Id': '606',
#   'TagName': 'diff',
#   'Count': '3990',
#   'ExcerptPostId': '7447211',
#   'WikiPostId': '7447210'},
#  {'Id': '607',
#   'TagName': '.htaccess',
#   'Count': '67404',
#   'ExcerptPostId': '5034641',
#   'WikiPostId': '5034640'},
#  {'Id': '608',
#   'TagName': 'mod-rewrite',
#   'Count': '30884',
#   'ExcerptPostId': '3744959',
#   'WikiPostId': '3744958'},
#  {'Id': '609', 'TagName': 'mappath', 'Count': '17'},
#  {'Id': '614',
#   'TagName': 'fogbugz',
#   'Count': '176',
#   'ExcerptPostId': '3898323',
#   'WikiPostId': '3898322'},
#  {'Id': '618',
#   'TagName': 'midi',
#   'Count': '1590',
#   'ExcerptPostId': '3767445',
#   'WikiPostId': '3767444'},
#  {'Id': '619', 'TagName': 'interface-design', 'Count': '31'},
#  {'Id': '623',
#   'TagName': 'complexity-theory',
#   'Count': '3139',
#   'ExcerptPostId': '5786559',
#   'WikiPostId': '5786558'},
#  {'Id': '624',
#   'TagName': 'big-o',
#   'Count': '5084',
#   'ExcerptPostId': '5110603',
#   'WikiPostId': '5110602'},
#  {'Id': '627',
#   'TagName': 'service',
#   'Count': '20859',
#   'ExcerptPostId': '8104635',
#   'WikiPostId': '8104634'},
#  {'Id': '628',
#   'TagName': 'reduce',
#   'Count': '2129',
#   'ExcerptPostId': '12756357',
#   'WikiPostId': '12756356'},
#  {'Id': '629',
#   'TagName': 'ienumerable',
#   'Count': '3094',
#   'ExcerptPostId': '6428616',
#   'WikiPostId': '6428615'},
#  {'Id': '630',
#   'TagName': 'ienumerator',
#   'Count': '312',
#   'ExcerptPostId': '13442719',
#   'WikiPostId': '13442718'},
#  {'Id': '631',
#   'TagName': 'foreach',
#   'Count': '20861',
#   'ExcerptPostId': '5479110',
#   'WikiPostId': '5479109'},
#  {'Id': '633',
#   'TagName': 'vpn',
#   'Count': '2502',
#   'ExcerptPostId': '5488897',
#   'WikiPostId': '5488896'},
#  {'Id': '638',
#   'TagName': 'explorer',
#   'Count': '1028',
#   'ExcerptPostId': '13318478',
#   'WikiPostId': '13318477'},
#  {'Id': '640',
#   'TagName': 'maps',
#   'Count': '7847',
#   'ExcerptPostId': '9679981',
#   'WikiPostId': '9679980'},
#  {'Id': '641',
#   'TagName': 'ssl',
#   'Count': '41436',
#   'ExcerptPostId': '5124516',
#   'WikiPostId': '5124515'},
#  {'Id': '642',
#   'TagName': 'https',
#   'Count': '20716',
#   'ExcerptPostId': '4985338',
#   'WikiPostId': '4985337'},
#  {'Id': '643',
#   'TagName': 'iframe',
#   'Count': '28724',
#   'ExcerptPostId': '5107916',
#   'WikiPostId': '5107915'},
#  {'Id': '644',
#   'TagName': 'xhtml',
#   'Count': '6590',
#   'ExcerptPostId': '5012850',
#   'WikiPostId': '5012849'},
#  {'Id': '645',
#   'TagName': 'markup',
#   'Count': '1238',
#   'ExcerptPostId': '5947383',
#   'WikiPostId': '5947382'},
#  {'Id': '646',
#   'TagName': 'http-referer',
#   'Count': '518',
#   'ExcerptPostId': '7966603',
#   'WikiPostId': '7966602'},
#  {'Id': '647',
#   'TagName': 'orm',
#   'Count': '16643',
#   'ExcerptPostId': '5253532',
#   'WikiPostId': '5253531'},
#  {'Id': '650',
#   'TagName': 'rake',
#   'Count': '4232',
#   'ExcerptPostId': '5150783',
#   'WikiPostId': '5150782'},
#  {'Id': '652',
#   'TagName': 'clickonce',
#   'Count': '3117',
#   'ExcerptPostId': '5818465',
#   'WikiPostId': '5818464'},
#  {'Id': '653',
#   'TagName': 'installer',
#   'Count': '5603',
#   'ExcerptPostId': '7110661',
#   'WikiPostId': '7110660'},
#  {'Id': '655',
#   'TagName': 'sap',
#   'Count': '5813',
#   'ExcerptPostId': '5564122',
#   'WikiPostId': '5564121'},
#  {'Id': '656',
#   'TagName': 'tortoisesvn',
#   'Count': '4729',
#   'ExcerptPostId': '3761153',
#   'WikiPostId': '3761152'},
#  {'Id': '657',
#   'TagName': 'integration',
#   'Count': '4399',
#   'ExcerptPostId': '9044250',
#   'WikiPostId': '9044249'},
#  {'Id': '658',
#   'TagName': 'upload',
#   'Count': '12810',
#   'ExcerptPostId': '8077660',
#   'WikiPostId': '8077659'},
#  {'Id': '659',
#   'TagName': 'project-planning',
#   'Count': '219',
#   'ExcerptPostId': '5214946',
#   'WikiPostId': '5214945'},
#  {'Id': '667',
#   'TagName': 'ram',
#   'Count': '1791',
#   'ExcerptPostId': '8301034',
#   'WikiPostId': '8301033'},
#  {'Id': '669',
#   'TagName': 'sharepoint',
#   'Count': '25496',
#   'ExcerptPostId': '3653617',
#   'WikiPostId': '3653616'},
#  {'Id': '671',
#   'TagName': 'privileges',
#   'Count': '1234',
#   'ExcerptPostId': '6058383',
#   'WikiPostId': '6058382'},
#  {'Id': '672', 'TagName': 'stsadm', 'Count': '55'},
#  {'Id': '673',
#   'TagName': 'impersonation',
#   'Count': '1376',
#   'ExcerptPostId': '5760471',
#   'WikiPostId': '5760470'},
#  {'Id': '674',
#   'TagName': 'markdown',
#   'Count': '5754',
#   'ExcerptPostId': '5319787',
#   'WikiPostId': '5319786'},
#  {'Id': '677',
#   'TagName': 'propertygrid',
#   'Count': '904',
#   'ExcerptPostId': '9793246',
#   'WikiPostId': '9793245'},
#  {'Id': '678',
#   'TagName': 'prototyping',
#   'Count': '143',
#   'ExcerptPostId': '24069516',
#   'WikiPostId': '24069515'},
#  {'Id': '680',
#   'TagName': 'wmi',
#   'Count': '4017',
#   'ExcerptPostId': '5231698',
#   'WikiPostId': '5231697'},
#  {'Id': '681',
#   'TagName': '64-bit',
#   'Count': '5755',
#   'ExcerptPostId': '5600773',
#   'WikiPostId': '5600772'},
#  {'Id': '682',
#   'TagName': 'xelement',
#   'Count': '826',
#   'ExcerptPostId': '8357843',
#   'WikiPostId': '8357842'},
#  {'Id': '683',
#   'TagName': 'innerxml',
#   'Count': '13',
#   'ExcerptPostId': '15636822',
#   'WikiPostId': '15636821'},
#  {'Id': '684',
#   'TagName': 'replication',
#   'Count': '3415',
#   'ExcerptPostId': '8887271',
#   'WikiPostId': '8887270'},
#  {'Id': '685',
#   'TagName': 'audit',
#   'Count': '952',
#   'ExcerptPostId': '10435517',
#   'WikiPostId': '10435516'},
#  {'Id': '688',
#   'TagName': 'session',
#   'Count': '41538',
#   'ExcerptPostId': '5088687',
#   'WikiPostId': '5088686'},
#  {'Id': '689',
#   'TagName': 'union',
#   'Count': '4208',
#   'ExcerptPostId': '6438218',
#   'WikiPostId': '6438217'},
#  {'Id': '691',
#   'TagName': 'firefox',
#   'Count': '35699',
#   'ExcerptPostId': '5253566',
#   'WikiPostId': '5253565'},
#  {'Id': '694',
#   'TagName': 'null',
#   'Count': '13393',
#   'ExcerptPostId': '5168462',
#   'WikiPostId': '5168461'},
#  {'Id': '696',
#   'TagName': 'profiler',
#   'Count': '1473',
#   'ExcerptPostId': '5751002',
#   'WikiPostId': '5751001'},
#  {'Id': '698',
#   'TagName': 'lamp',
#   'Count': '1969',
#   'ExcerptPostId': '5295381',
#   'WikiPostId': '5295380'},
#  {'Id': '700',
#   'TagName': 'port',
#   'Count': '5363',
#   'ExcerptPostId': '7260650',
#   'WikiPostId': '7260649'},
#  {'Id': '701',
#   'TagName': 'paradigms',
#   'Count': '267',
#   'ExcerptPostId': '13179115',
#   'WikiPostId': '13179114'},
#  {'Id': '706',
#   'TagName': 'smb',
#   'Count': '689',
#   'ExcerptPostId': '10441037',
#   'WikiPostId': '10441036'},
#  {'Id': '711',
#   'TagName': 'multilingual',
#   'Count': '2915',
#   'ExcerptPostId': '5402505',
#   'WikiPostId': '5402504'},
#  {'Id': '713',
#   'TagName': 'ear',
#   'Count': '1193',
#   'ExcerptPostId': '5783437',
#   'WikiPostId': '5783436'},
#  {'Id': '714',
#   'TagName': 'websphere',
#   'Count': '6284',
#   'ExcerptPostId': '5633069',
#   'WikiPostId': '5633068'},
#  {'Id': '716',
#   'TagName': 'rational-number',
#   'Count': '85',
#   'ExcerptPostId': '6235232',
#   'WikiPostId': '6235231'},
#  {'Id': '717',
#   'TagName': 'merge',
#   'Count': '18629',
#   'ExcerptPostId': '5143758',
#   'WikiPostId': '5143757'},
#  {'Id': '719',
#   'TagName': 'policy',
#   'Count': '892',
#   'ExcerptPostId': '23071146',
#   'WikiPostId': '23071145'},
#  {'Id': '722',
#   'TagName': 'benchmarking',
#   'Count': '2898',
#   'ExcerptPostId': '6605689',
#   'WikiPostId': '6605688'},
#  {'Id': '723',
#   'TagName': 'evaluation',
#   'Count': '1030',
#   'ExcerptPostId': '19393093',
#   'WikiPostId': '19393092'},
#  {'Id': '724',
#   'TagName': 'file-io',
#   'Count': '19711',
#   'ExcerptPostId': '4996579',
#   'WikiPostId': '4996578'},
#  {'Id': '725',
#   'TagName': 'configuration',
#   'Count': '15573',
#   'ExcerptPostId': '5163171',
#   'WikiPostId': '5163170'},
#  {'Id': '727',
#   'TagName': 'webcam',
#   'Count': '2472',
#   'ExcerptPostId': '9213557',
#   'WikiPostId': '9213556'},
#  {'Id': '729',
#   'TagName': 'ado.net',
#   'Count': '9413',
#   'ExcerptPostId': '5042312',
#   'WikiPostId': '5042311'},
#  {'Id': '733',
#   'TagName': 'tfs',
#   'Count': '20348',
#   'ExcerptPostId': '3760798',
#   'WikiPostId': '3760797'},
#  {'Id': '735',
#   'TagName': 'messaging',
#   'Count': '2255',
#   'ExcerptPostId': '5408758',
#   'WikiPostId': '5408757'},
#  {'Id': '740',
#   'TagName': 'primitive',
#   'Count': '870',
#   'ExcerptPostId': '8021601',
#   'WikiPostId': '8021600'},
#  {'Id': '741',
#   'TagName': 'autoboxing',
#   'Count': '367',
#   'ExcerptPostId': '5559681',
#   'WikiPostId': '5559680'},
#  {'Id': '742',
#   'TagName': 'mobile',
#   'Count': '26022',
#   'ExcerptPostId': '6006809',
#   'WikiPostId': '6006808'},
#  {'Id': '743',
#   'TagName': 'sms',
#   'Count': '7007',
#   'ExcerptPostId': '4949738',
#   'WikiPostId': '4949737'},
#  {'Id': '752',
#   'TagName': 'wcf',
#   'Count': '49790',
#   'ExcerptPostId': '3624977',
#   'WikiPostId': '3607595'},
#  {'Id': '753',
#   'TagName': 'soa',
#   'Count': '1904',
#   'ExcerptPostId': '4987387',
#   'WikiPostId': '4987386'},
#  {'Id': '758',
#   'TagName': 'workflow',
#   'Count': '4567',
#   'ExcerptPostId': '5820815',
#   'WikiPostId': '5820814'},
#  {'Id': '759',
#   'TagName': 'sdk',
#   'Count': '12871',
#   'ExcerptPostId': '5506405',
#   'WikiPostId': '5506404'},
#  {'Id': '760',
#   'TagName': 'proxy',
#   'Count': '16436',
#   'ExcerptPostId': '5095179',
#   'WikiPostId': '5095178'},
#  {'Id': '761',
#   'TagName': 'gem',
#   'Count': '6299',
#   'ExcerptPostId': '5010171',
#   'WikiPostId': '5010170'},
#  {'Id': '766',
#   'TagName': 'dsl',
#   'Count': '1809',
#   'ExcerptPostId': '6852357',
#   'WikiPostId': '6852356'},
#  {'Id': '767',
#   'TagName': 't4',
#   'Count': '1526',
#   'ExcerptPostId': '4830430',
#   'WikiPostId': '4830429'},
#  {'Id': '768',
#   'TagName': 'vsx',
#   'Count': '349',
#   'ExcerptPostId': '6127944',
#   'WikiPostId': '6127943'},
#  {'Id': '773',
#   'TagName': 'seo',
#   'Count': '7286',
#   'ExcerptPostId': '4044686',
#   'WikiPostId': '4044685'},
#  {'Id': '777',
#   'TagName': 'mapi',
#   'Count': '611',
#   'ExcerptPostId': '5708321',
#   'WikiPostId': '5708320'},
#  {'Id': '778',
#   'TagName': 'pinvoke',
#   'Count': '3563',
#   'ExcerptPostId': '6079938',
#   'WikiPostId': '6079937'},
#  {'Id': '781',
#   'TagName': 'intellisense',
#   'Count': '3323',
#   'ExcerptPostId': '5798029',
#   'WikiPostId': '5798028'},
#  {'Id': '782',
#   'TagName': 'xming',
#   'Count': '74',
#   'ExcerptPostId': '23180709',
#   'WikiPostId': '23180708'},
#  {'Id': '785',
#   'TagName': 'etag',
#   'Count': '539',
#   'ExcerptPostId': '6631433',
#   'WikiPostId': '6631432'},
#  {'Id': '787',
#   'TagName': 'olap',
#   'Count': '1519',
#   'ExcerptPostId': '5045182',
#   'WikiPostId': '5045181'},
#  {'Id': '790',
#   'TagName': 'filehelpers',
#   'Count': '425',
#   'ExcerptPostId': '5109911',
#   'WikiPostId': '5109910'},
#  {'Id': '792',
#   'TagName': 'xmp',
#   'Count': '210',
#   'ExcerptPostId': '9349112',
#   'WikiPostId': '9349111'},
#  {'Id': '793',
#   'TagName': 'qos',
#   'Count': '160',
#   'ExcerptPostId': '22350218',
#   'WikiPostId': '22350217'},
#  {'Id': '794',
#   'TagName': 'networking',
#   'Count': '31679',
#   'ExcerptPostId': '5253674',
#   'WikiPostId': '5253673'},
#  {'Id': '795',
#   'TagName': 'adsl',
#   'Count': '12',
#   'ExcerptPostId': '18105652',
#   'WikiPostId': '18105651'},
#  {'Id': '796',
#   'TagName': 'modem',
#   'Count': '679',
#   'ExcerptPostId': '11863348',
#   'WikiPostId': '11863347'},
#  {'Id': '802',
#   'TagName': 'mercurial',
#   'Count': '8019',
#   'ExcerptPostId': '3625261',
#   'WikiPostId': '3607049'},
#  {'Id': '804',
#   'TagName': 'java-native-interface',
#   'Count': '8813',
#   'ExcerptPostId': '4985098',
#   'WikiPostId': '4985097'},
#  {'Id': '815', 'TagName': 'ssp', 'Count': '45'},
#  {'Id': '816',
#   'TagName': 'search',
#   'Count': '32429',
#   'ExcerptPostId': '5609248',
#   'WikiPostId': '5609247'},
#  {'Id': '817',
#   'TagName': 'microcontroller',
#   'Count': '2879',
#   'ExcerptPostId': '3640939',
#   'WikiPostId': '3640938'},
#  {'Id': '820',
#   'TagName': 'jquery',
#   'Count': '978412',
#   'ExcerptPostId': '3625262',
#   'WikiPostId': '3607053'},
#  {'Id': '823',
#   'TagName': 'x86',
#   'Count': '12942',
#   'ExcerptPostId': '4913044',
#   'WikiPostId': '4913043'},
#  {'Id': '824',
#   'TagName': 'assembly',
#   'Count': '33240',
#   'ExcerptPostId': '3640959',
#   'WikiPostId': '3640958'},
#  {'Id': '828',
#   'TagName': 'confirm',
#   'Count': '696',
#   'ExcerptPostId': '24723981',
#   'WikiPostId': '24723980'},
#  {'Id': '829',
#   'TagName': 'events',
#   'Count': '33585',
#   'ExcerptPostId': '4946849',
#   'WikiPostId': '4946848'},
#  {'Id': '831',
#   'TagName': 'virtual',
#   'Count': '2822',
#   'ExcerptPostId': '12207686',
#   'WikiPostId': '12207685'},
#  {'Id': '833',
#   'TagName': 'height',
#   'Count': '5628',
#   'ExcerptPostId': '7050447',
#   'WikiPostId': '7050446'},
#  {'Id': '834',
#   'TagName': 'schema',
#   'Count': '6059',
#   'ExcerptPostId': '9299844',
#   'WikiPostId': '9299843'},
#  {'Id': '835',
#   'TagName': 'ddl',
#   'Count': '1775',
#   'ExcerptPostId': '6973481',
#   'WikiPostId': '6973480'},
#  {'Id': '837',
#   'TagName': 'remoting',
#   'Count': '1135',
#   'ExcerptPostId': '7792057',
#   'WikiPostId': '7792056'},
#  {'Id': '838',
#   'TagName': 'wireless',
#   'Count': '1127',
#   'ExcerptPostId': '7077982',
#   'WikiPostId': '7077981'},
#  {'Id': '846',
#   'TagName': 'culture',
#   'Count': '744',
#   'ExcerptPostId': '13867660',
#   'WikiPostId': '13867659'},
#  {'Id': '847',
#   'TagName': 'joomla',
# ...
#  {'Id': '1758',
#   'TagName': 'static-methods',
#   'Count': '2352',
#   'ExcerptPostId': '8342599',
#   'WikiPostId': '8342598'},
#  {'Id': '1759',
#   'TagName': 'combobox',
#   'Count': '16362',
#   'ExcerptPostId': '5353731',
#   'WikiPostId': '5353730'},
#  {'Id': '1763',
#   'TagName': 'caching',
#   'Count': '33276',
#   'ExcerptPostId': '5015959',
#   'WikiPostId': '5015958'},
#  {'Id': '1766', 'TagName': 'urlrewriter', 'Count': '47'},
#  {'Id': '1768',
#   'TagName': 'putty',
#   'Count': '2029',
#   'ExcerptPostId': '5783603',
#   'WikiPostId': '5783602'},
#  {'Id': '1771',
#   'TagName': 'shtml',
#   'Count': '83',
#   'ExcerptPostId': '12959721',
#   'WikiPostId': '12959720'},
#  {'Id': '1775',
#   'TagName': 'dotnetnuke',
#   'Count': '3201',
#   'ExcerptPostId': '4189326',
#   'WikiPostId': '4189325'},
#  {'Id': '1776',
#   'TagName': 'speech-recognition',
#   'Count': '4203',
#   'ExcerptPostId': '7162125',
#   'WikiPostId': '7162124'},
#  {'Id': '1781',
#   'TagName': 'combinations',
#   'Count': '4568',
#   'ExcerptPostId': '12939722',
#   'WikiPostId': '12939721'},
#  {'Id': '1783',
#   'TagName': 'build-process',
#   'Count': '2334',
#   'ExcerptPostId': '7392715',
#   'WikiPostId': '7392714'},
#  {'Id': '1784',
#   'TagName': 'pdf-generation',
#   'Count': '6313',
#   'ExcerptPostId': '7065882',
#   'WikiPostId': '7065881'},
#  {'Id': '1786',
#   'TagName': 'servicepacks',
#   'Count': '37',
#   'ExcerptPostId': '10605271',
#   'WikiPostId': '10605270'},
#  {'Id': '1787',
#   'TagName': 'rendering',
#   'Count': '5283',
#   'ExcerptPostId': '5918769',
#   'WikiPostId': '5918768'},
#  {'Id': '1788',
#   'TagName': 'greasemonkey',
#   'Count': '2678',
#   'ExcerptPostId': '5121430',
#   'WikiPostId': '5121429'},
#  {'Id': '1789',
#   'TagName': 'watin',
#   'Count': '1052',
#   'ExcerptPostId': '5143273',
#   'WikiPostId': '5143272'},
#  {'Id': '1790',
#   'TagName': 'automated-tests',
#   'Count': '9531',
#   'ExcerptPostId': '7051065',
#   'WikiPostId': '7051064'},
#  {'Id': '1792', 'TagName': 'dailybuilds', 'Count': '17'},
#  {'Id': '1796',
#   'TagName': 'command',
#   'Count': '8677',
#   'ExcerptPostId': '9652702',
#   'WikiPostId': '9652701'},
#  {'Id': '1802',
#   'TagName': 'vsto',
#   'Count': '5531',
#   'ExcerptPostId': '3625018',
#   'WikiPostId': '3625017'},
#  {'Id': '1805',
#   'TagName': 'install',
#   'Count': '7406',
#   'ExcerptPostId': '9697142',
#   'WikiPostId': '9697141'},
#  {'Id': '1808',
#   'TagName': 'ocaml',
#   'Count': '6068',
#   'ExcerptPostId': '3832033',
#   'WikiPostId': '3832032'},
#  {'Id': '1814',
#   'TagName': 'ultrawebgrid',
#   'Count': '49',
#   'ExcerptPostId': '14547698',
#   'WikiPostId': '14547697'},
#  {'Id': '1815',
#   'TagName': 'infragistics',
#   'Count': '1669',
#   'ExcerptPostId': '4950977',
#   'WikiPostId': '4950976'},
#  {'Id': '1816',
#   'TagName': 'preprocessor',
#   'Count': '1332',
#   'ExcerptPostId': '5184273',
#   'WikiPostId': '5184272'},
#  {'Id': '1817',
#   'TagName': 'frameworks',
#   'Count': '10744',
#   'ExcerptPostId': '5215746',
#   'WikiPostId': '5215745'},
#  {'Id': '1819',
#   'TagName': 'google-maps',
#   'Count': '62161',
#   'ExcerptPostId': '3625330',
#   'WikiPostId': '3610293'},
#  {'Id': '1828',
#   'TagName': 'uml',
#   'Count': '5864',
#   'ExcerptPostId': '4998445',
#   'WikiPostId': '4998444'},
#  {'Id': '1829',
#   'TagName': 'modeling',
#   'Count': '1583',
#   'ExcerptPostId': '13250281',
#   'WikiPostId': '13250280'},
#  {'Id': '1832',
#   'TagName': 'consolas',
#   'Count': '9',
#   'ExcerptPostId': '25220790',
#   'WikiPostId': '25220789'},
#  {'Id': '1834',
#   'TagName': 'dictionary',
#   'Count': '52205',
#   'ExcerptPostId': '6168485',
#   'WikiPostId': '6168484'},
#  {'Id': '1835',
#   'TagName': 'open-source',
#   'Count': '3735',
#   'ExcerptPostId': '5637073',
#   'WikiPostId': '5637072'},
#  {'Id': '1838',
#   'TagName': 'gdi+',
#   'Count': '2644',
#   'ExcerptPostId': '4998381',
#   'WikiPostId': '4998380'},
#  {'Id': '1839',
#   'TagName': 'ilist',
#   'Count': '284',
#   'ExcerptPostId': '8477565',
#   'WikiPostId': '8477564'},
#  {'Id': '1840',
#   'TagName': 'sourceforge',
#   'Count': '200',
#   'ExcerptPostId': '7132017',
#   'WikiPostId': '7132016'},
#  {'Id': '1843',
#   'TagName': 'ascii',
#   'Count': '5737',
#   'ExcerptPostId': '5310017',
#   'WikiPostId': '5310016'},
#  {'Id': '1847',
#   'TagName': 'visio',
#   'Count': '1210',
#   'ExcerptPostId': '5998329',
#   'WikiPostId': '5998328'},
#  {'Id': '1848',
#   'TagName': 'visualization',
#   'Count': '3965',
#   'ExcerptPostId': '5146384',
#   'WikiPostId': '5146383'},
#  {'Id': '1850',
#   'TagName': 'garbage-collection',
#   'Count': '10679',
#   'ExcerptPostId': '5124497',
#   'WikiPostId': '5124496'},
#  {'Id': '1851',
#   'TagName': 'stripes',
#   'Count': '287',
#   'ExcerptPostId': '3807974',
#   'WikiPostId': '3807973'},
#  {'Id': '1852',
#   'TagName': 'yaml',
#   'Count': '7878',
#   'ExcerptPostId': '3748661',
#   'WikiPostId': '3748660'},
#  {'Id': '1854',
#   'TagName': 'glossary',
#   'Count': '87',
#   'ExcerptPostId': '30990997',
#   'WikiPostId': '30990996'},
#  {'Id': '1856',
#   'TagName': 'add-in',
#   'Count': '2402',
#   'ExcerptPostId': '8149174',
#   'WikiPostId': '8149173'},
#  {'Id': '1857',
#   'TagName': 'dtd',
#   'Count': '1314',
#   'ExcerptPostId': '6174885',
#   'WikiPostId': '6174884'},
#  {'Id': '1858',
#   'TagName': 'vnc',
#   'Count': '602',
#   'ExcerptPostId': '4174711',
#   'WikiPostId': '4174710'},
#  {'Id': '1861', 'TagName': 'suckerfish', 'Count': '53'},
#  {'Id': '1862',
#   'TagName': 'msg',
#   'Count': '234',
#   'ExcerptPostId': '18181214',
#   'WikiPostId': '18181213'},
#  {'Id': '1863',
#   'TagName': 'message',
#   'Count': '3000',
#   'ExcerptPostId': '12277084',
#   'WikiPostId': '12277083'},
#  {'Id': '1864',
#   'TagName': 'xquery',
#   'Count': '4351',
#   'ExcerptPostId': '5224981',
#   'WikiPostId': '5224980'},
#  {'Id': '1866',
#   'TagName': 'solr',
#   'Count': '18901',
#   'ExcerptPostId': '3625332',
#   'WikiPostId': '3608751'},
#  {'Id': '1869',
#   'TagName': 'sql-server-agent',
#   'Count': '394',
#   'ExcerptPostId': '6413534',
#   'WikiPostId': '6413533'},
#  {'Id': '1871',
#   'TagName': 'fortran',
#   'Count': '10382',
#   'ExcerptPostId': '3793300',
#   'WikiPostId': '3793299'},
#  {'Id': '1872',
#   'TagName': 'ctypes',
#   'Count': '3018',
#   'ExcerptPostId': '4423550',
#   'WikiPostId': '4423549'},
#  {'Id': '1873',
#   'TagName': 'styles',
#   'Count': '7634',
#   'ExcerptPostId': '7338756',
#   'WikiPostId': '7338755'},
#  {'Id': '1874',
#   'TagName': 'textbox',
#   'Count': '11683',
#   'ExcerptPostId': '5170161',
#   'WikiPostId': '5170160'},
#  {'Id': '1875', 'TagName': 'nfsclient', 'Count': '60'},
#  {'Id': '1877',
#   'TagName': 'osgi',
#   'Count': '5878',
#   'ExcerptPostId': '5006727',
#   'WikiPostId': '5006726'},
#  {'Id': '1879',
#   'TagName': 'branch',
#   'Count': '4623',
#   'ExcerptPostId': '6350354',
#   'WikiPostId': '6350353'},
#  {'Id': '1880',
#   'TagName': 'trunk',
#   'Count': '153',
#   'ExcerptPostId': '17025455',
#   'WikiPostId': '17025454'},
#  {'Id': '1882',
#   'TagName': 'extends',
#   'Count': '1409',
#   'ExcerptPostId': '10014146',
#   'WikiPostId': '10014145'},
#  {'Id': '1883',
#   'TagName': 'cvsnt',
#   'Count': '34',
#   'ExcerptPostId': '12191346',
#   'WikiPostId': '12191345'},
#  {'Id': '1888',
#   'TagName': 'eruby',
#   'Count': '36',
#   'ExcerptPostId': '13341991',
#   'WikiPostId': '13341990'},
#  {'Id': '1890',
#   'TagName': 'cname',
#   'Count': '770',
#   'ExcerptPostId': '10946773',
#   'WikiPostId': '10946772'},
#  {'Id': '1895',
#   'TagName': 'administration',
#   'Count': '607',
#   'ExcerptPostId': '21684387',
#   'WikiPostId': '21684386'},
#  {'Id': '1896',
#   'TagName': 'portal',
#   'Count': '702',
#   'ExcerptPostId': '10736660',
#   'WikiPostId': '10736659'},
#  {'Id': '1897',
#   'TagName': 'vignette',
#   'Count': '94',
#   'ExcerptPostId': '6015709',
#   'WikiPostId': '6015708'},
#  {'Id': '1898',
#   'TagName': 'portlet',
#   'Count': '1852',
#   'ExcerptPostId': '6131443',
#   'WikiPostId': '6131442'},
#  {'Id': '1899',
#   'TagName': 'jsr168',
#   'Count': '34',
#   'ExcerptPostId': '7490780',
#   'WikiPostId': '7490779'},
#  {'Id': '1903',
#   'TagName': 'entity',
#   'Count': '5655',
#   'ExcerptPostId': '6753470',
#   'WikiPostId': '6753469'},
#  {'Id': '1906',
#   'TagName': 'numerical',
#   'Count': '520',
#   'ExcerptPostId': '9845757',
#   'WikiPostId': '9845756'},
#  {'Id': '1907',
#   'TagName': 'axis2',
#   'Count': '2348',
#   'ExcerptPostId': '5266889',
#   'WikiPostId': '5266888'},
#  {'Id': '1908',
#   'TagName': 'wse',
#   'Count': '141',
#   'ExcerptPostId': '5280201',
#   'WikiPostId': '5280200'},
#  {'Id': '1912',
#   'TagName': 'maven-2',
#   'Count': '5578',
#   'ExcerptPostId': '3625021',
#   'WikiPostId': '3610585'},
#  {'Id': '1914',
#   'TagName': 'windows-installer',
#   'Count': '7668',
#   'ExcerptPostId': '3625023',
#   'WikiPostId': '3625022'},
#  {'Id': '1921',
#   'TagName': 'locale',
#   'Count': '4412',
#   'ExcerptPostId': '7296341',
#   'WikiPostId': '7296340'},
#  {'Id': '1923',
#   'TagName': 'pcre',
#   'Count': '2095',
#   'ExcerptPostId': '5635460',
#   'WikiPostId': '5635459'},
#  {'Id': '1925',
#   'TagName': 'haskell',
#   'Count': '43221',
#   'ExcerptPostId': '3625024',
#   'WikiPostId': '3607687'},
#  {'Id': '1926',
#   'TagName': 'types',
#   'Count': '20857',
#   'ExcerptPostId': '5688861',
#   'WikiPostId': '5688860'},
#  {'Id': '1927',
#   'TagName': 'type-systems',
#   'Count': '418',
#   'ExcerptPostId': '5688886',
#   'WikiPostId': '5688885'},
#  {'Id': '1928',
#   'TagName': 'type-theory',
#   'Count': '147',
#   'ExcerptPostId': '23802231',
#   'WikiPostId': '23802230'},
#  {'Id': '1929',
#   'TagName': 'reporting',
#   'Count': '3377',
#   'ExcerptPostId': '8840417',
#   'WikiPostId': '8840416'},
#  {'Id': '1930',
#   'TagName': 'gzip',
#   'Count': '5125',
#   'ExcerptPostId': '4998580',
#   'WikiPostId': '4998579'},
#  {'Id': '1931',
#   'TagName': 'unit-testing',
#   'Count': '67966',
#   'ExcerptPostId': '3625025',
#   'WikiPostId': '3608605'},
#  {'Id': '1932', 'TagName': 'system.io.fileinfo', 'Count': '68'},
#  {'Id': '1937',
#   'TagName': 'rack',
#   'Count': '1547',
#   'ExcerptPostId': '5271735',
#   'WikiPostId': '5271734'},
#  {'Id': '1939',
#   'TagName': 'identity',
#   'Count': '2384',
#   'ExcerptPostId': '12208265',
#   'WikiPostId': '12208264'},
#  {'Id': '1944',
#   'TagName': 'activemq',
#   'Count': '5212',
#   'ExcerptPostId': '4947921',
#   'WikiPostId': '4947920'},
#  {'Id': '1947', 'TagName': 'payment-schemas', 'Count': '2'},
#  {'Id': '1949',
#   'TagName': 'pascal',
#   'Count': '2095',
#   'ExcerptPostId': '3660227',
#   'WikiPostId': '3660226'},
#  {'Id': '1951',
#   'TagName': 'encode',
#   'Count': '2592',
#   'ExcerptPostId': '13667529',
#   'WikiPostId': '13667528'},
#  {'Id': '1954',
#   'TagName': 'palm-os',
#   'Count': '38',
#   'ExcerptPostId': '7884736',
#   'WikiPostId': '7884735'},
#  {'Id': '1955',
#   'TagName': 'codewarrior',
#   'Count': '90',
#   'ExcerptPostId': '15178898',
#   'WikiPostId': '15178897'},
#  {'Id': '1956',
#   'TagName': 'prc-tools',
#   'Count': '4',
#   'ExcerptPostId': '25220750',
#   'WikiPostId': '25220749'},
#  {'Id': '1959',
#   'TagName': 'defensive-programming',
#   'Count': '126',
#   'ExcerptPostId': '15021026',
#   'WikiPostId': '15021025'},
#  {'Id': '1961',
#   'TagName': 'records',
#   'Count': '690',
#   'ExcerptPostId': '9290740',
#   'WikiPostId': '9290739'},
#  {'Id': '1962',
#   'TagName': 'gdb',
#   'Count': '9129',
#   'ExcerptPostId': '5309157',
#   'WikiPostId': '5309156'},
#  {'Id': '1963',
#   'TagName': 'valgrind',
#   'Count': '3335',
#   'ExcerptPostId': '5379341',
#   'WikiPostId': '5379340'},
#  {'Id': '1964',
#   'TagName': 'ksh',
#   'Count': '2479',
#   'ExcerptPostId': '6038407',
#   'WikiPostId': '6038406'},
#  {'Id': '1966',
#   'TagName': 'comments',
#   'Count': '5351',
#   'ExcerptPostId': '7576964',
#   'WikiPostId': '7576963'},
#  {'Id': '1967',
#   'TagName': 'load',
#   'Count': '6579',
#   'ExcerptPostId': '9405166',
#   'WikiPostId': '9405165'},
#  {'Id': '1971',
#   'TagName': 'glew',
#   'Count': '891',
#   'ExcerptPostId': '9623679',
#   'WikiPostId': '9623678'},
#  {'Id': '1972',
#   'TagName': 'cgi',
#   'Count': '5019',
#   'ExcerptPostId': '5551935',
#   'WikiPostId': '5551934'},
#  {'Id': '1973',
#   'TagName': 'encapsulation',
#   'Count': '1773',
#   'ExcerptPostId': '8341942',
#   'WikiPostId': '8341941'},
#  {'Id': '1980',
#   'TagName': 'uac',
#   'Count': '1320',
#   'ExcerptPostId': '5273630',
#   'WikiPostId': '5273629'},
#  {'Id': '1983', 'TagName': 'ndoc', 'Count': '11'},
#  {'Id': '1987',
#   'TagName': 'operating-system',
#   'Count': '10666',
#   'ExcerptPostId': '5408896',
#   'WikiPostId': '5408895'},
#  {'Id': '1988', 'TagName': 'developer-machine', 'Count': '6'},
#  {'Id': '1991',
#   'TagName': 'visualsvn',
#   'Count': '447',
#   'ExcerptPostId': '8364637',
#   'WikiPostId': '8364636'},
#  {'Id': '1992',
#   'TagName': 'websvn',
#   'Count': '49',
#   'ExcerptPostId': '11339694',
#   'WikiPostId': '11339693'},
#  {'Id': '1993',
#   'TagName': 'posix',
#   'Count': '4991',
#   'ExcerptPostId': '7006700',
#   'WikiPostId': '7006699'},
#  {'Id': '1995',
#   'TagName': 'hadoop',
#   'Count': '41569',
#   'ExcerptPostId': '4891088',
#   'WikiPostId': '4891087'},
#  {'Id': '1997',
#   'TagName': 'assert',
#   'Count': '2159',
#   'ExcerptPostId': '7624049',
#   'WikiPostId': '7624048'},
#  {'Id': '1999',
#   'TagName': 'openssl',
#   'Count': '12560',
#   'ExcerptPostId': '5268469',
#   'WikiPostId': '5268468'},
#  {'Id': '2004',
#   'TagName': 'rdf',
#   'Count': '3551',
#   'ExcerptPostId': '4756841',
#   'WikiPostId': '4756840'},
#  {'Id': '2005',
#   'TagName': 'sesame',
#   'Count': '296',
#   'ExcerptPostId': '6618459',
#   'WikiPostId': '6618458'},
#  {'Id': '2008',
#   'TagName': 'iwork',
#   'Count': '85',
#   'ExcerptPostId': '5671675',
#   'WikiPostId': '5671674'},
#  {'Id': '2010',
#   'TagName': 'packaging',
#   'Count': '1624',
#   'ExcerptPostId': '10973557',
#   'WikiPostId': '10973556'},
#  {'Id': '2013',
#   'TagName': 'sifr',
#   'Count': '373',
#   'ExcerptPostId': '8170898',
#   'WikiPostId': '8170897'},
#  {'Id': '2015',
#   'TagName': 'installshield',
#   'Count': '2292',
#   'ExcerptPostId': '3625028',
#   'WikiPostId': '3625027'},
#  {'Id': '2017',
#   'TagName': 'coredump',
#   'Count': '836',
#   'ExcerptPostId': '10539145',
#   'WikiPostId': '10539144'},
#  {'Id': '2018',
#   'TagName': 'ankhsvn',
#   'Count': '392',
#   'ExcerptPostId': '4071308',
#   'WikiPostId': '4071307'},
#  {'Id': '2019',
#   'TagName': 'backport',
#   'Count': '68',
#   'ExcerptPostId': '22932769',
#   'WikiPostId': '22932768'},
#  {'Id': '2020',
#   'TagName': 'pop3',
#   'Count': '873',
#   'ExcerptPostId': '8356939',
#   'WikiPostId': '8356938'},
#  {'Id': '2021',
#   'TagName': 'imap',
#   'Count': '3804',
#   'ExcerptPostId': '5146470',
#   'WikiPostId': '5146469'},
#  {'Id': '2024',
#   'TagName': 'toad',
#   'Count': '1108',
#   'ExcerptPostId': '7490829',
#   'WikiPostId': '7490828'},
#  {'Id': '2026',
#   'TagName': 'nvelocity',
#   'Count': '100',
#   'ExcerptPostId': '3799784',
#   'WikiPostId': '3799783'},
#  {'Id': '2027',
#   'TagName': 'pointers',
#   'Count': '45876',
#   'ExcerptPostId': '4890936',
#   'WikiPostId': '4890935'},
#  {'Id': '2034',
#   'TagName': 'drivers',
#   'Count': '667',
#   'ExcerptPostId': '12920161',
#   'WikiPostId': '12920160'},
#  {'Id': '2035',
#   'TagName': 'kernel',
#   'Count': '7878',
#   'ExcerptPostId': '3625029',
#   'WikiPostId': '3608380'},
#  {'Id': '2037', 'TagName': 'extended-properties', 'Count': '87'},
#  {'Id': '2039',
#   'TagName': 'specs',
#   'Count': '97',
#   'ExcerptPostId': '48039903',
#   'WikiPostId': '48039902'},
#  {'Id': '2042',
#   'TagName': 'tivo',
#   'Count': '9',
#   'ExcerptPostId': '15944278',
#   'WikiPostId': '15944277'},
#  {'Id': '2043',
#   'TagName': 'sdlc',
#   'Count': '68',
#   'ExcerptPostId': '7494037',
#   'WikiPostId': '7494036'},
#  {'Id': '2045',
#   'TagName': 'firewall',
#   'Count': '2396',
#   'ExcerptPostId': '5094827',
#   'WikiPostId': '5094826'},
#  {'Id': '2046',
#   'TagName': 'boolean-logic',
#   'Count': '1388',
#   'ExcerptPostId': '8057333',
#   'WikiPostId': '8057332'},
#  {'Id': '2051',
#   'TagName': 'authorization',
#   'Count': '7725',
#   'ExcerptPostId': '6423394',
#   'WikiPostId': '6423393'},
#  {'Id': '2054',
#   'TagName': 'integer',
#   'Count': '9533',
#   'ExcerptPostId': '5642573',
#   'WikiPostId': '5642572'},
#  {'Id': '2056',
#   'TagName': 'trackball',
#   'Count': '72',
#   'ExcerptPostId': '9609511',
#   'WikiPostId': '9609510'},
#  {'Id': '2057',
#   'TagName': 'input-devices',
#   'Count': '69',
#   'ExcerptPostId': '19522880',
#   'WikiPostId': '19522879'},
#  {'Id': '2060',
#   'TagName': 'exchange-server',
#   'Count': '4082',
#   'ExcerptPostId': '6953404',
#   'WikiPostId': '6953403'},
#  {'Id': '2061',
#   'TagName': 'email-client',
#   'Count': '553',
#   'ExcerptPostId': '8117267',
#   'WikiPostId': '8117266'},
#  ...]

# %%
users = parse_and_save_in_db('./stackoverflow.com/Users.xml')

# %%
votes = parse_and_save_in_db('./stackoverflow.com/Votes.xml')

# %%
posts = parse_and_save_in_db('./stackoverflow.com/Posts.xml')

# %%
# extracting tags

def get_tags_from_string(val):
    val = val.split("><")
    if len(val[0])>0:
        val[0] = val[0][1:]
        val[len(val)-1] = val[len(val)-1][:-1]
    return val

tags = {}

questions=0

for obj in posts:
    if obj['PostTypeId'] == '1':
        tag_list = get_tags_from_string(obj['Tags'])
        for tag in tag_list:
            if tag not in tags.keys():
                tags[tag] = 0
            tags[tag] += 1
        questions += 1
#         if questions==100000:
#             break
# Out:
# Total number of questions present in posts.xml : 1358860
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-20306e47e5ed> in <module>
#      27
#      28 print("Total number of questions present in posts.xml : {}".format(questions))
# ---> 29 print("Tag with maximum occurances : {}".format(list(tags.keys)[0]))
#      30 print("Python is the tag with maxim ")
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
# sorting the dictionary based on frequency from maximum to minimum
tags = dict(sorted(tags.items(), key=lambda item: item[1], reverse=True))

# figuring out the criteria
print("Total number of questions present in posts.xml : {}".format(questions))
most_tag = list(tags.keys())[0]
print("{} is the tag with maximum occurances which occurs in {} questions".format(most_tag, tags[most_tag]))
if questions == tags[most_tag]:
    print("Since {} tag occurs in every question".format(most_tag))
    print("Hence questions having {} tag is the criteria for subsampling".format(most_tag))
# Out:
# Total number of questions present in posts.xml : 1358860
# python is the tag with maximum occurances which occurs in 1358860 questions
# Since python tag occurs in every question
# Hence questions having python tag is the criteria for subsampling

# %%
# generating a wordcloud of tags

wordcloud = WordCloud(background_color='white', width=3840, height=2160)
wordcloud.generate_from_frequencies(frequencies=tags)

plt.figure(figsize=(20,11),  facecolor='grey')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# a plot of frequency of each tag

top_tags = list(tags.keys())[:10]
top_tags_freq = list(tags.values())[:10]

plt.figure(figsize=(16, 8))
plt.bar(top_tags, top_tags_freq)
plt.ticklabel_format(style='plain', axis='y')
plt.xlabel('Tags')
plt.ylabel('Frequency of Tags')
plt.show()
