# %%
import camelot

# %%
filepath="./Rec_Task/EICHERMOT.pdf"

# %%
tables = camelot.read_pdf(filepath, flavor="stream",  table_regions=['306,196,551,276'])
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-23-1e544efcee03> in <module>
# ----> 1 tables = camelot.read_pdf(filepath, flavor="stream",  table_regions=['306,196,551,276'])
#
# ~/anaconda3/lib/python3.8/site-packages/camelot/io.py in read_pdf(filepath, pages, password, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     111         p = PDFHandler(filepath, pages=pages, password=password)
#     112         kwargs = remove_extra(kwargs, flavor=flavor)
# --> 113         tables = p.parse(
#     114             flavor=flavor,
#     115             suppress_stdout=suppress_stdout,
#
# ~/anaconda3/lib/python3.8/site-packages/camelot/handlers.py in parse(self, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     169             parser = Lattice(**kwargs) if flavor == "lattice" else Stream(**kwargs)
#     170             for p in pages:
# ...

# %%
len(tables)
# Out:
# 1

# %%
tables[0].df
# Out:
#                     0                      1  \
# 0                  80
# 1   STATUTORY REPORTS
# 2
# 3
# 4
# ..                ...                    ...
# 76
# 77
# 78
# 79
# 80                     EICHER MOTORS LIMITED
#
#                                                    2  \
# 0
# 1
# 2   (ii) \n \nRecommending the amount of expenditure
# 3    to be incurred on the activities referred to in
# 4                                        CSR policy.
# ..                                               ...
# 76
# 77       determining the Quantum of Commission to be
# 78
# 79                    paid to the Managing Director.
# 80
#
#                                                     3
# 0
# 1
# 2                      7.1 \nMajor Terms of Reference
# 3   (i) \n \nTo assist the Board in formulating th...
# 4                      Management Plan and practices.
# ..                                                ...
# 76    The members of the Company in their 33rd Annual
# 77
# ...

# %%
tables[1].df
# Out:
#                       0                                                  1  \
# 0                        General Meeting. The details of remuneration o...
# 1
# 2  Name of the Director                                             Salary
# 3
# 4     Mr Siddhartha Lal                                               3.29
# 5     Managing Director
# 6
# 7
# 8
# 9
#
#             2            3                                  4  \
# 0
# 1
# 2  Commission  Perquisites
# 3                                                      Tenure
# 4        4.20                  1.71 5 years (Members at their
# 5                                  AGM held on June 18, 2016,
# 6                                  approved re-appointment of
# 7                               Mr Siddhartha Lal as Managing
# 8                           Director w.e.f. May 1, 2016 up to
# 9                                             April 30, 2021)
#
#                                     5
# 0
# ...

# %%
tables[2]
# Out:
#   Name of the Director  Salary  Commission  Perquisites  \
# 0                  NaN     NaN         NaN          NaN
# 1    Mr Siddhartha Lal    3.29         4.2         1.71
# 2    Managing Director     NaN         NaN          NaN
# 3                  NaN     NaN         NaN          NaN
# 4                  NaN     NaN         NaN          NaN
# 5                  NaN     NaN         NaN          NaN
# 6                  NaN     NaN         NaN          NaN
#
#                           Unnamed: 0                    Service Contract
# 0                             Tenure                       Notice period
# 1          5 years (Members at their       3 months' notice or salary in
# 2         AGM held on June 18, 2016,  lieu of notice for 3 months or for
# 3         approved re-appointment of    such period which falls short of
# 4      Mr Siddhartha Lal as Managing                            3 months
# 5  Director w.e.f. May 1, 2016 up to                                 NaN
# ...
